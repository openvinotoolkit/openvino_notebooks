# %% [markdown]
# # Stable Diffusion v2 Demo with Torch Compile

# %% [markdown]
# ## Stable Diffusion v2 for Text-to-Image Generation
#
# To start, let's look on Text-to-Image process for Stable Diffusion v2. We will use [Stable Diffusion v2-1](https://huggingface.co/stabilityai/stable-diffusion-2-1) model for these purposes. The main difference from Stable Diffusion v2 and Stable Diffusion v2.1 is usage of more data, more training, and less restrictive filtering of the dataset, that gives promising results for selecting wide range of input text prompts. More details about model can be found in [Stability AI blog post](https://stability.ai/blog/stablediffusion2-1-release7-dec-2022) and original model [repository](https://github.com/Stability-AI/stablediffusion).
#
# ### Stable Diffusion in Diffusers library
# To work with Stable Diffusion v2, we will use Hugging Face [Diffusers](https://github.com/huggingface/diffusers) library. To experiment with Stable Diffusion models, Diffusers exposes the [`StableDiffusionPipeline`](https://huggingface.co/docs/diffusers/using-diffusers/conditional_image_generation) similar to the [other Diffusers pipelines](https://huggingface.co/docs/diffusers/api/pipelines/overview).  The code below demonstrates how to create `StableDiffusionPipeline` using `stable-diffusion-2-1`:

# %%
from torch._export import capture_pre_autograd_graph
from nncf.torch.dynamic_graph.patch_pytorch import disable_patching
import numpy as np
# Out:
# INFO:nncf:NNCF initialized successfully. Supported frameworks detected: torch, onnx, openvino
# WARNING:nncf:NNCF provides best results with torch==2.4.*, while current torch version is 2.3.1+cpu. If you encounter issues, consider switching to torch==2.4.*

# %%
from diffusers import DiffusionPipeline
import torch
import random
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)
generator = torch.Generator(device="cpu").manual_seed(42)
pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0")
pipe.to("cpu")

prompt = "valley in the Alps at sunset, epic vista, beautiful landscape, 4k, 8k"
negative_prompt = "frames, borderline, text, charachter, duplicate, error, out of frame, watermark, low quality, ugly, deformed, blur"
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# ### Convert Models to Torch Fx Graph

# %%
text_encoder_input = torch.ones((1, 77), dtype=torch.long)
text_encoder_2_input = torch.ones((1, 77), dtype=torch.long)
vae_encoder_input = torch.ones((1, 3, 256, 256))
vae_decoder_input = torch.ones((1, 4, 128, 128))
vae_decoder_kwargs = {}
vae_decoder_kwargs["return_dict"] = False
latents_shape = (2, 4, 128, 128)
latents = torch.randn(latents_shape)
t = torch.from_numpy(np.array(1, dtype=np.float32))
added_cond_kwargs = {}
added_cond_kwargs["text_embeds"] = torch.ones((2, 1280))
added_cond_kwargs["time_ids"] = torch.ones((2,6))
unet_kwargs = {}
unet_kwargs["encoder_hidden_states"] = torch.ones((2, 77, 2048))
unet_kwargs["added_cond_kwargs"] = added_cond_kwargs
unet_kwargs["return_dict"] = False
unet_input = (latents, t)

text_encoder_kwargs = {}
text_encoder_kwargs['output_hidden_states'] = True

with torch.no_grad():
    with disable_patching():
        text_encoder = capture_pre_autograd_graph(pipe.text_encoder.eval(), args=(text_encoder_input,), kwargs=(text_encoder_kwargs))
        text_encoder_2 = capture_pre_autograd_graph(pipe.text_encoder_2.eval(), args=(text_encoder_2_input,), kwargs=(text_encoder_kwargs))
        vae_encoder = capture_pre_autograd_graph(pipe.vae.encoder, args=(vae_encoder_input,))
        vae_decoder = capture_pre_autograd_graph(pipe.vae.decoder.eval(), args=(vae_decoder_input,))
        unet = capture_pre_autograd_graph(pipe.unet.eval(), args=(*unet_input,), kwargs=(unet_kwargs))
del added_cond_kwargs
del unet_kwargs
del unet_input
del latents
del t
del vae_encoder_input
del vae_decoder_input
del text_encoder_2_input
del text_encoder_input
del text_encoder_kwargs
del vae_decoder_kwargs

# %%
pipe.text_encoder = torch.compile(text_encoder, backend='openvino')
pipe.text_encoder_2 = torch.compile(text_encoder_2, backend='openvino')
pipe.vae.decoder = torch.compile(vae_decoder, backend='openvino')
pipe.vae.encoder = torch.compile(vae_encoder, backend='openvino')
pipe.unet = unet

# %% [markdown]
# ### Weights Compression

# %%
import pickle
with open("test_faster", "rb") as fp:
    unet_calibration_data = pickle.load(fp)

def collect_ops_with_weights(graph_module):
    ops_with_weights = []
    for node in graph_module.graph.nodes:
        if "linear" in node.name:
            ops_with_weights.append(node.name)
    return ops_with_weights

unet_ignored_scope = collect_ops_with_weights(pipe.unet)

# %%
import nncf
from nncf.quantization.advanced_parameters import AdvancedSmoothQuantParameters
from nncf.quantization.range_estimator import RangeEstimatorParametersSet

def disable_progress_bar(pipeline, disable=True):
    if not hasattr(pipeline, "_progress_bar_config"):
        pipeline._progress_bar_config = {'disable': disable}
    else:
        pipeline._progress_bar_config['disable'] = disable

with disable_patching():
    with torch.no_grad():
        # compressed_unet = nncf.compress_weights(unet, ignored_scope=nncf.IgnoredScope(types=['conv2d']))
        # quantized_unet = nncf.quantize( #1
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1, disable_bias_correction=True)
        # )
        # quantized_unet = nncf.quantize( #2
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     fast_bias_correction=False,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1, disable_bias_correction=True, weights_range_estimator_params=RangeEstimatorParametersSet.MINMAX, activations_range_estimator_params=RangeEstimatorParametersSet.MINMAX)
        # )
        # quantized_unet = nncf.quantize( #3
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     fast_bias_correction=False,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1)
        # )
        # quantized_unet = nncf.quantize( #4.1
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     fast_bias_correction=False,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alphas=AdvancedSmoothQuantParameters(convolution=0.95, matmul=-1))
        # )
        quantized_unet = nncf.quantize( #4.2
            model=pipe.unet,
            calibration_dataset=nncf.Dataset(unet_calibration_data),
            subset_size=len(unet_calibration_data),
            model_type=nncf.ModelType.TRANSFORMER,
            fast_bias_correction=False,
            ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
            advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alphas=AdvancedSmoothQuantParameters(convolution=0.95), disable_bias_correction=True)
        )
# del text_encoder
# del text_encoder_2
# del vae_decoder
del unet
# Out:
# WARNING:nncf:Experimental Torch FX quantization backend is being used for the given torch.fx.GraphModule model. Torch FX PTQ is an experimental feature, consider using Torch or OpenVino PTQ backends in case of errors or a poor model performance.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:nncf:743 ignored nodes were found by names in the NNCFGraph
# INFO:nncf:Not adding activation input quantizer for operation: 1061 linear_109
# INFO:nncf:Not adding activation input quantizer for operation: 1064 linear_110
# INFO:nncf:Not adding activation input quantizer for operation: 1141 linear_119
# INFO:nncf:Not adding activation input quantizer for operation: 1144 linear_120
# INFO:nncf:Not adding activation input quantizer for operation: 1221 linear_129
# INFO:nncf:Not adding activation input quantizer for operation: 1224 linear_130
# INFO:nncf:Not adding activation input quantizer for operation: 1301 linear_139
# INFO:nncf:Not adding activation input quantizer for operation: 1304 linear_140
# INFO:nncf:Not adding activation input quantizer for operation: 1381 linear_149
# INFO:nncf:Not adding activation input quantizer for operation: 1384 linear_150
# INFO:nncf:Not adding activation input quantizer for operation: 1511 linear_162
# INFO:nncf:Not adding activation input quantizer for operation: 1514 linear_163
# INFO:nncf:Not adding activation input quantizer for operation: 1591 linear_172
# INFO:nncf:Not adding activation input quantizer for operation: 1594 linear_173
# INFO:nncf:Not adding activation input quantizer for operation: 1671 linear_182
# INFO:nncf:Not adding activation input quantizer for operation: 1674 linear_183
# INFO:nncf:Not adding activation input quantizer for operation: 1751 linear_192
# INFO:nncf:Not adding activation input quantizer for operation: 1754 linear_193
# INFO:nncf:Not adding activation input quantizer for operation: 1831 linear_202
# INFO:nncf:Not adding activation input quantizer for operation: 1834 linear_203
# INFO:nncf:Not adding activation input quantizer for operation: 1911 linear_212
# INFO:nncf:Not adding activation input quantizer for operation: 1914 linear_213
# INFO:nncf:Not adding activation input quantizer for operation: 1991 linear_222
# INFO:nncf:Not adding activation input quantizer for operation: 1994 linear_223
# INFO:nncf:Not adding activation input quantizer for operation: 2071 linear_232
# INFO:nncf:Not adding activation input quantizer for operation: 2074 linear_233
# INFO:nncf:Not adding activation input quantizer for operation: 2151 linear_242
# INFO:nncf:Not adding activation input quantizer for operation: 2154 linear_243
# INFO:nncf:Not adding activation input quantizer for operation: 2231 linear_252
# INFO:nncf:Not adding activation input quantizer for operation: 2234 linear_253
# INFO:nncf:Not adding activation input quantizer for operation: 231 linear_13
# INFO:nncf:Not adding activation input quantizer for operation: 234 linear_14
# INFO:nncf:Not adding activation input quantizer for operation: 2361 linear_265
# INFO:nncf:Not adding activation input quantizer for operation: 2364 linear_266
# INFO:nncf:Not adding activation input quantizer for operation: 2441 linear_275
# INFO:nncf:Not adding activation input quantizer for operation: 2444 linear_276
# INFO:nncf:Not adding activation input quantizer for operation: 2521 linear_285
# INFO:nncf:Not adding activation input quantizer for operation: 2524 linear_286
# INFO:nncf:Not adding activation input quantizer for operation: 2601 linear_295
# INFO:nncf:Not adding activation input quantizer for operation: 2604 linear_296
# INFO:nncf:Not adding activation input quantizer for operation: 2681 linear_305
# INFO:nncf:Not adding activation input quantizer for operation: 2684 linear_306
# INFO:nncf:Not adding activation input quantizer for operation: 2761 linear_315
# INFO:nncf:Not adding activation input quantizer for operation: 2764 linear_316
# INFO:nncf:Not adding activation input quantizer for operation: 2841 linear_325
# INFO:nncf:Not adding activation input quantizer for operation: 2844 linear_326
# INFO:nncf:Not adding activation input quantizer for operation: 2921 linear_335
# INFO:nncf:Not adding activation input quantizer for operation: 2924 linear_336
# INFO:nncf:Not adding activation input quantizer for operation: 3001 linear_345
# INFO:nncf:Not adding activation input quantizer for operation: 3004 linear_346
# INFO:nncf:Not adding activation input quantizer for operation: 3081 linear_355
# INFO:nncf:Not adding activation input quantizer for operation: 3084 linear_356
# INFO:nncf:Not adding activation input quantizer for operation: 311 linear_23
# INFO:nncf:Not adding activation input quantizer for operation: 314 linear_24
# INFO:nncf:Not adding activation input quantizer for operation: 3248 linear_369
# INFO:nncf:Not adding activation input quantizer for operation: 3251 linear_370
# INFO:nncf:Not adding activation input quantizer for operation: 3328 linear_379
# INFO:nncf:Not adding activation input quantizer for operation: 3331 linear_380
# INFO:nncf:Not adding activation input quantizer for operation: 3408 linear_389
# INFO:nncf:Not adding activation input quantizer for operation: 3411 linear_390
# INFO:nncf:Not adding activation input quantizer for operation: 3488 linear_399
# INFO:nncf:Not adding activation input quantizer for operation: 3491 linear_400
# INFO:nncf:Not adding activation input quantizer for operation: 3568 linear_409
# INFO:nncf:Not adding activation input quantizer for operation: 3571 linear_410
# INFO:nncf:Not adding activation input quantizer for operation: 3648 linear_419
# INFO:nncf:Not adding activation input quantizer for operation: 3651 linear_420
# INFO:nncf:Not adding activation input quantizer for operation: 3728 linear_429
# INFO:nncf:Not adding activation input quantizer for operation: 3731 linear_430
# INFO:nncf:Not adding activation input quantizer for operation: 3808 linear_439
# INFO:nncf:Not adding activation input quantizer for operation: 3811 linear_440
# INFO:nncf:Not adding activation input quantizer for operation: 3888 linear_449
# INFO:nncf:Not adding activation input quantizer for operation: 3891 linear_450
# INFO:nncf:Not adding activation input quantizer for operation: 3968 linear_459
# INFO:nncf:Not adding activation input quantizer for operation: 3971 linear_460
# INFO:nncf:Not adding activation input quantizer for operation: 4104 linear_472
# INFO:nncf:Not adding activation input quantizer for operation: 4107 linear_473
# INFO:nncf:Not adding activation input quantizer for operation: 4184 linear_482
# INFO:nncf:Not adding activation input quantizer for operation: 4187 linear_483
# INFO:nncf:Not adding activation input quantizer for operation: 4264 linear_492
# INFO:nncf:Not adding activation input quantizer for operation: 4267 linear_493
# INFO:nncf:Not adding activation input quantizer for operation: 4344 linear_502
# INFO:nncf:Not adding activation input quantizer for operation: 4347 linear_503
# INFO:nncf:Not adding activation input quantizer for operation: 441 linear_36
# INFO:nncf:Not adding activation input quantizer for operation: 4424 linear_512
# INFO:nncf:Not adding activation input quantizer for operation: 4427 linear_513
# INFO:nncf:Not adding activation input quantizer for operation: 444 linear_37
# INFO:nncf:Not adding activation input quantizer for operation: 4504 linear_522
# INFO:nncf:Not adding activation input quantizer for operation: 4507 linear_523
# INFO:nncf:Not adding activation input quantizer for operation: 4584 linear_532
# INFO:nncf:Not adding activation input quantizer for operation: 4587 linear_533
# INFO:nncf:Not adding activation input quantizer for operation: 4664 linear_542
# INFO:nncf:Not adding activation input quantizer for operation: 4667 linear_543
# INFO:nncf:Not adding activation input quantizer for operation: 4744 linear_552
# INFO:nncf:Not adding activation input quantizer for operation: 4747 linear_553
# INFO:nncf:Not adding activation input quantizer for operation: 4824 linear_562
# INFO:nncf:Not adding activation input quantizer for operation: 4827 linear_563
# INFO:nncf:Not adding activation input quantizer for operation: 4960 linear_575
# INFO:nncf:Not adding activation input quantizer for operation: 4963 linear_576
# INFO:nncf:Not adding activation input quantizer for operation: 5040 linear_585
# INFO:nncf:Not adding activation input quantizer for operation: 5043 linear_586
# INFO:nncf:Not adding activation input quantizer for operation: 5120 linear_595
# INFO:nncf:Not adding activation input quantizer for operation: 5123 linear_596
# INFO:nncf:Not adding activation input quantizer for operation: 5200 linear_605
# INFO:nncf:Not adding activation input quantizer for operation: 5203 linear_606
# INFO:nncf:Not adding activation input quantizer for operation: 521 linear_46
# INFO:nncf:Not adding activation input quantizer for operation: 524 linear_47
# INFO:nncf:Not adding activation input quantizer for operation: 5280 linear_615
# INFO:nncf:Not adding activation input quantizer for operation: 5283 linear_616
# INFO:nncf:Not adding activation input quantizer for operation: 5360 linear_625
# INFO:nncf:Not adding activation input quantizer for operation: 5363 linear_626
# INFO:nncf:Not adding activation input quantizer for operation: 5440 linear_635
# INFO:nncf:Not adding activation input quantizer for operation: 5443 linear_636
# INFO:nncf:Not adding activation input quantizer for operation: 5520 linear_645
# INFO:nncf:Not adding activation input quantizer for operation: 5523 linear_646
# INFO:nncf:Not adding activation input quantizer for operation: 5600 linear_655
# INFO:nncf:Not adding activation input quantizer for operation: 5603 linear_656
# INFO:nncf:Not adding activation input quantizer for operation: 5680 linear_665
# INFO:nncf:Not adding activation input quantizer for operation: 5683 linear_666
# INFO:nncf:Not adding activation input quantizer for operation: 5822 linear_678
# INFO:nncf:Not adding activation input quantizer for operation: 5825 linear_679
# INFO:nncf:Not adding activation input quantizer for operation: 5902 linear_688
# INFO:nncf:Not adding activation input quantizer for operation: 5905 linear_689
# INFO:nncf:Not adding activation input quantizer for operation: 6038 linear_701
# INFO:nncf:Not adding activation input quantizer for operation: 6041 linear_702
# INFO:nncf:Not adding activation input quantizer for operation: 6118 linear_711
# INFO:nncf:Not adding activation input quantizer for operation: 6121 linear_712
# INFO:nncf:Not adding activation input quantizer for operation: 6254 linear_724
# INFO:nncf:Not adding activation input quantizer for operation: 6257 linear_725
# INFO:nncf:Not adding activation input quantizer for operation: 6334 linear_734
# INFO:nncf:Not adding activation input quantizer for operation: 6337 linear_735
# INFO:nncf:Not adding activation input quantizer for operation: 661 linear_59
# INFO:nncf:Not adding activation input quantizer for operation: 664 linear_60
# INFO:nncf:Not adding activation input quantizer for operation: 741 linear_69
# INFO:nncf:Not adding activation input quantizer for operation: 744 linear_70
# INFO:nncf:Not adding activation input quantizer for operation: 821 linear_79
# INFO:nncf:Not adding activation input quantizer for operation: 824 linear_80
# INFO:nncf:Not adding activation input quantizer for operation: 901 linear_89
# INFO:nncf:Not adding activation input quantizer for operation: 904 linear_90
# INFO:nncf:Not adding activation input quantizer for operation: 981 linear_99
# INFO:nncf:Not adding activation input quantizer for operation: 984 linear_100
# INFO:nncf:Not adding activation input quantizer for operation: 31 linear
# 33 add_tensor
#
# INFO:nncf:Not adding activation input quantizer for operation: 37 linear_1
# 39 add_tensor_1
#
# INFO:nncf:Not adding activation input quantizer for operation: 65 linear_2
# 67 add_tensor_2
#
# INFO:nncf:Not adding activation input quantizer for operation: 71 linear_3
# 73 add_tensor_3
#
# INFO:nncf:Not adding activation input quantizer for operation: 123 linear_5
# 125 add_tensor_5
#
# INFO:nncf:Not adding activation input quantizer for operation: 1444 linear_155
# 1446 add_tensor_71
#
# INFO:nncf:Not adding activation input quantizer for operation: 159 linear_6
# 161 add_tensor_6
#
# INFO:nncf:Not adding activation input quantizer for operation: 2294 linear_258
# 2296 add_tensor_114
#
# INFO:nncf:Not adding activation input quantizer for operation: 3144 linear_361
# 3146 add_tensor_157
#
# INFO:nncf:Not adding activation input quantizer for operation: 3176 linear_362
# 3178 add_tensor_158
#
# INFO:nncf:Not adding activation input quantizer for operation: 374 linear_29
# 376 add_tensor_17
#
# INFO:nncf:Not adding activation input quantizer for operation: 4032 linear_465
# 4034 add_tensor_201
#
# INFO:nncf:Not adding activation input quantizer for operation: 4888 linear_568
# 4890 add_tensor_244
#
# INFO:nncf:Not adding activation input quantizer for operation: 5750 linear_671
# 5752 add_tensor_287
#
# INFO:nncf:Not adding activation input quantizer for operation: 589 linear_52
# 591 add_tensor_28
#
# INFO:nncf:Not adding activation input quantizer for operation: 5966 linear_694
# 5968 add_tensor_298
#
# INFO:nncf:Not adding activation input quantizer for operation: 6182 linear_717
# 6184 add_tensor_309
#
# INFO:nncf:Not adding activation input quantizer for operation: 6404 linear_740
# 6406 add_tensor_320
#
# INFO:nncf:Not adding activation input quantizer for operation: 6441 linear_741
# 6443 add_tensor_321
#
# INFO:nncf:Not adding activation input quantizer for operation: 6478 linear_742
# 6480 add_tensor_322
#
# INFO:nncf:Not adding activation input quantizer for operation: 92 linear_4
# 94 add_tensor_4
#
# INFO:nncf:Not adding activation input quantizer for operation: 190 linear_7
# 192 add_tensor_7
#
# INFO:nncf:Not adding activation input quantizer for operation: 198 linear_8
# INFO:nncf:Not adding activation input quantizer for operation: 201 linear_9
# INFO:nncf:Not adding activation input quantizer for operation: 204 linear_10
# INFO:nncf:Not adding activation input quantizer for operation: 217 linear_11
# 219 add_tensor_8
# 221 div_5
#
# INFO:nncf:Not adding activation input quantizer for operation: 228 linear_12
# INFO:nncf:Not adding activation input quantizer for operation: 247 linear_15
# 249 add_tensor_9
# 251 div_6
#
# INFO:nncf:Not adding activation input quantizer for operation: 258 linear_16
# 260 add_tensor_10
#
# INFO:nncf:Not adding activation input quantizer for operation: 269 linear_17
# 271 add_tensor_11
#
# INFO:nncf:Not adding activation input quantizer for operation: 278 linear_18
# INFO:nncf:Not adding activation input quantizer for operation: 281 linear_19
# INFO:nncf:Not adding activation input quantizer for operation: 284 linear_20
# INFO:nncf:Not adding activation input quantizer for operation: 297 linear_21
# 299 add_tensor_12
# 301 div_7
#
# INFO:nncf:Not adding activation input quantizer for operation: 308 linear_22
# INFO:nncf:Not adding activation input quantizer for operation: 327 linear_25
# 329 add_tensor_13
# 331 div_8
#
# INFO:nncf:Not adding activation input quantizer for operation: 338 linear_26
# 340 add_tensor_14
#
# INFO:nncf:Not adding activation input quantizer for operation: 349 linear_27
# 351 add_tensor_15
#
# INFO:nncf:Not adding activation input quantizer for operation: 355 linear_28
# 357 add_tensor_16
#
# INFO:nncf:Not adding activation input quantizer for operation: 400 linear_30
# 402 add_tensor_18
#
# INFO:nncf:Not adding activation input quantizer for operation: 408 linear_31
# INFO:nncf:Not adding activation input quantizer for operation: 411 linear_32
# INFO:nncf:Not adding activation input quantizer for operation: 414 linear_33
# INFO:nncf:Not adding activation input quantizer for operation: 427 linear_34
# 429 add_tensor_19
# 431 div_10
#
# INFO:nncf:Not adding activation input quantizer for operation: 438 linear_35
# INFO:nncf:Not adding activation input quantizer for operation: 457 linear_38
# 459 add_tensor_20
# 461 div_11
#
# INFO:nncf:Not adding activation input quantizer for operation: 468 linear_39
# 470 add_tensor_21
#
# INFO:nncf:Not adding activation input quantizer for operation: 479 linear_40
# 481 add_tensor_22
#
# INFO:nncf:Not adding activation input quantizer for operation: 488 linear_41
# INFO:nncf:Not adding activation input quantizer for operation: 491 linear_42
# INFO:nncf:Not adding activation input quantizer for operation: 494 linear_43
# INFO:nncf:Not adding activation input quantizer for operation: 507 linear_44
# 509 add_tensor_23
# 511 div_12
#
# INFO:nncf:Not adding activation input quantizer for operation: 518 linear_45
# INFO:nncf:Not adding activation input quantizer for operation: 537 linear_48
# 539 add_tensor_24
# 541 div_13
#
# INFO:nncf:Not adding activation input quantizer for operation: 548 linear_49
# 550 add_tensor_25
#
# INFO:nncf:Not adding activation input quantizer for operation: 559 linear_50
# 561 add_tensor_26
#
# INFO:nncf:Not adding activation input quantizer for operation: 565 linear_51
# 567 add_tensor_27
#
# INFO:nncf:Not adding activation input quantizer for operation: 620 linear_53
# 622 add_tensor_29
#
# INFO:nncf:Not adding activation input quantizer for operation: 628 linear_54
# INFO:nncf:Not adding activation input quantizer for operation: 631 linear_55
# INFO:nncf:Not adding activation input quantizer for operation: 634 linear_56
# INFO:nncf:Not adding activation input quantizer for operation: 647 linear_57
# 649 add_tensor_30
# 651 div_15
#
# INFO:nncf:Not adding activation input quantizer for operation: 658 linear_58
# INFO:nncf:Not adding activation input quantizer for operation: 677 linear_61
# 679 add_tensor_31
# 681 div_16
#
# INFO:nncf:Not adding activation input quantizer for operation: 688 linear_62
# 690 add_tensor_32
#
# INFO:nncf:Not adding activation input quantizer for operation: 699 linear_63
# 701 add_tensor_33
#
# INFO:nncf:Not adding activation input quantizer for operation: 708 linear_64
# INFO:nncf:Not adding activation input quantizer for operation: 711 linear_65
# INFO:nncf:Not adding activation input quantizer for operation: 714 linear_66
# INFO:nncf:Not adding activation input quantizer for operation: 727 linear_67
# 729 add_tensor_34
# 731 div_17
#
# INFO:nncf:Not adding activation input quantizer for operation: 738 linear_68
# INFO:nncf:Not adding activation input quantizer for operation: 757 linear_71
# 759 add_tensor_35
# 761 div_18
#
# INFO:nncf:Not adding activation input quantizer for operation: 768 linear_72
# 770 add_tensor_36
#
# INFO:nncf:Not adding activation input quantizer for operation: 779 linear_73
# 781 add_tensor_37
#
# INFO:nncf:Not adding activation input quantizer for operation: 788 linear_74
# INFO:nncf:Not adding activation input quantizer for operation: 791 linear_75
# INFO:nncf:Not adding activation input quantizer for operation: 794 linear_76
# INFO:nncf:Not adding activation input quantizer for operation: 807 linear_77
# 809 add_tensor_38
# 811 div_19
#
# INFO:nncf:Not adding activation input quantizer for operation: 818 linear_78
# INFO:nncf:Not adding activation input quantizer for operation: 837 linear_81
# 839 add_tensor_39
# 841 div_20
#
# INFO:nncf:Not adding activation input quantizer for operation: 848 linear_82
# 850 add_tensor_40
#
# INFO:nncf:Not adding activation input quantizer for operation: 859 linear_83
# 861 add_tensor_41
#
# INFO:nncf:Not adding activation input quantizer for operation: 868 linear_84
# INFO:nncf:Not adding activation input quantizer for operation: 871 linear_85
# INFO:nncf:Not adding activation input quantizer for operation: 874 linear_86
# INFO:nncf:Not adding activation input quantizer for operation: 887 linear_87
# 889 add_tensor_42
# 891 div_21
#
# INFO:nncf:Not adding activation input quantizer for operation: 898 linear_88
# INFO:nncf:Not adding activation input quantizer for operation: 917 linear_91
# 919 add_tensor_43
# 921 div_22
#
# INFO:nncf:Not adding activation input quantizer for operation: 928 linear_92
# 930 add_tensor_44
#
# INFO:nncf:Not adding activation input quantizer for operation: 939 linear_93
# 941 add_tensor_45
#
# INFO:nncf:Not adding activation input quantizer for operation: 948 linear_94
# INFO:nncf:Not adding activation input quantizer for operation: 951 linear_95
# INFO:nncf:Not adding activation input quantizer for operation: 954 linear_96
# INFO:nncf:Not adding activation input quantizer for operation: 967 linear_97
# 969 add_tensor_46
# 971 div_23
#
# INFO:nncf:Not adding activation input quantizer for operation: 978 linear_98
# INFO:nncf:Not adding activation input quantizer for operation: 997 linear_101
# 999 add_tensor_47
# 1001 div_24
#
# INFO:nncf:Not adding activation input quantizer for operation: 1008 linear_102
# 1010 add_tensor_48
#
# INFO:nncf:Not adding activation input quantizer for operation: 1019 linear_103
# 1021 add_tensor_49
#
# INFO:nncf:Not adding activation input quantizer for operation: 1028 linear_104
# INFO:nncf:Not adding activation input quantizer for operation: 1031 linear_105
# INFO:nncf:Not adding activation input quantizer for operation: 1034 linear_106
# INFO:nncf:Not adding activation input quantizer for operation: 1047 linear_107
# 1049 add_tensor_50
# 1051 div_25
#
# INFO:nncf:Not adding activation input quantizer for operation: 1058 linear_108
# INFO:nncf:Not adding activation input quantizer for operation: 1077 linear_111
# 1079 add_tensor_51
# 1081 div_26
#
# INFO:nncf:Not adding activation input quantizer for operation: 1088 linear_112
# 1090 add_tensor_52
#
# INFO:nncf:Not adding activation input quantizer for operation: 1099 linear_113
# 1101 add_tensor_53
#
# INFO:nncf:Not adding activation input quantizer for operation: 1108 linear_114
# INFO:nncf:Not adding activation input quantizer for operation: 1111 linear_115
# INFO:nncf:Not adding activation input quantizer for operation: 1114 linear_116
# INFO:nncf:Not adding activation input quantizer for operation: 1127 linear_117
# 1129 add_tensor_54
# 1131 div_27
#
# INFO:nncf:Not adding activation input quantizer for operation: 1138 linear_118
# INFO:nncf:Not adding activation input quantizer for operation: 1157 linear_121
# 1159 add_tensor_55
# 1161 div_28
#
# INFO:nncf:Not adding activation input quantizer for operation: 1168 linear_122
# 1170 add_tensor_56
#
# INFO:nncf:Not adding activation input quantizer for operation: 1179 linear_123
# 1181 add_tensor_57
#
# INFO:nncf:Not adding activation input quantizer for operation: 1188 linear_124
# INFO:nncf:Not adding activation input quantizer for operation: 1191 linear_125
# INFO:nncf:Not adding activation input quantizer for operation: 1194 linear_126
# INFO:nncf:Not adding activation input quantizer for operation: 1207 linear_127
# 1209 add_tensor_58
# 1211 div_29
#
# INFO:nncf:Not adding activation input quantizer for operation: 1218 linear_128
# INFO:nncf:Not adding activation input quantizer for operation: 1237 linear_131
# 1239 add_tensor_59
# 1241 div_30
#
# INFO:nncf:Not adding activation input quantizer for operation: 1248 linear_132
# 1250 add_tensor_60
#
# INFO:nncf:Not adding activation input quantizer for operation: 1259 linear_133
# 1261 add_tensor_61
#
# INFO:nncf:Not adding activation input quantizer for operation: 1268 linear_134
# INFO:nncf:Not adding activation input quantizer for operation: 1271 linear_135
# INFO:nncf:Not adding activation input quantizer for operation: 1274 linear_136
# INFO:nncf:Not adding activation input quantizer for operation: 1287 linear_137
# 1289 add_tensor_62
# 1291 div_31
#
# INFO:nncf:Not adding activation input quantizer for operation: 1298 linear_138
# INFO:nncf:Not adding activation input quantizer for operation: 1317 linear_141
# 1319 add_tensor_63
# 1321 div_32
#
# INFO:nncf:Not adding activation input quantizer for operation: 1328 linear_142
# 1330 add_tensor_64
#
# INFO:nncf:Not adding activation input quantizer for operation: 1339 linear_143
# 1341 add_tensor_65
#
# INFO:nncf:Not adding activation input quantizer for operation: 1348 linear_144
# INFO:nncf:Not adding activation input quantizer for operation: 1351 linear_145
# INFO:nncf:Not adding activation input quantizer for operation: 1354 linear_146
# INFO:nncf:Not adding activation input quantizer for operation: 1367 linear_147
# 1369 add_tensor_66
# 1371 div_33
#
# INFO:nncf:Not adding activation input quantizer for operation: 1378 linear_148
# INFO:nncf:Not adding activation input quantizer for operation: 1397 linear_151
# 1399 add_tensor_67
# 1401 div_34
#
# INFO:nncf:Not adding activation input quantizer for operation: 1408 linear_152
# 1410 add_tensor_68
#
# INFO:nncf:Not adding activation input quantizer for operation: 1419 linear_153
# 1421 add_tensor_69
#
# INFO:nncf:Not adding activation input quantizer for operation: 1425 linear_154
# 1427 add_tensor_70
#
# INFO:nncf:Not adding activation input quantizer for operation: 1470 linear_156
# 1472 add_tensor_72
#
# INFO:nncf:Not adding activation input quantizer for operation: 1478 linear_157
# INFO:nncf:Not adding activation input quantizer for operation: 1481 linear_158
# INFO:nncf:Not adding activation input quantizer for operation: 1484 linear_159
# INFO:nncf:Not adding activation input quantizer for operation: 1497 linear_160
# 1499 add_tensor_73
# 1501 div_36
#
# INFO:nncf:Not adding activation input quantizer for operation: 1508 linear_161
# INFO:nncf:Not adding activation input quantizer for operation: 1527 linear_164
# 1529 add_tensor_74
# 1531 div_37
#
# INFO:nncf:Not adding activation input quantizer for operation: 1538 linear_165
# 1540 add_tensor_75
#
# INFO:nncf:Not adding activation input quantizer for operation: 1549 linear_166
# 1551 add_tensor_76
#
# INFO:nncf:Not adding activation input quantizer for operation: 1558 linear_167
# INFO:nncf:Not adding activation input quantizer for operation: 1561 linear_168
# INFO:nncf:Not adding activation input quantizer for operation: 1564 linear_169
# INFO:nncf:Not adding activation input quantizer for operation: 1577 linear_170
# 1579 add_tensor_77
# 1581 div_38
#
# INFO:nncf:Not adding activation input quantizer for operation: 1588 linear_171
# INFO:nncf:Not adding activation input quantizer for operation: 1607 linear_174
# 1609 add_tensor_78
# 1611 div_39
#
# INFO:nncf:Not adding activation input quantizer for operation: 1618 linear_175
# 1620 add_tensor_79
#
# INFO:nncf:Not adding activation input quantizer for operation: 1629 linear_176
# 1631 add_tensor_80
#
# INFO:nncf:Not adding activation input quantizer for operation: 1638 linear_177
# INFO:nncf:Not adding activation input quantizer for operation: 1641 linear_178
# INFO:nncf:Not adding activation input quantizer for operation: 1644 linear_179
# INFO:nncf:Not adding activation input quantizer for operation: 1657 linear_180
# 1659 add_tensor_81
# 1661 div_40
#
# INFO:nncf:Not adding activation input quantizer for operation: 1668 linear_181
# INFO:nncf:Not adding activation input quantizer for operation: 1687 linear_184
# 1689 add_tensor_82
# 1691 div_41
#
# INFO:nncf:Not adding activation input quantizer for operation: 1698 linear_185
# 1700 add_tensor_83
#
# INFO:nncf:Not adding activation input quantizer for operation: 1709 linear_186
# 1711 add_tensor_84
#
# INFO:nncf:Not adding activation input quantizer for operation: 1718 linear_187
# INFO:nncf:Not adding activation input quantizer for operation: 1721 linear_188
# INFO:nncf:Not adding activation input quantizer for operation: 1724 linear_189
# INFO:nncf:Not adding activation input quantizer for operation: 1737 linear_190
# 1739 add_tensor_85
# 1741 div_42
#
# INFO:nncf:Not adding activation input quantizer for operation: 1748 linear_191
# INFO:nncf:Not adding activation input quantizer for operation: 1767 linear_194
# 1769 add_tensor_86
# 1771 div_43
#
# INFO:nncf:Not adding activation input quantizer for operation: 1778 linear_195
# 1780 add_tensor_87
#
# INFO:nncf:Not adding activation input quantizer for operation: 1789 linear_196
# 1791 add_tensor_88
#
# INFO:nncf:Not adding activation input quantizer for operation: 1798 linear_197
# INFO:nncf:Not adding activation input quantizer for operation: 1801 linear_198
# INFO:nncf:Not adding activation input quantizer for operation: 1804 linear_199
# INFO:nncf:Not adding activation input quantizer for operation: 1817 linear_200
# 1819 add_tensor_89
# 1821 div_44
#
# INFO:nncf:Not adding activation input quantizer for operation: 1828 linear_201
# INFO:nncf:Not adding activation input quantizer for operation: 1847 linear_204
# 1849 add_tensor_90
# 1851 div_45
#
# INFO:nncf:Not adding activation input quantizer for operation: 1858 linear_205
# 1860 add_tensor_91
#
# INFO:nncf:Not adding activation input quantizer for operation: 1869 linear_206
# 1871 add_tensor_92
#
# INFO:nncf:Not adding activation input quantizer for operation: 1878 linear_207
# INFO:nncf:Not adding activation input quantizer for operation: 1881 linear_208
# INFO:nncf:Not adding activation input quantizer for operation: 1884 linear_209
# INFO:nncf:Not adding activation input quantizer for operation: 1897 linear_210
# 1899 add_tensor_93
# 1901 div_46
#
# INFO:nncf:Not adding activation input quantizer for operation: 1908 linear_211
# INFO:nncf:Not adding activation input quantizer for operation: 1927 linear_214
# 1929 add_tensor_94
# 1931 div_47
#
# INFO:nncf:Not adding activation input quantizer for operation: 1938 linear_215
# 1940 add_tensor_95
#
# INFO:nncf:Not adding activation input quantizer for operation: 1949 linear_216
# 1951 add_tensor_96
#
# INFO:nncf:Not adding activation input quantizer for operation: 1958 linear_217
# INFO:nncf:Not adding activation input quantizer for operation: 1961 linear_218
# INFO:nncf:Not adding activation input quantizer for operation: 1964 linear_219
# INFO:nncf:Not adding activation input quantizer for operation: 1977 linear_220
# 1979 add_tensor_97
# 1981 div_48
#
# INFO:nncf:Not adding activation input quantizer for operation: 1988 linear_221
# INFO:nncf:Not adding activation input quantizer for operation: 2007 linear_224
# 2009 add_tensor_98
# 2011 div_49
#
# INFO:nncf:Not adding activation input quantizer for operation: 2018 linear_225
# 2020 add_tensor_99
#
# INFO:nncf:Not adding activation input quantizer for operation: 2029 linear_226
# 2031 add_tensor_100
#
# INFO:nncf:Not adding activation input quantizer for operation: 2038 linear_227
# INFO:nncf:Not adding activation input quantizer for operation: 2041 linear_228
# INFO:nncf:Not adding activation input quantizer for operation: 2044 linear_229
# INFO:nncf:Not adding activation input quantizer for operation: 2057 linear_230
# 2059 add_tensor_101
# 2061 div_50
#
# INFO:nncf:Not adding activation input quantizer for operation: 2068 linear_231
# INFO:nncf:Not adding activation input quantizer for operation: 2087 linear_234
# 2089 add_tensor_102
# 2091 div_51
#
# INFO:nncf:Not adding activation input quantizer for operation: 2098 linear_235
# 2100 add_tensor_103
#
# INFO:nncf:Not adding activation input quantizer for operation: 2109 linear_236
# 2111 add_tensor_104
#
# INFO:nncf:Not adding activation input quantizer for operation: 2118 linear_237
# INFO:nncf:Not adding activation input quantizer for operation: 2121 linear_238
# INFO:nncf:Not adding activation input quantizer for operation: 2124 linear_239
# INFO:nncf:Not adding activation input quantizer for operation: 2137 linear_240
# 2139 add_tensor_105
# 2141 div_52
#
# INFO:nncf:Not adding activation input quantizer for operation: 2148 linear_241
# INFO:nncf:Not adding activation input quantizer for operation: 2167 linear_244
# 2169 add_tensor_106
# 2171 div_53
#
# INFO:nncf:Not adding activation input quantizer for operation: 2178 linear_245
# 2180 add_tensor_107
#
# INFO:nncf:Not adding activation input quantizer for operation: 2189 linear_246
# 2191 add_tensor_108
#
# INFO:nncf:Not adding activation input quantizer for operation: 2198 linear_247
# INFO:nncf:Not adding activation input quantizer for operation: 2201 linear_248
# INFO:nncf:Not adding activation input quantizer for operation: 2204 linear_249
# INFO:nncf:Not adding activation input quantizer for operation: 2217 linear_250
# 2219 add_tensor_109
# 2221 div_54
#
# INFO:nncf:Not adding activation input quantizer for operation: 2228 linear_251
# INFO:nncf:Not adding activation input quantizer for operation: 2247 linear_254
# 2249 add_tensor_110
# 2251 div_55
#
# INFO:nncf:Not adding activation input quantizer for operation: 2258 linear_255
# 2260 add_tensor_111
#
# INFO:nncf:Not adding activation input quantizer for operation: 2269 linear_256
# 2271 add_tensor_112
#
# INFO:nncf:Not adding activation input quantizer for operation: 2275 linear_257
# 2277 add_tensor_113
#
# INFO:nncf:Not adding activation input quantizer for operation: 2320 linear_259
# 2322 add_tensor_115
#
# INFO:nncf:Not adding activation input quantizer for operation: 2328 linear_260
# INFO:nncf:Not adding activation input quantizer for operation: 2331 linear_261
# INFO:nncf:Not adding activation input quantizer for operation: 2334 linear_262
# INFO:nncf:Not adding activation input quantizer for operation: 2347 linear_263
# 2349 add_tensor_116
# 2351 div_57
#
# INFO:nncf:Not adding activation input quantizer for operation: 2358 linear_264
# INFO:nncf:Not adding activation input quantizer for operation: 2377 linear_267
# 2379 add_tensor_117
# 2381 div_58
#
# INFO:nncf:Not adding activation input quantizer for operation: 2388 linear_268
# 2390 add_tensor_118
#
# INFO:nncf:Not adding activation input quantizer for operation: 2399 linear_269
# 2401 add_tensor_119
#
# INFO:nncf:Not adding activation input quantizer for operation: 2408 linear_270
# INFO:nncf:Not adding activation input quantizer for operation: 2411 linear_271
# INFO:nncf:Not adding activation input quantizer for operation: 2414 linear_272
# INFO:nncf:Not adding activation input quantizer for operation: 2427 linear_273
# 2429 add_tensor_120
# 2431 div_59
#
# INFO:nncf:Not adding activation input quantizer for operation: 2438 linear_274
# INFO:nncf:Not adding activation input quantizer for operation: 2457 linear_277
# 2459 add_tensor_121
# 2461 div_60
#
# INFO:nncf:Not adding activation input quantizer for operation: 2468 linear_278
# 2470 add_tensor_122
#
# INFO:nncf:Not adding activation input quantizer for operation: 2479 linear_279
# 2481 add_tensor_123
#
# INFO:nncf:Not adding activation input quantizer for operation: 2488 linear_280
# INFO:nncf:Not adding activation input quantizer for operation: 2491 linear_281
# INFO:nncf:Not adding activation input quantizer for operation: 2494 linear_282
# INFO:nncf:Not adding activation input quantizer for operation: 2507 linear_283
# 2509 add_tensor_124
# 2511 div_61
#
# INFO:nncf:Not adding activation input quantizer for operation: 2518 linear_284
# INFO:nncf:Not adding activation input quantizer for operation: 2537 linear_287
# 2539 add_tensor_125
# 2541 div_62
#
# INFO:nncf:Not adding activation input quantizer for operation: 2548 linear_288
# 2550 add_tensor_126
#
# INFO:nncf:Not adding activation input quantizer for operation: 2559 linear_289
# 2561 add_tensor_127
#
# INFO:nncf:Not adding activation input quantizer for operation: 2568 linear_290
# INFO:nncf:Not adding activation input quantizer for operation: 2571 linear_291
# INFO:nncf:Not adding activation input quantizer for operation: 2574 linear_292
# INFO:nncf:Not adding activation input quantizer for operation: 2587 linear_293
# 2589 add_tensor_128
# 2591 div_63
#
# INFO:nncf:Not adding activation input quantizer for operation: 2598 linear_294
# INFO:nncf:Not adding activation input quantizer for operation: 2617 linear_297
# 2619 add_tensor_129
# 2621 div_64
#
# INFO:nncf:Not adding activation input quantizer for operation: 2628 linear_298
# 2630 add_tensor_130
#
# INFO:nncf:Not adding activation input quantizer for operation: 2639 linear_299
# 2641 add_tensor_131
#
# INFO:nncf:Not adding activation input quantizer for operation: 2648 linear_300
# INFO:nncf:Not adding activation input quantizer for operation: 2651 linear_301
# INFO:nncf:Not adding activation input quantizer for operation: 2654 linear_302
# INFO:nncf:Not adding activation input quantizer for operation: 2667 linear_303
# 2669 add_tensor_132
# 2671 div_65
#
# INFO:nncf:Not adding activation input quantizer for operation: 2678 linear_304
# INFO:nncf:Not adding activation input quantizer for operation: 2697 linear_307
# 2699 add_tensor_133
# 2701 div_66
#
# INFO:nncf:Not adding activation input quantizer for operation: 2708 linear_308
# 2710 add_tensor_134
#
# INFO:nncf:Not adding activation input quantizer for operation: 2719 linear_309
# 2721 add_tensor_135
#
# INFO:nncf:Not adding activation input quantizer for operation: 2728 linear_310
# INFO:nncf:Not adding activation input quantizer for operation: 2731 linear_311
# INFO:nncf:Not adding activation input quantizer for operation: 2734 linear_312
# INFO:nncf:Not adding activation input quantizer for operation: 2747 linear_313
# 2749 add_tensor_136
# 2751 div_67
#
# INFO:nncf:Not adding activation input quantizer for operation: 2758 linear_314
# INFO:nncf:Not adding activation input quantizer for operation: 2777 linear_317
# 2779 add_tensor_137
# 2781 div_68
#
# INFO:nncf:Not adding activation input quantizer for operation: 2788 linear_318
# 2790 add_tensor_138
#
# INFO:nncf:Not adding activation input quantizer for operation: 2799 linear_319
# 2801 add_tensor_139
#
# INFO:nncf:Not adding activation input quantizer for operation: 2808 linear_320
# INFO:nncf:Not adding activation input quantizer for operation: 2811 linear_321
# INFO:nncf:Not adding activation input quantizer for operation: 2814 linear_322
# INFO:nncf:Not adding activation input quantizer for operation: 2827 linear_323
# 2829 add_tensor_140
# 2831 div_69
#
# INFO:nncf:Not adding activation input quantizer for operation: 2838 linear_324
# INFO:nncf:Not adding activation input quantizer for operation: 2857 linear_327
# 2859 add_tensor_141
# 2861 div_70
#
# INFO:nncf:Not adding activation input quantizer for operation: 2868 linear_328
# 2870 add_tensor_142
#
# INFO:nncf:Not adding activation input quantizer for operation: 2879 linear_329
# 2881 add_tensor_143
#
# INFO:nncf:Not adding activation input quantizer for operation: 2888 linear_330
# INFO:nncf:Not adding activation input quantizer for operation: 2891 linear_331
# INFO:nncf:Not adding activation input quantizer for operation: 2894 linear_332
# INFO:nncf:Not adding activation input quantizer for operation: 2907 linear_333
# 2909 add_tensor_144
# 2911 div_71
#
# INFO:nncf:Not adding activation input quantizer for operation: 2918 linear_334
# INFO:nncf:Not adding activation input quantizer for operation: 2937 linear_337
# 2939 add_tensor_145
# 2941 div_72
#
# INFO:nncf:Not adding activation input quantizer for operation: 2948 linear_338
# 2950 add_tensor_146
#
# INFO:nncf:Not adding activation input quantizer for operation: 2959 linear_339
# 2961 add_tensor_147
#
# INFO:nncf:Not adding activation input quantizer for operation: 2968 linear_340
# INFO:nncf:Not adding activation input quantizer for operation: 2971 linear_341
# INFO:nncf:Not adding activation input quantizer for operation: 2974 linear_342
# INFO:nncf:Not adding activation input quantizer for operation: 2987 linear_343
# 2989 add_tensor_148
# 2991 div_73
#
# INFO:nncf:Not adding activation input quantizer for operation: 2998 linear_344
# INFO:nncf:Not adding activation input quantizer for operation: 3017 linear_347
# 3019 add_tensor_149
# 3021 div_74
#
# INFO:nncf:Not adding activation input quantizer for operation: 3028 linear_348
# 3030 add_tensor_150
#
# INFO:nncf:Not adding activation input quantizer for operation: 3039 linear_349
# 3041 add_tensor_151
#
# INFO:nncf:Not adding activation input quantizer for operation: 3048 linear_350
# INFO:nncf:Not adding activation input quantizer for operation: 3051 linear_351
# INFO:nncf:Not adding activation input quantizer for operation: 3054 linear_352
# INFO:nncf:Not adding activation input quantizer for operation: 3067 linear_353
# 3069 add_tensor_152
# 3071 div_75
#
# INFO:nncf:Not adding activation input quantizer for operation: 3078 linear_354
# INFO:nncf:Not adding activation input quantizer for operation: 3097 linear_357
# 3099 add_tensor_153
# 3101 div_76
#
# INFO:nncf:Not adding activation input quantizer for operation: 3108 linear_358
# 3110 add_tensor_154
#
# INFO:nncf:Not adding activation input quantizer for operation: 3119 linear_359
# 3121 add_tensor_155
#
# INFO:nncf:Not adding activation input quantizer for operation: 3125 linear_360
# 3127 add_tensor_156
#
# INFO:nncf:Not adding activation input quantizer for operation: 3207 linear_363
# 3209 add_tensor_159
#
# INFO:nncf:Not adding activation input quantizer for operation: 3215 linear_364
# INFO:nncf:Not adding activation input quantizer for operation: 3218 linear_365
# INFO:nncf:Not adding activation input quantizer for operation: 3221 linear_366
# INFO:nncf:Not adding activation input quantizer for operation: 3234 linear_367
# 3236 add_tensor_160
# 3238 div_79
#
# INFO:nncf:Not adding activation input quantizer for operation: 3245 linear_368
# INFO:nncf:Not adding activation input quantizer for operation: 3264 linear_371
# 3266 add_tensor_161
# 3268 div_80
#
# INFO:nncf:Not adding activation input quantizer for operation: 3275 linear_372
# 3277 add_tensor_162
#
# INFO:nncf:Not adding activation input quantizer for operation: 3286 linear_373
# 3288 add_tensor_163
#
# INFO:nncf:Not adding activation input quantizer for operation: 3295 linear_374
# INFO:nncf:Not adding activation input quantizer for operation: 3298 linear_375
# INFO:nncf:Not adding activation input quantizer for operation: 3301 linear_376
# INFO:nncf:Not adding activation input quantizer for operation: 3314 linear_377
# 3316 add_tensor_164
# 3318 div_81
#
# INFO:nncf:Not adding activation input quantizer for operation: 3325 linear_378
# INFO:nncf:Not adding activation input quantizer for operation: 3344 linear_381
# 3346 add_tensor_165
# 3348 div_82
#
# INFO:nncf:Not adding activation input quantizer for operation: 3355 linear_382
# 3357 add_tensor_166
#
# INFO:nncf:Not adding activation input quantizer for operation: 3366 linear_383
# 3368 add_tensor_167
#
# INFO:nncf:Not adding activation input quantizer for operation: 3375 linear_384
# INFO:nncf:Not adding activation input quantizer for operation: 3378 linear_385
# INFO:nncf:Not adding activation input quantizer for operation: 3381 linear_386
# INFO:nncf:Not adding activation input quantizer for operation: 3394 linear_387
# 3396 add_tensor_168
# 3398 div_83
#
# INFO:nncf:Not adding activation input quantizer for operation: 3405 linear_388
# INFO:nncf:Not adding activation input quantizer for operation: 3424 linear_391
# 3426 add_tensor_169
# 3428 div_84
#
# INFO:nncf:Not adding activation input quantizer for operation: 3435 linear_392
# 3437 add_tensor_170
#
# INFO:nncf:Not adding activation input quantizer for operation: 3446 linear_393
# 3448 add_tensor_171
#
# INFO:nncf:Not adding activation input quantizer for operation: 3455 linear_394
# INFO:nncf:Not adding activation input quantizer for operation: 3458 linear_395
# INFO:nncf:Not adding activation input quantizer for operation: 3461 linear_396
# INFO:nncf:Not adding activation input quantizer for operation: 3474 linear_397
# 3476 add_tensor_172
# 3478 div_85
#
# INFO:nncf:Not adding activation input quantizer for operation: 3485 linear_398
# INFO:nncf:Not adding activation input quantizer for operation: 3504 linear_401
# 3506 add_tensor_173
# 3508 div_86
#
# INFO:nncf:Not adding activation input quantizer for operation: 3515 linear_402
# 3517 add_tensor_174
#
# INFO:nncf:Not adding activation input quantizer for operation: 3526 linear_403
# 3528 add_tensor_175
#
# INFO:nncf:Not adding activation input quantizer for operation: 3535 linear_404
# INFO:nncf:Not adding activation input quantizer for operation: 3538 linear_405
# INFO:nncf:Not adding activation input quantizer for operation: 3541 linear_406
# INFO:nncf:Not adding activation input quantizer for operation: 3554 linear_407
# 3556 add_tensor_176
# 3558 div_87
#
# INFO:nncf:Not adding activation input quantizer for operation: 3565 linear_408
# INFO:nncf:Not adding activation input quantizer for operation: 3584 linear_411
# 3586 add_tensor_177
# 3588 div_88
#
# INFO:nncf:Not adding activation input quantizer for operation: 3595 linear_412
# 3597 add_tensor_178
#
# INFO:nncf:Not adding activation input quantizer for operation: 3606 linear_413
# 3608 add_tensor_179
#
# INFO:nncf:Not adding activation input quantizer for operation: 3615 linear_414
# INFO:nncf:Not adding activation input quantizer for operation: 3618 linear_415
# INFO:nncf:Not adding activation input quantizer for operation: 3621 linear_416
# INFO:nncf:Not adding activation input quantizer for operation: 3634 linear_417
# 3636 add_tensor_180
# 3638 div_89
#
# INFO:nncf:Not adding activation input quantizer for operation: 3645 linear_418
# INFO:nncf:Not adding activation input quantizer for operation: 3664 linear_421
# 3666 add_tensor_181
# 3668 div_90
#
# INFO:nncf:Not adding activation input quantizer for operation: 3675 linear_422
# 3677 add_tensor_182
#
# INFO:nncf:Not adding activation input quantizer for operation: 3686 linear_423
# 3688 add_tensor_183
#
# INFO:nncf:Not adding activation input quantizer for operation: 3695 linear_424
# INFO:nncf:Not adding activation input quantizer for operation: 3698 linear_425
# INFO:nncf:Not adding activation input quantizer for operation: 3701 linear_426
# INFO:nncf:Not adding activation input quantizer for operation: 3714 linear_427
# 3716 add_tensor_184
# 3718 div_91
#
# INFO:nncf:Not adding activation input quantizer for operation: 3725 linear_428
# INFO:nncf:Not adding activation input quantizer for operation: 3744 linear_431
# 3746 add_tensor_185
# 3748 div_92
#
# INFO:nncf:Not adding activation input quantizer for operation: 3755 linear_432
# 3757 add_tensor_186
#
# INFO:nncf:Not adding activation input quantizer for operation: 3766 linear_433
# 3768 add_tensor_187
#
# INFO:nncf:Not adding activation input quantizer for operation: 3775 linear_434
# INFO:nncf:Not adding activation input quantizer for operation: 3778 linear_435
# INFO:nncf:Not adding activation input quantizer for operation: 3781 linear_436
# INFO:nncf:Not adding activation input quantizer for operation: 3794 linear_437
# 3796 add_tensor_188
# 3798 div_93
#
# INFO:nncf:Not adding activation input quantizer for operation: 3805 linear_438
# INFO:nncf:Not adding activation input quantizer for operation: 3824 linear_441
# 3826 add_tensor_189
# 3828 div_94
#
# INFO:nncf:Not adding activation input quantizer for operation: 3835 linear_442
# 3837 add_tensor_190
#
# INFO:nncf:Not adding activation input quantizer for operation: 3846 linear_443
# 3848 add_tensor_191
#
# INFO:nncf:Not adding activation input quantizer for operation: 3855 linear_444
# INFO:nncf:Not adding activation input quantizer for operation: 3858 linear_445
# INFO:nncf:Not adding activation input quantizer for operation: 3861 linear_446
# INFO:nncf:Not adding activation input quantizer for operation: 3874 linear_447
# 3876 add_tensor_192
# 3878 div_95
#
# INFO:nncf:Not adding activation input quantizer for operation: 3885 linear_448
# INFO:nncf:Not adding activation input quantizer for operation: 3904 linear_451
# 3906 add_tensor_193
# 3908 div_96
#
# INFO:nncf:Not adding activation input quantizer for operation: 3915 linear_452
# 3917 add_tensor_194
#
# INFO:nncf:Not adding activation input quantizer for operation: 3926 linear_453
# 3928 add_tensor_195
#
# INFO:nncf:Not adding activation input quantizer for operation: 3935 linear_454
# INFO:nncf:Not adding activation input quantizer for operation: 3938 linear_455
# INFO:nncf:Not adding activation input quantizer for operation: 3941 linear_456
# INFO:nncf:Not adding activation input quantizer for operation: 3954 linear_457
# 3956 add_tensor_196
# 3958 div_97
#
# INFO:nncf:Not adding activation input quantizer for operation: 3965 linear_458
# INFO:nncf:Not adding activation input quantizer for operation: 3984 linear_461
# 3986 add_tensor_197
# 3988 div_98
#
# INFO:nncf:Not adding activation input quantizer for operation: 3995 linear_462
# 3997 add_tensor_198
#
# INFO:nncf:Not adding activation input quantizer for operation: 4006 linear_463
# 4008 add_tensor_199
#
# INFO:nncf:Not adding activation input quantizer for operation: 4012 linear_464
# 4014 add_tensor_200
#
# INFO:nncf:Not adding activation input quantizer for operation: 4063 linear_466
# 4065 add_tensor_202
#
# INFO:nncf:Not adding activation input quantizer for operation: 4071 linear_467
# INFO:nncf:Not adding activation input quantizer for operation: 4074 linear_468
# INFO:nncf:Not adding activation input quantizer for operation: 4077 linear_469
# INFO:nncf:Not adding activation input quantizer for operation: 4090 linear_470
# 4092 add_tensor_203
# 4094 div_100
#
# INFO:nncf:Not adding activation input quantizer for operation: 4101 linear_471
# ...
# INFO:nncf:Not adding activation input quantizer for operation: 4554 linear_528
# INFO:nncf:Not adding activation input quantizer for operation: 4557 linear_529
# INFO:nncf:Not adding activation input quantizer for operation: 4570 linear_530
# 4572 add_tensor_227
# 4574 div_112
#
# INFO:nncf:Not adding activation input quantizer for operation: 4581 linear_531
# INFO:nncf:Not adding activation input quantizer for operation: 4600 linear_534
# 4602 add_tensor_228
# 4604 div_113
#
# INFO:nncf:Not adding activation input quantizer for operation: 4611 linear_535
# 4613 add_tensor_229
#
# INFO:nncf:Not adding activation input quantizer for operation: 4622 linear_536
# 4624 add_tensor_230
#
# INFO:nncf:Not adding activation input quantizer for operation: 4631 linear_537
# INFO:nncf:Not adding activation input quantizer for operation: 4634 linear_538
# INFO:nncf:Not adding activation input quantizer for operation: 4637 linear_539
# INFO:nncf:Not adding activation input quantizer for operation: 4650 linear_540
# 4652 add_tensor_231
# 4654 div_114
#
# INFO:nncf:Not adding activation input quantizer for operation: 4661 linear_541
# INFO:nncf:Not adding activation input quantizer for operation: 4680 linear_544
# 4682 add_tensor_232
# 4684 div_115
#
# INFO:nncf:Not adding activation input quantizer for operation: 4691 linear_545
# 4693 add_tensor_233
#
# INFO:nncf:Not adding activation input quantizer for operation: 4702 linear_546
# 4704 add_tensor_234
#
# INFO:nncf:Not adding activation input quantizer for operation: 4711 linear_547
# INFO:nncf:Not adding activation input quantizer for operation: 4714 linear_548
# INFO:nncf:Not adding activation input quantizer for operation: 4717 linear_549
# INFO:nncf:Not adding activation input quantizer for operation: 4730 linear_550
# 4732 add_tensor_235
# 4734 div_116
#
# INFO:nncf:Not adding activation input quantizer for operation: 4741 linear_551
# INFO:nncf:Not adding activation input quantizer for operation: 4760 linear_554
# 4762 add_tensor_236
# 4764 div_117
#
# INFO:nncf:Not adding activation input quantizer for operation: 4771 linear_555
# 4773 add_tensor_237
#
# INFO:nncf:Not adding activation input quantizer for operation: 4782 linear_556
# 4784 add_tensor_238
#
# INFO:nncf:Not adding activation input quantizer for operation: 4791 linear_557
# INFO:nncf:Not adding activation input quantizer for operation: 4794 linear_558
# INFO:nncf:Not adding activation input quantizer for operation: 4797 linear_559
# INFO:nncf:Not adding activation input quantizer for operation: 4810 linear_560
# 4812 add_tensor_239
# 4814 div_118
#
# INFO:nncf:Not adding activation input quantizer for operation: 4821 linear_561
# INFO:nncf:Not adding activation input quantizer for operation: 4840 linear_564
# 4842 add_tensor_240
# 4844 div_119
#
# INFO:nncf:Not adding activation input quantizer for operation: 4851 linear_565
# 4853 add_tensor_241
#
# INFO:nncf:Not adding activation input quantizer for operation: 4862 linear_566
# 4864 add_tensor_242
#
# INFO:nncf:Not adding activation input quantizer for operation: 4868 linear_567
# 4870 add_tensor_243
#
# INFO:nncf:Not adding activation input quantizer for operation: 4919 linear_569
# 4921 add_tensor_245
#
# INFO:nncf:Not adding activation input quantizer for operation: 4927 linear_570
# INFO:nncf:Not adding activation input quantizer for operation: 4930 linear_571
# INFO:nncf:Not adding activation input quantizer for operation: 4933 linear_572
# INFO:nncf:Not adding activation input quantizer for operation: 4946 linear_573
# 4948 add_tensor_246
# 4950 div_121
#
# INFO:nncf:Not adding activation input quantizer for operation: 4957 linear_574
# INFO:nncf:Not adding activation input quantizer for operation: 4976 linear_577
# 4978 add_tensor_247
# 4980 div_122
#
# INFO:nncf:Not adding activation input quantizer for operation: 4987 linear_578
# 4989 add_tensor_248
#
# INFO:nncf:Not adding activation input quantizer for operation: 4998 linear_579
# 5000 add_tensor_249
#
# INFO:nncf:Not adding activation input quantizer for operation: 5007 linear_580
# INFO:nncf:Not adding activation input quantizer for operation: 5010 linear_581
# INFO:nncf:Not adding activation input quantizer for operation: 5013 linear_582
# INFO:nncf:Not adding activation input quantizer for operation: 5026 linear_583
# 5028 add_tensor_250
# 5030 div_123
#
# INFO:nncf:Not adding activation input quantizer for operation: 5037 linear_584
# INFO:nncf:Not adding activation input quantizer for operation: 5056 linear_587
# 5058 add_tensor_251
# 5060 div_124
#
# INFO:nncf:Not adding activation input quantizer for operation: 5067 linear_588
# 5069 add_tensor_252
#
# INFO:nncf:Not adding activation input quantizer for operation: 5078 linear_589
# 5080 add_tensor_253
#
# INFO:nncf:Not adding activation input quantizer for operation: 5087 linear_590
# INFO:nncf:Not adding activation input quantizer for operation: 5090 linear_591
# INFO:nncf:Not adding activation input quantizer for operation: 5093 linear_592
# INFO:nncf:Not adding activation input quantizer for operation: 5106 linear_593
# 5108 add_tensor_254
# 5110 div_125
#
# INFO:nncf:Not adding activation input quantizer for operation: 5117 linear_594
# INFO:nncf:Not adding activation input quantizer for operation: 5136 linear_597
# 5138 add_tensor_255
# 5140 div_126
#
# INFO:nncf:Not adding activation input quantizer for operation: 5147 linear_598
# 5149 add_tensor_256
#
# INFO:nncf:Not adding activation input quantizer for operation: 5158 linear_599
# 5160 add_tensor_257
#
# INFO:nncf:Not adding activation input quantizer for operation: 5167 linear_600
# INFO:nncf:Not adding activation input quantizer for operation: 5170 linear_601
# INFO:nncf:Not adding activation input quantizer for operation: 5173 linear_602
# INFO:nncf:Not adding activation input quantizer for operation: 5186 linear_603
# 5188 add_tensor_258
# 5190 div_127
#
# INFO:nncf:Not adding activation input quantizer for operation: 5197 linear_604
# INFO:nncf:Not adding activation input quantizer for operation: 5216 linear_607
# 5218 add_tensor_259
# 5220 div_128
#
# INFO:nncf:Not adding activation input quantizer for operation: 5227 linear_608
# 5229 add_tensor_260
#
# INFO:nncf:Not adding activation input quantizer for operation: 5238 linear_609
# 5240 add_tensor_261
#
# INFO:nncf:Not adding activation input quantizer for operation: 5247 linear_610
# INFO:nncf:Not adding activation input quantizer for operation: 5250 linear_611
# INFO:nncf:Not adding activation input quantizer for operation: 5253 linear_612
# INFO:nncf:Not adding activation input quantizer for operation: 5266 linear_613
# 5268 add_tensor_262
# 5270 div_129
#
# INFO:nncf:Not adding activation input quantizer for operation: 5277 linear_614
# INFO:nncf:Not adding activation input quantizer for operation: 5296 linear_617
# 5298 add_tensor_263
# 5300 div_130
#
# INFO:nncf:Not adding activation input quantizer for operation: 5307 linear_618
# 5309 add_tensor_264
#
# INFO:nncf:Not adding activation input quantizer for operation: 5318 linear_619
# 5320 add_tensor_265
#
# INFO:nncf:Not adding activation input quantizer for operation: 5327 linear_620
# INFO:nncf:Not adding activation input quantizer for operation: 5330 linear_621
# INFO:nncf:Not adding activation input quantizer for operation: 5333 linear_622
# INFO:nncf:Not adding activation input quantizer for operation: 5346 linear_623
# 5348 add_tensor_266
# 5350 div_131
#
# INFO:nncf:Not adding activation input quantizer for operation: 5357 linear_624
# INFO:nncf:Not adding activation input quantizer for operation: 5376 linear_627
# 5378 add_tensor_267
# 5380 div_132
#
# INFO:nncf:Not adding activation input quantizer for operation: 5387 linear_628
# 5389 add_tensor_268
#
# INFO:nncf:Not adding activation input quantizer for operation: 5398 linear_629
# 5400 add_tensor_269
#
# INFO:nncf:Not adding activation input quantizer for operation: 5407 linear_630
# INFO:nncf:Not adding activation input quantizer for operation: 5410 linear_631
# INFO:nncf:Not adding activation input quantizer for operation: 5413 linear_632
# INFO:nncf:Not adding activation input quantizer for operation: 5426 linear_633
# 5428 add_tensor_270
# 5430 div_133
#
# INFO:nncf:Not adding activation input quantizer for operation: 5437 linear_634
# INFO:nncf:Not adding activation input quantizer for operation: 5456 linear_637
# 5458 add_tensor_271
# 5460 div_134
#
# INFO:nncf:Not adding activation input quantizer for operation: 5467 linear_638
# 5469 add_tensor_272
#
# INFO:nncf:Not adding activation input quantizer for operation: 5478 linear_639
# 5480 add_tensor_273
#
# INFO:nncf:Not adding activation input quantizer for operation: 5487 linear_640
# INFO:nncf:Not adding activation input quantizer for operation: 5490 linear_641
# INFO:nncf:Not adding activation input quantizer for operation: 5493 linear_642
# INFO:nncf:Not adding activation input quantizer for operation: 5506 linear_643
# 5508 add_tensor_274
# 5510 div_135
#
# INFO:nncf:Not adding activation input quantizer for operation: 5517 linear_644
# INFO:nncf:Not adding activation input quantizer for operation: 5536 linear_647
# 5538 add_tensor_275
# 5540 div_136
#
# INFO:nncf:Not adding activation input quantizer for operation: 5547 linear_648
# 5549 add_tensor_276
#
# INFO:nncf:Not adding activation input quantizer for operation: 5558 linear_649
# 5560 add_tensor_277
#
# INFO:nncf:Not adding activation input quantizer for operation: 5567 linear_650
# INFO:nncf:Not adding activation input quantizer for operation: 5570 linear_651
# INFO:nncf:Not adding activation input quantizer for operation: 5573 linear_652
# INFO:nncf:Not adding activation input quantizer for operation: 5586 linear_653
# 5588 add_tensor_278
# 5590 div_137
#
# INFO:nncf:Not adding activation input quantizer for operation: 5597 linear_654
# INFO:nncf:Not adding activation input quantizer for operation: 5616 linear_657
# 5618 add_tensor_279
# 5620 div_138
#
# INFO:nncf:Not adding activation input quantizer for operation: 5627 linear_658
# 5629 add_tensor_280
#
# INFO:nncf:Not adding activation input quantizer for operation: 5638 linear_659
# 5640 add_tensor_281
#
# INFO:nncf:Not adding activation input quantizer for operation: 5647 linear_660
# INFO:nncf:Not adding activation input quantizer for operation: 5650 linear_661
# INFO:nncf:Not adding activation input quantizer for operation: 5653 linear_662
# INFO:nncf:Not adding activation input quantizer for operation: 5666 linear_663
# 5668 add_tensor_282
# 5670 div_139
#
# INFO:nncf:Not adding activation input quantizer for operation: 5677 linear_664
# INFO:nncf:Not adding activation input quantizer for operation: 5696 linear_667
# 5698 add_tensor_283
# 5700 div_140
#
# INFO:nncf:Not adding activation input quantizer for operation: 5707 linear_668
# 5709 add_tensor_284
#
# INFO:nncf:Not adding activation input quantizer for operation: 5718 linear_669
# 5720 add_tensor_285
#
# INFO:nncf:Not adding activation input quantizer for operation: 5724 linear_670
# 5726 add_tensor_286
#
# INFO:nncf:Not adding activation input quantizer for operation: 5781 linear_672
# 5783 add_tensor_288
#
# INFO:nncf:Not adding activation input quantizer for operation: 5789 linear_673
# INFO:nncf:Not adding activation input quantizer for operation: 5792 linear_674
# INFO:nncf:Not adding activation input quantizer for operation: 5795 linear_675
# INFO:nncf:Not adding activation input quantizer for operation: 5808 linear_676
# 5810 add_tensor_289
# 5812 div_142
#
# INFO:nncf:Not adding activation input quantizer for operation: 5819 linear_677
# INFO:nncf:Not adding activation input quantizer for operation: 5838 linear_680
# 5840 add_tensor_290
# 5842 div_143
#
# INFO:nncf:Not adding activation input quantizer for operation: 5849 linear_681
# 5851 add_tensor_291
#
# INFO:nncf:Not adding activation input quantizer for operation: 5860 linear_682
# 5862 add_tensor_292
#
# INFO:nncf:Not adding activation input quantizer for operation: 5869 linear_683
# INFO:nncf:Not adding activation input quantizer for operation: 5872 linear_684
# INFO:nncf:Not adding activation input quantizer for operation: 5875 linear_685
# INFO:nncf:Not adding activation input quantizer for operation: 5888 linear_686
# 5890 add_tensor_293
# 5892 div_144
#
# INFO:nncf:Not adding activation input quantizer for operation: 5899 linear_687
# INFO:nncf:Not adding activation input quantizer for operation: 5918 linear_690
# 5920 add_tensor_294
# 5922 div_145
#
# INFO:nncf:Not adding activation input quantizer for operation: 5929 linear_691
# 5931 add_tensor_295
#
# INFO:nncf:Not adding activation input quantizer for operation: 5940 linear_692
# 5942 add_tensor_296
#
# INFO:nncf:Not adding activation input quantizer for operation: 5946 linear_693
# 5948 add_tensor_297
#
# INFO:nncf:Not adding activation input quantizer for operation: 5997 linear_695
# 5999 add_tensor_299
#
# INFO:nncf:Not adding activation input quantizer for operation: 6005 linear_696
# INFO:nncf:Not adding activation input quantizer for operation: 6008 linear_697
# INFO:nncf:Not adding activation input quantizer for operation: 6011 linear_698
# INFO:nncf:Not adding activation input quantizer for operation: 6024 linear_699
# 6026 add_tensor_300
# 6028 div_147
#
# INFO:nncf:Not adding activation input quantizer for operation: 6035 linear_700
# INFO:nncf:Not adding activation input quantizer for operation: 6054 linear_703
# 6056 add_tensor_301
# 6058 div_148
#
# INFO:nncf:Not adding activation input quantizer for operation: 6065 linear_704
# 6067 add_tensor_302
#
# INFO:nncf:Not adding activation input quantizer for operation: 6076 linear_705
# 6078 add_tensor_303
#
# INFO:nncf:Not adding activation input quantizer for operation: 6085 linear_706
# INFO:nncf:Not adding activation input quantizer for operation: 6088 linear_707
# INFO:nncf:Not adding activation input quantizer for operation: 6091 linear_708
# INFO:nncf:Not adding activation input quantizer for operation: 6104 linear_709
# 6106 add_tensor_304
# 6108 div_149
#
# INFO:nncf:Not adding activation input quantizer for operation: 6115 linear_710
# INFO:nncf:Not adding activation input quantizer for operation: 6134 linear_713
# 6136 add_tensor_305
# 6138 div_150
#
# INFO:nncf:Not adding activation input quantizer for operation: 6145 linear_714
# 6147 add_tensor_306
#
# INFO:nncf:Not adding activation input quantizer for operation: 6156 linear_715
# 6158 add_tensor_307
#
# INFO:nncf:Not adding activation input quantizer for operation: 6162 linear_716
# 6164 add_tensor_308
#
# INFO:nncf:Not adding activation input quantizer for operation: 6213 linear_718
# 6215 add_tensor_310
#
# INFO:nncf:Not adding activation input quantizer for operation: 6221 linear_719
# INFO:nncf:Not adding activation input quantizer for operation: 6224 linear_720
# INFO:nncf:Not adding activation input quantizer for operation: 6227 linear_721
# INFO:nncf:Not adding activation input quantizer for operation: 6240 linear_722
# 6242 add_tensor_311
# 6244 div_152
#
# INFO:nncf:Not adding activation input quantizer for operation: 6251 linear_723
# INFO:nncf:Not adding activation input quantizer for operation: 6270 linear_726
# 6272 add_tensor_312
# 6274 div_153
#
# INFO:nncf:Not adding activation input quantizer for operation: 6281 linear_727
# 6283 add_tensor_313
#
# INFO:nncf:Not adding activation input quantizer for operation: 6292 linear_728
# 6294 add_tensor_314
#
# INFO:nncf:Not adding activation input quantizer for operation: 6301 linear_729
# INFO:nncf:Not adding activation input quantizer for operation: 6304 linear_730
# INFO:nncf:Not adding activation input quantizer for operation: 6307 linear_731
# INFO:nncf:Not adding activation input quantizer for operation: 6320 linear_732
# 6322 add_tensor_315
# 6324 div_154
#
# INFO:nncf:Not adding activation input quantizer for operation: 6331 linear_733
# INFO:nncf:Not adding activation input quantizer for operation: 6350 linear_736
# 6352 add_tensor_316
# 6354 div_155
#
# INFO:nncf:Not adding activation input quantizer for operation: 6361 linear_737
# 6363 add_tensor_317
#
# INFO:nncf:Not adding activation input quantizer for operation: 6372 linear_738
# 6374 add_tensor_318
#
# INFO:nncf:Not adding activation input quantizer for operation: 6378 linear_739
# 6380 add_tensor_319
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ### Compile Models with OV Backend

# %%
pipe.unet = torch.compile(quantized_unet, backend='openvino')
del quantized_unet

# %%
unet_calibration_data[0][3]
# Out:
# {'text_embeds': tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [-6.3955e-01, -5.1384e-01,  8.0071e-01,  ...,  4.5383e-04,
#           -5.2668e-01, -1.1611e-01]]),
#  'time_ids': tensor([[1024., 1024.,    0.,    0., 1024., 1024.],
#          [1024., 1024.,    0.,    0., 1024., 1024.]])}

# %%
pipe.unet(*unet_calibration_data[0])
# Out:
# (tensor([[[[-1.6584e+00, -7.0044e-01, -6.8709e-01,  ...,  4.7870e-01,
#              4.6750e-02, -1.2369e+00],
#            [-1.3534e+00,  8.3244e-01, -6.1183e-01,  ..., -1.2659e+00,
#             -1.1257e+00,  2.6731e+00],
#            [ 1.2686e+00, -3.2416e-01,  5.4531e-01,  ...,  9.5981e-01,
#              5.9856e-01, -1.5226e+00],
#            ...,
#            [ 1.2959e+00,  1.0142e+00, -4.5759e-01,  ..., -3.3549e-02,
#             -3.1405e-01, -3.7660e-02],
#            [ 1.1248e+00,  9.3148e-01,  1.2178e+00,  ...,  1.0596e+00,
#              3.3450e-01, -8.5141e-01],
#            [-1.6657e+00, -3.8550e-02, -1.3534e+00,  ..., -9.6988e-01,
#              8.1562e-01,  2.5960e-02]],
#
#           [[-9.4742e-01, -1.5508e+00, -7.6173e-01,  ...,  8.1611e-01,
#             -9.1108e-01, -1.8096e-02],
#            [-7.9793e-01, -1.0903e+00, -1.5579e+00,  ..., -2.5794e-01,
#             -2.8353e-01, -1.9787e+00],
#            [ 1.1761e+00, -6.5676e-01, -1.7775e-01,  ...,  1.3126e-01,
#              5.9437e-02, -7.9060e-01],
#            ...,
#            [-5.8763e-01,  9.7626e-01,  2.0074e-01,  ...,  6.9697e-01,
#             -1.8445e-01, -4.6474e-02],
#            [ 8.1845e-01, -2.2005e+00,  4.0096e-01,  ...,  1.7088e-01,
#             -1.7393e+00,  1.2707e+00],
#            [-1.0148e+00,  3.3454e-01, -6.3261e-01,  ..., -3.9414e-02,
#              4.0798e-01,  1.0471e+00]],
#
#           [[ 2.9582e-01, -1.4952e+00, -1.4444e+00,  ...,  4.7016e-01,
#              8.4459e-01,  6.5831e-01],
#            [-1.2200e+00,  9.3747e-01,  6.8110e-01,  ..., -2.2929e+00,
#              9.2342e-01,  1.2167e+00],
#            [-7.3415e-01, -1.0785e+00,  1.4916e+00,  ...,  2.6448e+00,
#             -4.1159e-01, -1.4309e+00],
#            ...,
#            [ 1.2667e+00, -4.6021e-01, -4.1576e-01,  ..., -7.1041e-02,
#             -7.7843e-02,  1.3758e+00],
#            [ 3.7028e-01, -4.2057e-01, -3.0696e-01,  ..., -1.5412e+00,
#              8.1965e-01, -1.7995e-01],
#            [ 4.3453e-01,  2.7979e-01,  1.2730e+00,  ...,  1.5889e+00,
#             -2.7417e-01,  1.2078e+00]],
#
#           [[ 3.2255e-01, -1.5890e+00,  1.8053e-01,  ...,  2.5553e-02,
#              1.1030e-01, -2.0074e-01],
#            [-1.4187e+00, -1.4642e+00,  3.2190e-01,  ..., -3.4282e-01,
#              5.0020e-01, -2.2274e-01],
#            [ 4.6082e-01,  4.3100e-01,  1.7039e+00,  ..., -1.8774e+00,
#             -4.7560e-01, -4.8502e-01],
#            ...,
#            [-1.1228e+00,  6.4974e-01, -3.1215e-01,  ...,  2.4568e-01,
#             -4.4144e-01, -2.7885e-01],
#            [-1.1292e+00,  9.8721e-01, -2.2709e+00,  ...,  5.2446e-01,
#             -2.8484e-01, -3.0761e+00],
#            [-3.4666e-02,  5.5599e-01, -5.4698e-01,  ..., -1.6777e-01,
#             -7.7782e-01,  6.4372e-02]]],
#
#
#          [[[-1.6374e+00, -6.9756e-01, -6.8698e-01,  ...,  4.9239e-01,
#              5.4231e-02, -1.2265e+00],
#            [-1.3553e+00,  8.3249e-01, -6.0778e-01,  ..., -1.2458e+00,
#             -1.1176e+00,  2.6894e+00],
#            [ 1.2768e+00, -3.1704e-01,  5.4075e-01,  ...,  9.7549e-01,
#              6.0914e-01, -1.5122e+00],
#            ...,
#            [ 1.3263e+00,  1.0355e+00, -4.3023e-01,  ..., -3.4629e-02,
#             -3.1344e-01, -1.8608e-02],
#            [ 1.1483e+00,  9.5545e-01,  1.2323e+00,  ...,  1.0637e+00,
#              3.3054e-01, -8.5071e-01],
#            [-1.6391e+00, -1.2292e-02, -1.3355e+00,  ..., -9.6556e-01,
#              8.3162e-01,  3.7192e-02]],
#
#           [[-9.4989e-01, -1.5638e+00, -7.6280e-01,  ...,  8.2866e-01,
#             -9.0348e-01, -1.5219e-04],
#            [-8.0292e-01, -1.0934e+00, -1.5536e+00,  ..., -2.2704e-01,
#             -2.5560e-01, -1.9495e+00],
#            [ 1.1745e+00, -6.5631e-01, -1.7843e-01,  ...,  1.5226e-01,
#              8.5701e-02, -7.7063e-01],
#            ...,
#            [-5.7693e-01,  9.9195e-01,  2.1095e-01,  ...,  7.0804e-01,
#             -1.5486e-01, -1.3779e-02],
#            [ 8.2780e-01, -2.1880e+00,  4.0015e-01,  ...,  1.9467e-01,
#             -1.7107e+00,  1.2992e+00],
#            [-9.9239e-01,  3.4987e-01, -6.2847e-01,  ..., -4.0648e-03,
#              4.2633e-01,  1.0682e+00]],
#
#           [[ 2.9363e-01, -1.4967e+00, -1.4427e+00,  ...,  4.6757e-01,
#              8.3718e-01,  6.4904e-01],
#            [-1.2092e+00,  9.4112e-01,  6.8548e-01,  ..., -2.2904e+00,
#              9.2124e-01,  1.2036e+00],
#            [-7.2630e-01, -1.0617e+00,  1.5007e+00,  ...,  2.6470e+00,
#             -4.2256e-01, -1.4318e+00],
#            ...,
#            [ 1.2979e+00, -4.5122e-01, -4.0252e-01,  ..., -6.1486e-02,
#             -6.5859e-02,  1.3766e+00],
#            [ 3.8894e-01, -4.2398e-01, -3.0223e-01,  ..., -1.5264e+00,
#              8.2674e-01, -1.8441e-01],
#            [ 4.4028e-01,  2.8744e-01,  1.2889e+00,  ...,  1.5934e+00,
#             -2.5834e-01,  1.2016e+00]],
#
#           [[ 3.1118e-01, -1.6000e+00,  1.6545e-01,  ...,  1.3716e-02,
#              1.1030e-01, -2.2117e-01],
#            [-1.4288e+00, -1.4850e+00,  3.0702e-01,  ..., -3.5106e-01,
#              4.8458e-01, -2.3835e-01],
#            [ 4.5043e-01,  4.1666e-01,  1.6852e+00,  ..., -1.8769e+00,
#             -4.7955e-01, -5.0169e-01],
#            ...,
#            [-1.1285e+00,  6.3566e-01, -3.2712e-01,  ...,  2.3898e-01,
#             -4.5620e-01, -2.9084e-01],
#            [-1.1421e+00,  9.6531e-01, -2.2893e+00,  ...,  5.1218e-01,
#             -2.9742e-01, -3.0872e+00],
#            [-4.6858e-02,  5.3329e-01, -5.6324e-01,  ..., -1.6653e-01,
#             -7.8526e-01,  6.1833e-02]]]]),)

# %% [markdown]
# ### Inference for Compilation

# %%
#Warmup the model for initial compile
prompt = "valley in the Alps at sunset, epic vista, beautiful landscape, 4k, 8k"
negative_prompt = "frames, borderline, text, charachter, duplicate, error, out of frame, watermark, low quality, ugly, deformed, blur"
num_steps = 1
with torch.no_grad():
    image = pipe(prompt=prompt, negative_prompt=negative_prompt, num_inference_steps=num_steps, generator=generator).images[0]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# Reached
# torch.Size([1, 4, 128, 128])

# %%
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)
with torch.no_grad():
    image = pipe(prompt=prompt, negative_prompt=negative_prompt, num_inference_steps=25, generator=generator).images[0]
image.show()
image.save("experiment_5.png")
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# Reached
# torch.Size([1, 4, 128, 128])
