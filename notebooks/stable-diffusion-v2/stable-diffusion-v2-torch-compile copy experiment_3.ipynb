# %% [markdown]
# # Stable Diffusion v2 Demo with Torch Compile

# %% [markdown]
# ## Stable Diffusion v2 for Text-to-Image Generation
#
# To start, let's look on Text-to-Image process for Stable Diffusion v2. We will use [Stable Diffusion v2-1](https://huggingface.co/stabilityai/stable-diffusion-2-1) model for these purposes. The main difference from Stable Diffusion v2 and Stable Diffusion v2.1 is usage of more data, more training, and less restrictive filtering of the dataset, that gives promising results for selecting wide range of input text prompts. More details about model can be found in [Stability AI blog post](https://stability.ai/blog/stablediffusion2-1-release7-dec-2022) and original model [repository](https://github.com/Stability-AI/stablediffusion).
#
# ### Stable Diffusion in Diffusers library
# To work with Stable Diffusion v2, we will use Hugging Face [Diffusers](https://github.com/huggingface/diffusers) library. To experiment with Stable Diffusion models, Diffusers exposes the [`StableDiffusionPipeline`](https://huggingface.co/docs/diffusers/using-diffusers/conditional_image_generation) similar to the [other Diffusers pipelines](https://huggingface.co/docs/diffusers/api/pipelines/overview).  The code below demonstrates how to create `StableDiffusionPipeline` using `stable-diffusion-2-1`:

# %%
from torch._export import capture_pre_autograd_graph
from nncf.torch.dynamic_graph.patch_pytorch import disable_patching
import numpy as np
# Out:
# INFO:nncf:NNCF initialized successfully. Supported frameworks detected: torch, onnx, openvino
# WARNING:nncf:NNCF provides best results with torch==2.4.*, while current torch version is 2.3.1+cpu. If you encounter issues, consider switching to torch==2.4.*

# %%
from diffusers import DiffusionPipeline
import torch
import random
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)
generator = torch.Generator(device="cpu").manual_seed(42)
pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0")
pipe.to("cpu")

prompt = "valley in the Alps at sunset, epic vista, beautiful landscape, 4k, 8k"
negative_prompt = "frames, borderline, text, charachter, duplicate, error, out of frame, watermark, low quality, ugly, deformed, blur"
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# ### Convert Models to Torch Fx Graph

# %%
text_encoder_input = torch.ones((1, 77), dtype=torch.long)
text_encoder_2_input = torch.ones((1, 77), dtype=torch.long)
vae_encoder_input = torch.ones((1, 3, 256, 256))
vae_decoder_input = torch.ones((1, 4, 128, 128))
vae_decoder_kwargs = {}
vae_decoder_kwargs["return_dict"] = False
latents_shape = (2, 4, 128, 128)
latents = torch.randn(latents_shape)
t = torch.from_numpy(np.array(1, dtype=np.float32))
added_cond_kwargs = {}
added_cond_kwargs["text_embeds"] = torch.ones((2, 1280))
added_cond_kwargs["time_ids"] = torch.ones((2,6))
unet_kwargs = {}
unet_kwargs["encoder_hidden_states"] = torch.ones((2, 77, 2048))
unet_kwargs["added_cond_kwargs"] = added_cond_kwargs
unet_kwargs["return_dict"] = False
unet_input = (latents, t)

text_encoder_kwargs = {}
text_encoder_kwargs['output_hidden_states'] = True

with torch.no_grad():
    with disable_patching():
        text_encoder = capture_pre_autograd_graph(pipe.text_encoder.eval(), args=(text_encoder_input,), kwargs=(text_encoder_kwargs))
        text_encoder_2 = capture_pre_autograd_graph(pipe.text_encoder_2.eval(), args=(text_encoder_2_input,), kwargs=(text_encoder_kwargs))
        vae_encoder = capture_pre_autograd_graph(pipe.vae.encoder, args=(vae_encoder_input,))
        vae_decoder = capture_pre_autograd_graph(pipe.vae.decoder.eval(), args=(vae_decoder_input,))
        unet = capture_pre_autograd_graph(pipe.unet.eval(), args=(*unet_input,), kwargs=(unet_kwargs))
del added_cond_kwargs
del unet_kwargs
del unet_input
del latents
del t
del vae_encoder_input
del vae_decoder_input
del text_encoder_2_input
del text_encoder_input
del text_encoder_kwargs
del vae_decoder_kwargs

# %%
pipe.text_encoder = torch.compile(text_encoder, backend='openvino')
pipe.text_encoder_2 = torch.compile(text_encoder_2, backend='openvino')
pipe.vae.decoder = torch.compile(vae_decoder, backend='openvino')
pipe.vae.encoder = torch.compile(vae_encoder, backend='openvino')
pipe.unet = unet

# %% [markdown]
# ### Weights Compression

# %%
import pickle
with open("test", "rb") as fp:
    unet_calibration_data = pickle.load(fp)

def collect_ops_with_weights(graph_module):
    ops_with_weights = []
    for node in graph_module.graph.nodes:
        if "linear" in node.name:
            ops_with_weights.append(node.name)
    return ops_with_weights

unet_ignored_scope = collect_ops_with_weights(pipe.unet)

# %%
import nncf
from nncf.quantization.advanced_parameters import AdvancedSmoothQuantParameters
from nncf.quantization.range_estimator import RangeEstimatorParametersSet

def disable_progress_bar(pipeline, disable=True):
    if not hasattr(pipeline, "_progress_bar_config"):
        pipeline._progress_bar_config = {'disable': disable}
    else:
        pipeline._progress_bar_config['disable'] = disable

with disable_patching():
    with torch.no_grad():
        compressed_unet = nncf.compress_weights(unet, ignored_scope=nncf.IgnoredScope(types=['conv2d']))
        # quantized_unet = nncf.quantize( #1
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1, disable_bias_correction=True)
        # )
        quantized_unet = nncf.quantize( #2
            model=compressed_unet,
            calibration_dataset=nncf.Dataset(unet_calibration_data),
            subset_size=len(unet_calibration_data),
            model_type=nncf.ModelType.TRANSFORMER,
            fast_bias_correction=False,
            ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
            advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1, disable_bias_correction=True, weights_range_estimator_params=RangeEstimatorParametersSet.MINMAX, activations_range_estimator_params=RangeEstimatorParametersSet.MINMAX)
        )
        # quantized_unet = nncf.quantize( #3
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     fast_bias_correction=False,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1)
        # )
        # quantized_unet = nncf.quantize( #4.1
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     fast_bias_correction=False,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alphas=AdvancedSmoothQuantParameters(convolution=0.95, matmul=-1))
        # )
        # quantized_unet = nncf.quantize( #4.2
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     fast_bias_correction=False,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alphas=AdvancedSmoothQuantParameters(convolution=0.95))
        # )
# del text_encoder
# del text_encoder_2
# del vae_decoder
del unet
# Out:
# INFO:nncf:51 ignored nodes were found by types in the NNCFGraph
# INFO:nncf:Statistics of the bitwidth distribution:
# ┍━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
# │   Num bits (N) │ % all parameters (layers)   │ % ratio-defining parameters (layers)   │
# ┝━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │              8 │ 100% (743 / 743)            │ 100% (743 / 743)                       │
# ┕━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# WARNING:nncf:Experimental Torch FX quantization backend is being used for the given torch.fx.GraphModule model. Torch FX PTQ is an experimental feature, consider using Torch or OpenVino PTQ backends in case of errors or a poor model performance.
# /home/user/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/nncf/quantization/algorithms/post_training/pipeline.py:87: FutureWarning: `AdvancedQuantizationParameters(smooth_quant_alpha=..)` is deprecated.Please, use `AdvancedQuantizationParameters(smooth_quant_alphas)` option with AdvancedSmoothQuantParameters(convolution=.., matmul=..) as value instead.
#   warning_deprecated(
# INFO:nncf:743 ignored nodes were found by names in the NNCFGraph
# INFO:nncf:Not adding activation input quantizer for operation: 1051 linear_109
# INFO:nncf:Not adding activation input quantizer for operation: 1054 linear_110
# INFO:nncf:Not adding activation input quantizer for operation: 1131 linear_119
# INFO:nncf:Not adding activation input quantizer for operation: 1134 linear_120
# INFO:nncf:Not adding activation input quantizer for operation: 1211 linear_129
# INFO:nncf:Not adding activation input quantizer for operation: 1214 linear_130
# INFO:nncf:Not adding activation input quantizer for operation: 1291 linear_139
# INFO:nncf:Not adding activation input quantizer for operation: 1294 linear_140
# INFO:nncf:Not adding activation input quantizer for operation: 1371 linear_149
# INFO:nncf:Not adding activation input quantizer for operation: 1374 linear_150
# INFO:nncf:Not adding activation input quantizer for operation: 1500 linear_162
# INFO:nncf:Not adding activation input quantizer for operation: 1503 linear_163
# INFO:nncf:Not adding activation input quantizer for operation: 1580 linear_172
# INFO:nncf:Not adding activation input quantizer for operation: 1583 linear_173
# INFO:nncf:Not adding activation input quantizer for operation: 1660 linear_182
# INFO:nncf:Not adding activation input quantizer for operation: 1663 linear_183
# INFO:nncf:Not adding activation input quantizer for operation: 1740 linear_192
# INFO:nncf:Not adding activation input quantizer for operation: 1743 linear_193
# INFO:nncf:Not adding activation input quantizer for operation: 1820 linear_202
# INFO:nncf:Not adding activation input quantizer for operation: 1823 linear_203
# INFO:nncf:Not adding activation input quantizer for operation: 1900 linear_212
# INFO:nncf:Not adding activation input quantizer for operation: 1903 linear_213
# INFO:nncf:Not adding activation input quantizer for operation: 1980 linear_222
# INFO:nncf:Not adding activation input quantizer for operation: 1983 linear_223
# INFO:nncf:Not adding activation input quantizer for operation: 2060 linear_232
# INFO:nncf:Not adding activation input quantizer for operation: 2063 linear_233
# INFO:nncf:Not adding activation input quantizer for operation: 2140 linear_242
# INFO:nncf:Not adding activation input quantizer for operation: 2143 linear_243
# INFO:nncf:Not adding activation input quantizer for operation: 2220 linear_252
# INFO:nncf:Not adding activation input quantizer for operation: 2223 linear_253
# INFO:nncf:Not adding activation input quantizer for operation: 225 linear_13
# INFO:nncf:Not adding activation input quantizer for operation: 228 linear_14
# INFO:nncf:Not adding activation input quantizer for operation: 2349 linear_265
# INFO:nncf:Not adding activation input quantizer for operation: 2352 linear_266
# INFO:nncf:Not adding activation input quantizer for operation: 2429 linear_275
# INFO:nncf:Not adding activation input quantizer for operation: 2432 linear_276
# INFO:nncf:Not adding activation input quantizer for operation: 2509 linear_285
# INFO:nncf:Not adding activation input quantizer for operation: 2512 linear_286
# INFO:nncf:Not adding activation input quantizer for operation: 2589 linear_295
# INFO:nncf:Not adding activation input quantizer for operation: 2592 linear_296
# INFO:nncf:Not adding activation input quantizer for operation: 2669 linear_305
# INFO:nncf:Not adding activation input quantizer for operation: 2672 linear_306
# INFO:nncf:Not adding activation input quantizer for operation: 2749 linear_315
# INFO:nncf:Not adding activation input quantizer for operation: 2752 linear_316
# INFO:nncf:Not adding activation input quantizer for operation: 2829 linear_325
# INFO:nncf:Not adding activation input quantizer for operation: 2832 linear_326
# INFO:nncf:Not adding activation input quantizer for operation: 2909 linear_335
# INFO:nncf:Not adding activation input quantizer for operation: 2912 linear_336
# INFO:nncf:Not adding activation input quantizer for operation: 2989 linear_345
# INFO:nncf:Not adding activation input quantizer for operation: 2992 linear_346
# INFO:nncf:Not adding activation input quantizer for operation: 305 linear_23
# INFO:nncf:Not adding activation input quantizer for operation: 3069 linear_355
# INFO:nncf:Not adding activation input quantizer for operation: 3072 linear_356
# INFO:nncf:Not adding activation input quantizer for operation: 308 linear_24
# INFO:nncf:Not adding activation input quantizer for operation: 3233 linear_369
# INFO:nncf:Not adding activation input quantizer for operation: 3236 linear_370
# INFO:nncf:Not adding activation input quantizer for operation: 3313 linear_379
# INFO:nncf:Not adding activation input quantizer for operation: 3316 linear_380
# INFO:nncf:Not adding activation input quantizer for operation: 3393 linear_389
# INFO:nncf:Not adding activation input quantizer for operation: 3396 linear_390
# INFO:nncf:Not adding activation input quantizer for operation: 3473 linear_399
# INFO:nncf:Not adding activation input quantizer for operation: 3476 linear_400
# INFO:nncf:Not adding activation input quantizer for operation: 3553 linear_409
# INFO:nncf:Not adding activation input quantizer for operation: 3556 linear_410
# INFO:nncf:Not adding activation input quantizer for operation: 3633 linear_419
# INFO:nncf:Not adding activation input quantizer for operation: 3636 linear_420
# INFO:nncf:Not adding activation input quantizer for operation: 3713 linear_429
# INFO:nncf:Not adding activation input quantizer for operation: 3716 linear_430
# INFO:nncf:Not adding activation input quantizer for operation: 3793 linear_439
# INFO:nncf:Not adding activation input quantizer for operation: 3796 linear_440
# INFO:nncf:Not adding activation input quantizer for operation: 3873 linear_449
# INFO:nncf:Not adding activation input quantizer for operation: 3876 linear_450
# INFO:nncf:Not adding activation input quantizer for operation: 3953 linear_459
# INFO:nncf:Not adding activation input quantizer for operation: 3956 linear_460
# INFO:nncf:Not adding activation input quantizer for operation: 4087 linear_472
# INFO:nncf:Not adding activation input quantizer for operation: 4090 linear_473
# INFO:nncf:Not adding activation input quantizer for operation: 4167 linear_482
# INFO:nncf:Not adding activation input quantizer for operation: 4170 linear_483
# INFO:nncf:Not adding activation input quantizer for operation: 4247 linear_492
# INFO:nncf:Not adding activation input quantizer for operation: 4250 linear_493
# INFO:nncf:Not adding activation input quantizer for operation: 4327 linear_502
# INFO:nncf:Not adding activation input quantizer for operation: 4330 linear_503
# INFO:nncf:Not adding activation input quantizer for operation: 434 linear_36
# INFO:nncf:Not adding activation input quantizer for operation: 437 linear_37
# INFO:nncf:Not adding activation input quantizer for operation: 4407 linear_512
# INFO:nncf:Not adding activation input quantizer for operation: 4410 linear_513
# INFO:nncf:Not adding activation input quantizer for operation: 4487 linear_522
# INFO:nncf:Not adding activation input quantizer for operation: 4490 linear_523
# INFO:nncf:Not adding activation input quantizer for operation: 4567 linear_532
# INFO:nncf:Not adding activation input quantizer for operation: 4570 linear_533
# INFO:nncf:Not adding activation input quantizer for operation: 4647 linear_542
# INFO:nncf:Not adding activation input quantizer for operation: 4650 linear_543
# INFO:nncf:Not adding activation input quantizer for operation: 4727 linear_552
# INFO:nncf:Not adding activation input quantizer for operation: 4730 linear_553
# INFO:nncf:Not adding activation input quantizer for operation: 4807 linear_562
# INFO:nncf:Not adding activation input quantizer for operation: 4810 linear_563
# INFO:nncf:Not adding activation input quantizer for operation: 4941 linear_575
# INFO:nncf:Not adding activation input quantizer for operation: 4944 linear_576
# INFO:nncf:Not adding activation input quantizer for operation: 5021 linear_585
# INFO:nncf:Not adding activation input quantizer for operation: 5024 linear_586
# INFO:nncf:Not adding activation input quantizer for operation: 5101 linear_595
# INFO:nncf:Not adding activation input quantizer for operation: 5104 linear_596
# INFO:nncf:Not adding activation input quantizer for operation: 514 linear_46
# INFO:nncf:Not adding activation input quantizer for operation: 517 linear_47
# INFO:nncf:Not adding activation input quantizer for operation: 5181 linear_605
# INFO:nncf:Not adding activation input quantizer for operation: 5184 linear_606
# INFO:nncf:Not adding activation input quantizer for operation: 5261 linear_615
# INFO:nncf:Not adding activation input quantizer for operation: 5264 linear_616
# INFO:nncf:Not adding activation input quantizer for operation: 5341 linear_625
# INFO:nncf:Not adding activation input quantizer for operation: 5344 linear_626
# INFO:nncf:Not adding activation input quantizer for operation: 5421 linear_635
# INFO:nncf:Not adding activation input quantizer for operation: 5424 linear_636
# INFO:nncf:Not adding activation input quantizer for operation: 5501 linear_645
# INFO:nncf:Not adding activation input quantizer for operation: 5504 linear_646
# INFO:nncf:Not adding activation input quantizer for operation: 5581 linear_655
# INFO:nncf:Not adding activation input quantizer for operation: 5584 linear_656
# INFO:nncf:Not adding activation input quantizer for operation: 5661 linear_665
# INFO:nncf:Not adding activation input quantizer for operation: 5664 linear_666
# INFO:nncf:Not adding activation input quantizer for operation: 5800 linear_678
# INFO:nncf:Not adding activation input quantizer for operation: 5803 linear_679
# INFO:nncf:Not adding activation input quantizer for operation: 5880 linear_688
# INFO:nncf:Not adding activation input quantizer for operation: 5883 linear_689
# INFO:nncf:Not adding activation input quantizer for operation: 6014 linear_701
# INFO:nncf:Not adding activation input quantizer for operation: 6017 linear_702
# INFO:nncf:Not adding activation input quantizer for operation: 6094 linear_711
# INFO:nncf:Not adding activation input quantizer for operation: 6097 linear_712
# INFO:nncf:Not adding activation input quantizer for operation: 6228 linear_724
# INFO:nncf:Not adding activation input quantizer for operation: 6231 linear_725
# INFO:nncf:Not adding activation input quantizer for operation: 6308 linear_734
# INFO:nncf:Not adding activation input quantizer for operation: 6311 linear_735
# INFO:nncf:Not adding activation input quantizer for operation: 651 linear_59
# INFO:nncf:Not adding activation input quantizer for operation: 654 linear_60
# INFO:nncf:Not adding activation input quantizer for operation: 731 linear_69
# INFO:nncf:Not adding activation input quantizer for operation: 734 linear_70
# INFO:nncf:Not adding activation input quantizer for operation: 811 linear_79
# INFO:nncf:Not adding activation input quantizer for operation: 814 linear_80
# INFO:nncf:Not adding activation input quantizer for operation: 891 linear_89
# INFO:nncf:Not adding activation input quantizer for operation: 894 linear_90
# INFO:nncf:Not adding activation input quantizer for operation: 971 linear_99
# INFO:nncf:Not adding activation input quantizer for operation: 974 linear_100
# INFO:nncf:Not adding activation input quantizer for operation: 31 linear
# 33 add_tensor
#
# INFO:nncf:Not adding activation input quantizer for operation: 37 linear_1
# 39 add_tensor_1
#
# INFO:nncf:Not adding activation input quantizer for operation: 65 linear_2
# 67 add_tensor_2
#
# INFO:nncf:Not adding activation input quantizer for operation: 71 linear_3
# 73 add_tensor_3
#
# INFO:nncf:Not adding activation input quantizer for operation: 120 linear_5
# 122 add_tensor_5
#
# INFO:nncf:Not adding activation input quantizer for operation: 1433 linear_155
# 1435 add_tensor_71
#
# INFO:nncf:Not adding activation input quantizer for operation: 154 linear_6
# 156 add_tensor_6
#
# INFO:nncf:Not adding activation input quantizer for operation: 2282 linear_258
# 2284 add_tensor_114
#
# INFO:nncf:Not adding activation input quantizer for operation: 3131 linear_361
# 3133 add_tensor_157
#
# INFO:nncf:Not adding activation input quantizer for operation: 3162 linear_362
# 3164 add_tensor_158
#
# INFO:nncf:Not adding activation input quantizer for operation: 367 linear_29
# 369 add_tensor_17
#
# INFO:nncf:Not adding activation input quantizer for operation: 4016 linear_465
# 4018 add_tensor_201
#
# INFO:nncf:Not adding activation input quantizer for operation: 4870 linear_568
# 4872 add_tensor_244
#
# INFO:nncf:Not adding activation input quantizer for operation: 5729 linear_671
# 5731 add_tensor_287
#
# INFO:nncf:Not adding activation input quantizer for operation: 580 linear_52
# 582 add_tensor_28
#
# INFO:nncf:Not adding activation input quantizer for operation: 5943 linear_694
# 5945 add_tensor_298
#
# INFO:nncf:Not adding activation input quantizer for operation: 6157 linear_717
# 6159 add_tensor_309
#
# INFO:nncf:Not adding activation input quantizer for operation: 6376 linear_740
# 6378 add_tensor_320
#
# INFO:nncf:Not adding activation input quantizer for operation: 6411 linear_741
# 6413 add_tensor_321
#
# INFO:nncf:Not adding activation input quantizer for operation: 6446 linear_742
# 6448 add_tensor_322
#
# INFO:nncf:Not adding activation input quantizer for operation: 90 linear_4
# 92 add_tensor_4
#
# INFO:nncf:Not adding activation input quantizer for operation: 184 linear_7
# 186 add_tensor_7
#
# INFO:nncf:Not adding activation input quantizer for operation: 192 linear_8
# INFO:nncf:Not adding activation input quantizer for operation: 195 linear_9
# INFO:nncf:Not adding activation input quantizer for operation: 198 linear_10
# INFO:nncf:Not adding activation input quantizer for operation: 211 linear_11
# 213 add_tensor_8
# 215 div_5
#
# INFO:nncf:Not adding activation input quantizer for operation: 222 linear_12
# INFO:nncf:Not adding activation input quantizer for operation: 241 linear_15
# 243 add_tensor_9
# 245 div_6
#
# INFO:nncf:Not adding activation input quantizer for operation: 252 linear_16
# 254 add_tensor_10
#
# INFO:nncf:Not adding activation input quantizer for operation: 263 linear_17
# 265 add_tensor_11
#
# INFO:nncf:Not adding activation input quantizer for operation: 272 linear_18
# INFO:nncf:Not adding activation input quantizer for operation: 275 linear_19
# INFO:nncf:Not adding activation input quantizer for operation: 278 linear_20
# INFO:nncf:Not adding activation input quantizer for operation: 291 linear_21
# 293 add_tensor_12
# 295 div_7
#
# INFO:nncf:Not adding activation input quantizer for operation: 302 linear_22
# INFO:nncf:Not adding activation input quantizer for operation: 321 linear_25
# 323 add_tensor_13
# 325 div_8
#
# INFO:nncf:Not adding activation input quantizer for operation: 332 linear_26
# 334 add_tensor_14
#
# INFO:nncf:Not adding activation input quantizer for operation: 343 linear_27
# 345 add_tensor_15
#
# INFO:nncf:Not adding activation input quantizer for operation: 349 linear_28
# 351 add_tensor_16
#
# INFO:nncf:Not adding activation input quantizer for operation: 393 linear_30
# 395 add_tensor_18
#
# INFO:nncf:Not adding activation input quantizer for operation: 401 linear_31
# INFO:nncf:Not adding activation input quantizer for operation: 404 linear_32
# INFO:nncf:Not adding activation input quantizer for operation: 407 linear_33
# INFO:nncf:Not adding activation input quantizer for operation: 420 linear_34
# 422 add_tensor_19
# 424 div_10
#
# INFO:nncf:Not adding activation input quantizer for operation: 431 linear_35
# INFO:nncf:Not adding activation input quantizer for operation: 450 linear_38
# 452 add_tensor_20
# 454 div_11
#
# INFO:nncf:Not adding activation input quantizer for operation: 461 linear_39
# 463 add_tensor_21
#
# INFO:nncf:Not adding activation input quantizer for operation: 472 linear_40
# 474 add_tensor_22
#
# INFO:nncf:Not adding activation input quantizer for operation: 481 linear_41
# INFO:nncf:Not adding activation input quantizer for operation: 484 linear_42
# INFO:nncf:Not adding activation input quantizer for operation: 487 linear_43
# INFO:nncf:Not adding activation input quantizer for operation: 500 linear_44
# 502 add_tensor_23
# 504 div_12
#
# INFO:nncf:Not adding activation input quantizer for operation: 511 linear_45
# INFO:nncf:Not adding activation input quantizer for operation: 530 linear_48
# 532 add_tensor_24
# 534 div_13
#
# INFO:nncf:Not adding activation input quantizer for operation: 541 linear_49
# 543 add_tensor_25
#
# INFO:nncf:Not adding activation input quantizer for operation: 552 linear_50
# 554 add_tensor_26
#
# INFO:nncf:Not adding activation input quantizer for operation: 558 linear_51
# 560 add_tensor_27
#
# INFO:nncf:Not adding activation input quantizer for operation: 610 linear_53
# 612 add_tensor_29
#
# INFO:nncf:Not adding activation input quantizer for operation: 618 linear_54
# INFO:nncf:Not adding activation input quantizer for operation: 621 linear_55
# INFO:nncf:Not adding activation input quantizer for operation: 624 linear_56
# INFO:nncf:Not adding activation input quantizer for operation: 637 linear_57
# 639 add_tensor_30
# 641 div_15
#
# INFO:nncf:Not adding activation input quantizer for operation: 648 linear_58
# INFO:nncf:Not adding activation input quantizer for operation: 667 linear_61
# 669 add_tensor_31
# 671 div_16
#
# INFO:nncf:Not adding activation input quantizer for operation: 678 linear_62
# 680 add_tensor_32
#
# INFO:nncf:Not adding activation input quantizer for operation: 689 linear_63
# 691 add_tensor_33
#
# INFO:nncf:Not adding activation input quantizer for operation: 698 linear_64
# INFO:nncf:Not adding activation input quantizer for operation: 701 linear_65
# INFO:nncf:Not adding activation input quantizer for operation: 704 linear_66
# INFO:nncf:Not adding activation input quantizer for operation: 717 linear_67
# 719 add_tensor_34
# 721 div_17
#
# INFO:nncf:Not adding activation input quantizer for operation: 728 linear_68
# INFO:nncf:Not adding activation input quantizer for operation: 747 linear_71
# 749 add_tensor_35
# 751 div_18
#
# INFO:nncf:Not adding activation input quantizer for operation: 758 linear_72
# 760 add_tensor_36
#
# INFO:nncf:Not adding activation input quantizer for operation: 769 linear_73
# 771 add_tensor_37
#
# INFO:nncf:Not adding activation input quantizer for operation: 778 linear_74
# INFO:nncf:Not adding activation input quantizer for operation: 781 linear_75
# INFO:nncf:Not adding activation input quantizer for operation: 784 linear_76
# INFO:nncf:Not adding activation input quantizer for operation: 797 linear_77
# 799 add_tensor_38
# 801 div_19
#
# INFO:nncf:Not adding activation input quantizer for operation: 808 linear_78
# INFO:nncf:Not adding activation input quantizer for operation: 827 linear_81
# 829 add_tensor_39
# 831 div_20
#
# INFO:nncf:Not adding activation input quantizer for operation: 838 linear_82
# 840 add_tensor_40
#
# INFO:nncf:Not adding activation input quantizer for operation: 849 linear_83
# 851 add_tensor_41
#
# INFO:nncf:Not adding activation input quantizer for operation: 858 linear_84
# INFO:nncf:Not adding activation input quantizer for operation: 861 linear_85
# INFO:nncf:Not adding activation input quantizer for operation: 864 linear_86
# INFO:nncf:Not adding activation input quantizer for operation: 877 linear_87
# 879 add_tensor_42
# 881 div_21
#
# INFO:nncf:Not adding activation input quantizer for operation: 888 linear_88
# INFO:nncf:Not adding activation input quantizer for operation: 907 linear_91
# 909 add_tensor_43
# 911 div_22
#
# INFO:nncf:Not adding activation input quantizer for operation: 918 linear_92
# 920 add_tensor_44
#
# INFO:nncf:Not adding activation input quantizer for operation: 929 linear_93
# 931 add_tensor_45
#
# INFO:nncf:Not adding activation input quantizer for operation: 938 linear_94
# INFO:nncf:Not adding activation input quantizer for operation: 941 linear_95
# INFO:nncf:Not adding activation input quantizer for operation: 944 linear_96
# INFO:nncf:Not adding activation input quantizer for operation: 957 linear_97
# 959 add_tensor_46
# 961 div_23
#
# INFO:nncf:Not adding activation input quantizer for operation: 968 linear_98
# INFO:nncf:Not adding activation input quantizer for operation: 987 linear_101
# 989 add_tensor_47
# 991 div_24
#
# INFO:nncf:Not adding activation input quantizer for operation: 998 linear_102
# 1000 add_tensor_48
#
# INFO:nncf:Not adding activation input quantizer for operation: 1009 linear_103
# 1011 add_tensor_49
#
# INFO:nncf:Not adding activation input quantizer for operation: 1018 linear_104
# INFO:nncf:Not adding activation input quantizer for operation: 1021 linear_105
# INFO:nncf:Not adding activation input quantizer for operation: 1024 linear_106
# INFO:nncf:Not adding activation input quantizer for operation: 1037 linear_107
# 1039 add_tensor_50
# 1041 div_25
#
# INFO:nncf:Not adding activation input quantizer for operation: 1048 linear_108
# INFO:nncf:Not adding activation input quantizer for operation: 1067 linear_111
# 1069 add_tensor_51
# 1071 div_26
#
# INFO:nncf:Not adding activation input quantizer for operation: 1078 linear_112
# 1080 add_tensor_52
#
# INFO:nncf:Not adding activation input quantizer for operation: 1089 linear_113
# 1091 add_tensor_53
#
# INFO:nncf:Not adding activation input quantizer for operation: 1098 linear_114
# INFO:nncf:Not adding activation input quantizer for operation: 1101 linear_115
# INFO:nncf:Not adding activation input quantizer for operation: 1104 linear_116
# INFO:nncf:Not adding activation input quantizer for operation: 1117 linear_117
# 1119 add_tensor_54
# 1121 div_27
#
# INFO:nncf:Not adding activation input quantizer for operation: 1128 linear_118
# INFO:nncf:Not adding activation input quantizer for operation: 1147 linear_121
# 1149 add_tensor_55
# 1151 div_28
#
# INFO:nncf:Not adding activation input quantizer for operation: 1158 linear_122
# 1160 add_tensor_56
#
# INFO:nncf:Not adding activation input quantizer for operation: 1169 linear_123
# 1171 add_tensor_57
#
# INFO:nncf:Not adding activation input quantizer for operation: 1178 linear_124
# INFO:nncf:Not adding activation input quantizer for operation: 1181 linear_125
# INFO:nncf:Not adding activation input quantizer for operation: 1184 linear_126
# INFO:nncf:Not adding activation input quantizer for operation: 1197 linear_127
# 1199 add_tensor_58
# 1201 div_29
#
# INFO:nncf:Not adding activation input quantizer for operation: 1208 linear_128
# INFO:nncf:Not adding activation input quantizer for operation: 1227 linear_131
# 1229 add_tensor_59
# 1231 div_30
#
# INFO:nncf:Not adding activation input quantizer for operation: 1238 linear_132
# 1240 add_tensor_60
#
# INFO:nncf:Not adding activation input quantizer for operation: 1249 linear_133
# 1251 add_tensor_61
#
# INFO:nncf:Not adding activation input quantizer for operation: 1258 linear_134
# INFO:nncf:Not adding activation input quantizer for operation: 1261 linear_135
# INFO:nncf:Not adding activation input quantizer for operation: 1264 linear_136
# INFO:nncf:Not adding activation input quantizer for operation: 1277 linear_137
# 1279 add_tensor_62
# 1281 div_31
#
# INFO:nncf:Not adding activation input quantizer for operation: 1288 linear_138
# INFO:nncf:Not adding activation input quantizer for operation: 1307 linear_141
# 1309 add_tensor_63
# 1311 div_32
#
# INFO:nncf:Not adding activation input quantizer for operation: 1318 linear_142
# 1320 add_tensor_64
#
# INFO:nncf:Not adding activation input quantizer for operation: 1329 linear_143
# 1331 add_tensor_65
#
# INFO:nncf:Not adding activation input quantizer for operation: 1338 linear_144
# INFO:nncf:Not adding activation input quantizer for operation: 1341 linear_145
# INFO:nncf:Not adding activation input quantizer for operation: 1344 linear_146
# INFO:nncf:Not adding activation input quantizer for operation: 1357 linear_147
# 1359 add_tensor_66
# 1361 div_33
#
# INFO:nncf:Not adding activation input quantizer for operation: 1368 linear_148
# INFO:nncf:Not adding activation input quantizer for operation: 1387 linear_151
# 1389 add_tensor_67
# 1391 div_34
#
# INFO:nncf:Not adding activation input quantizer for operation: 1398 linear_152
# 1400 add_tensor_68
#
# INFO:nncf:Not adding activation input quantizer for operation: 1409 linear_153
# 1411 add_tensor_69
#
# INFO:nncf:Not adding activation input quantizer for operation: 1415 linear_154
# 1417 add_tensor_70
#
# INFO:nncf:Not adding activation input quantizer for operation: 1459 linear_156
# 1461 add_tensor_72
#
# INFO:nncf:Not adding activation input quantizer for operation: 1467 linear_157
# INFO:nncf:Not adding activation input quantizer for operation: 1470 linear_158
# INFO:nncf:Not adding activation input quantizer for operation: 1473 linear_159
# INFO:nncf:Not adding activation input quantizer for operation: 1486 linear_160
# 1488 add_tensor_73
# 1490 div_36
#
# INFO:nncf:Not adding activation input quantizer for operation: 1497 linear_161
# INFO:nncf:Not adding activation input quantizer for operation: 1516 linear_164
# 1518 add_tensor_74
# 1520 div_37
#
# INFO:nncf:Not adding activation input quantizer for operation: 1527 linear_165
# 1529 add_tensor_75
#
# INFO:nncf:Not adding activation input quantizer for operation: 1538 linear_166
# 1540 add_tensor_76
#
# INFO:nncf:Not adding activation input quantizer for operation: 1547 linear_167
# INFO:nncf:Not adding activation input quantizer for operation: 1550 linear_168
# INFO:nncf:Not adding activation input quantizer for operation: 1553 linear_169
# INFO:nncf:Not adding activation input quantizer for operation: 1566 linear_170
# 1568 add_tensor_77
# 1570 div_38
#
# INFO:nncf:Not adding activation input quantizer for operation: 1577 linear_171
# INFO:nncf:Not adding activation input quantizer for operation: 1596 linear_174
# 1598 add_tensor_78
# 1600 div_39
#
# INFO:nncf:Not adding activation input quantizer for operation: 1607 linear_175
# 1609 add_tensor_79
#
# INFO:nncf:Not adding activation input quantizer for operation: 1618 linear_176
# 1620 add_tensor_80
#
# INFO:nncf:Not adding activation input quantizer for operation: 1627 linear_177
# INFO:nncf:Not adding activation input quantizer for operation: 1630 linear_178
# INFO:nncf:Not adding activation input quantizer for operation: 1633 linear_179
# INFO:nncf:Not adding activation input quantizer for operation: 1646 linear_180
# 1648 add_tensor_81
# 1650 div_40
#
# INFO:nncf:Not adding activation input quantizer for operation: 1657 linear_181
# INFO:nncf:Not adding activation input quantizer for operation: 1676 linear_184
# 1678 add_tensor_82
# 1680 div_41
#
# INFO:nncf:Not adding activation input quantizer for operation: 1687 linear_185
# 1689 add_tensor_83
#
# INFO:nncf:Not adding activation input quantizer for operation: 1698 linear_186
# 1700 add_tensor_84
#
# INFO:nncf:Not adding activation input quantizer for operation: 1707 linear_187
# INFO:nncf:Not adding activation input quantizer for operation: 1710 linear_188
# INFO:nncf:Not adding activation input quantizer for operation: 1713 linear_189
# INFO:nncf:Not adding activation input quantizer for operation: 1726 linear_190
# 1728 add_tensor_85
# 1730 div_42
#
# INFO:nncf:Not adding activation input quantizer for operation: 1737 linear_191
# INFO:nncf:Not adding activation input quantizer for operation: 1756 linear_194
# 1758 add_tensor_86
# 1760 div_43
#
# INFO:nncf:Not adding activation input quantizer for operation: 1767 linear_195
# 1769 add_tensor_87
#
# INFO:nncf:Not adding activation input quantizer for operation: 1778 linear_196
# 1780 add_tensor_88
#
# INFO:nncf:Not adding activation input quantizer for operation: 1787 linear_197
# INFO:nncf:Not adding activation input quantizer for operation: 1790 linear_198
# INFO:nncf:Not adding activation input quantizer for operation: 1793 linear_199
# INFO:nncf:Not adding activation input quantizer for operation: 1806 linear_200
# 1808 add_tensor_89
# 1810 div_44
#
# INFO:nncf:Not adding activation input quantizer for operation: 1817 linear_201
# INFO:nncf:Not adding activation input quantizer for operation: 1836 linear_204
# 1838 add_tensor_90
# 1840 div_45
#
# INFO:nncf:Not adding activation input quantizer for operation: 1847 linear_205
# 1849 add_tensor_91
#
# INFO:nncf:Not adding activation input quantizer for operation: 1858 linear_206
# 1860 add_tensor_92
#
# INFO:nncf:Not adding activation input quantizer for operation: 1867 linear_207
# INFO:nncf:Not adding activation input quantizer for operation: 1870 linear_208
# INFO:nncf:Not adding activation input quantizer for operation: 1873 linear_209
# INFO:nncf:Not adding activation input quantizer for operation: 1886 linear_210
# 1888 add_tensor_93
# 1890 div_46
#
# INFO:nncf:Not adding activation input quantizer for operation: 1897 linear_211
# INFO:nncf:Not adding activation input quantizer for operation: 1916 linear_214
# 1918 add_tensor_94
# 1920 div_47
#
# INFO:nncf:Not adding activation input quantizer for operation: 1927 linear_215
# 1929 add_tensor_95
#
# INFO:nncf:Not adding activation input quantizer for operation: 1938 linear_216
# 1940 add_tensor_96
#
# INFO:nncf:Not adding activation input quantizer for operation: 1947 linear_217
# INFO:nncf:Not adding activation input quantizer for operation: 1950 linear_218
# INFO:nncf:Not adding activation input quantizer for operation: 1953 linear_219
# INFO:nncf:Not adding activation input quantizer for operation: 1966 linear_220
# 1968 add_tensor_97
# 1970 div_48
#
# INFO:nncf:Not adding activation input quantizer for operation: 1977 linear_221
# INFO:nncf:Not adding activation input quantizer for operation: 1996 linear_224
# 1998 add_tensor_98
# 2000 div_49
#
# INFO:nncf:Not adding activation input quantizer for operation: 2007 linear_225
# 2009 add_tensor_99
#
# INFO:nncf:Not adding activation input quantizer for operation: 2018 linear_226
# 2020 add_tensor_100
#
# INFO:nncf:Not adding activation input quantizer for operation: 2027 linear_227
# INFO:nncf:Not adding activation input quantizer for operation: 2030 linear_228
# INFO:nncf:Not adding activation input quantizer for operation: 2033 linear_229
# INFO:nncf:Not adding activation input quantizer for operation: 2046 linear_230
# 2048 add_tensor_101
# 2050 div_50
#
# INFO:nncf:Not adding activation input quantizer for operation: 2057 linear_231
# INFO:nncf:Not adding activation input quantizer for operation: 2076 linear_234
# 2078 add_tensor_102
# 2080 div_51
#
# INFO:nncf:Not adding activation input quantizer for operation: 2087 linear_235
# 2089 add_tensor_103
#
# INFO:nncf:Not adding activation input quantizer for operation: 2098 linear_236
# 2100 add_tensor_104
#
# INFO:nncf:Not adding activation input quantizer for operation: 2107 linear_237
# INFO:nncf:Not adding activation input quantizer for operation: 2110 linear_238
# INFO:nncf:Not adding activation input quantizer for operation: 2113 linear_239
# INFO:nncf:Not adding activation input quantizer for operation: 2126 linear_240
# 2128 add_tensor_105
# 2130 div_52
#
# INFO:nncf:Not adding activation input quantizer for operation: 2137 linear_241
# INFO:nncf:Not adding activation input quantizer for operation: 2156 linear_244
# 2158 add_tensor_106
# 2160 div_53
#
# INFO:nncf:Not adding activation input quantizer for operation: 2167 linear_245
# 2169 add_tensor_107
#
# INFO:nncf:Not adding activation input quantizer for operation: 2178 linear_246
# 2180 add_tensor_108
#
# INFO:nncf:Not adding activation input quantizer for operation: 2187 linear_247
# INFO:nncf:Not adding activation input quantizer for operation: 2190 linear_248
# INFO:nncf:Not adding activation input quantizer for operation: 2193 linear_249
# INFO:nncf:Not adding activation input quantizer for operation: 2206 linear_250
# 2208 add_tensor_109
# 2210 div_54
#
# INFO:nncf:Not adding activation input quantizer for operation: 2217 linear_251
# INFO:nncf:Not adding activation input quantizer for operation: 2236 linear_254
# 2238 add_tensor_110
# 2240 div_55
#
# INFO:nncf:Not adding activation input quantizer for operation: 2247 linear_255
# 2249 add_tensor_111
#
# INFO:nncf:Not adding activation input quantizer for operation: 2258 linear_256
# 2260 add_tensor_112
#
# INFO:nncf:Not adding activation input quantizer for operation: 2264 linear_257
# 2266 add_tensor_113
#
# INFO:nncf:Not adding activation input quantizer for operation: 2308 linear_259
# 2310 add_tensor_115
#
# INFO:nncf:Not adding activation input quantizer for operation: 2316 linear_260
# INFO:nncf:Not adding activation input quantizer for operation: 2319 linear_261
# INFO:nncf:Not adding activation input quantizer for operation: 2322 linear_262
# INFO:nncf:Not adding activation input quantizer for operation: 2335 linear_263
# 2337 add_tensor_116
# 2339 div_57
#
# INFO:nncf:Not adding activation input quantizer for operation: 2346 linear_264
# INFO:nncf:Not adding activation input quantizer for operation: 2365 linear_267
# 2367 add_tensor_117
# 2369 div_58
#
# INFO:nncf:Not adding activation input quantizer for operation: 2376 linear_268
# 2378 add_tensor_118
#
# INFO:nncf:Not adding activation input quantizer for operation: 2387 linear_269
# 2389 add_tensor_119
#
# INFO:nncf:Not adding activation input quantizer for operation: 2396 linear_270
# INFO:nncf:Not adding activation input quantizer for operation: 2399 linear_271
# INFO:nncf:Not adding activation input quantizer for operation: 2402 linear_272
# INFO:nncf:Not adding activation input quantizer for operation: 2415 linear_273
# 2417 add_tensor_120
# 2419 div_59
#
# INFO:nncf:Not adding activation input quantizer for operation: 2426 linear_274
# INFO:nncf:Not adding activation input quantizer for operation: 2445 linear_277
# 2447 add_tensor_121
# 2449 div_60
#
# INFO:nncf:Not adding activation input quantizer for operation: 2456 linear_278
# 2458 add_tensor_122
#
# INFO:nncf:Not adding activation input quantizer for operation: 2467 linear_279
# 2469 add_tensor_123
#
# INFO:nncf:Not adding activation input quantizer for operation: 2476 linear_280
# INFO:nncf:Not adding activation input quantizer for operation: 2479 linear_281
# INFO:nncf:Not adding activation input quantizer for operation: 2482 linear_282
# INFO:nncf:Not adding activation input quantizer for operation: 2495 linear_283
# 2497 add_tensor_124
# 2499 div_61
#
# INFO:nncf:Not adding activation input quantizer for operation: 2506 linear_284
# INFO:nncf:Not adding activation input quantizer for operation: 2525 linear_287
# 2527 add_tensor_125
# 2529 div_62
#
# INFO:nncf:Not adding activation input quantizer for operation: 2536 linear_288
# 2538 add_tensor_126
#
# INFO:nncf:Not adding activation input quantizer for operation: 2547 linear_289
# 2549 add_tensor_127
#
# INFO:nncf:Not adding activation input quantizer for operation: 2556 linear_290
# INFO:nncf:Not adding activation input quantizer for operation: 2559 linear_291
# INFO:nncf:Not adding activation input quantizer for operation: 2562 linear_292
# INFO:nncf:Not adding activation input quantizer for operation: 2575 linear_293
# 2577 add_tensor_128
# 2579 div_63
#
# INFO:nncf:Not adding activation input quantizer for operation: 2586 linear_294
# INFO:nncf:Not adding activation input quantizer for operation: 2605 linear_297
# 2607 add_tensor_129
# 2609 div_64
#
# INFO:nncf:Not adding activation input quantizer for operation: 2616 linear_298
# 2618 add_tensor_130
#
# INFO:nncf:Not adding activation input quantizer for operation: 2627 linear_299
# 2629 add_tensor_131
#
# INFO:nncf:Not adding activation input quantizer for operation: 2636 linear_300
# INFO:nncf:Not adding activation input quantizer for operation: 2639 linear_301
# INFO:nncf:Not adding activation input quantizer for operation: 2642 linear_302
# INFO:nncf:Not adding activation input quantizer for operation: 2655 linear_303
# 2657 add_tensor_132
# 2659 div_65
#
# INFO:nncf:Not adding activation input quantizer for operation: 2666 linear_304
# INFO:nncf:Not adding activation input quantizer for operation: 2685 linear_307
# 2687 add_tensor_133
# 2689 div_66
#
# INFO:nncf:Not adding activation input quantizer for operation: 2696 linear_308
# 2698 add_tensor_134
#
# INFO:nncf:Not adding activation input quantizer for operation: 2707 linear_309
# 2709 add_tensor_135
#
# INFO:nncf:Not adding activation input quantizer for operation: 2716 linear_310
# INFO:nncf:Not adding activation input quantizer for operation: 2719 linear_311
# INFO:nncf:Not adding activation input quantizer for operation: 2722 linear_312
# INFO:nncf:Not adding activation input quantizer for operation: 2735 linear_313
# 2737 add_tensor_136
# 2739 div_67
#
# INFO:nncf:Not adding activation input quantizer for operation: 2746 linear_314
# INFO:nncf:Not adding activation input quantizer for operation: 2765 linear_317
# 2767 add_tensor_137
# 2769 div_68
#
# INFO:nncf:Not adding activation input quantizer for operation: 2776 linear_318
# 2778 add_tensor_138
#
# INFO:nncf:Not adding activation input quantizer for operation: 2787 linear_319
# 2789 add_tensor_139
#
# INFO:nncf:Not adding activation input quantizer for operation: 2796 linear_320
# INFO:nncf:Not adding activation input quantizer for operation: 2799 linear_321
# INFO:nncf:Not adding activation input quantizer for operation: 2802 linear_322
# INFO:nncf:Not adding activation input quantizer for operation: 2815 linear_323
# 2817 add_tensor_140
# 2819 div_69
#
# INFO:nncf:Not adding activation input quantizer for operation: 2826 linear_324
# INFO:nncf:Not adding activation input quantizer for operation: 2845 linear_327
# 2847 add_tensor_141
# 2849 div_70
#
# INFO:nncf:Not adding activation input quantizer for operation: 2856 linear_328
# 2858 add_tensor_142
#
# INFO:nncf:Not adding activation input quantizer for operation: 2867 linear_329
# 2869 add_tensor_143
#
# INFO:nncf:Not adding activation input quantizer for operation: 2876 linear_330
# INFO:nncf:Not adding activation input quantizer for operation: 2879 linear_331
# INFO:nncf:Not adding activation input quantizer for operation: 2882 linear_332
# INFO:nncf:Not adding activation input quantizer for operation: 2895 linear_333
# 2897 add_tensor_144
# 2899 div_71
#
# INFO:nncf:Not adding activation input quantizer for operation: 2906 linear_334
# INFO:nncf:Not adding activation input quantizer for operation: 2925 linear_337
# 2927 add_tensor_145
# 2929 div_72
#
# INFO:nncf:Not adding activation input quantizer for operation: 2936 linear_338
# 2938 add_tensor_146
#
# INFO:nncf:Not adding activation input quantizer for operation: 2947 linear_339
# 2949 add_tensor_147
#
# INFO:nncf:Not adding activation input quantizer for operation: 2956 linear_340
# INFO:nncf:Not adding activation input quantizer for operation: 2959 linear_341
# INFO:nncf:Not adding activation input quantizer for operation: 2962 linear_342
# INFO:nncf:Not adding activation input quantizer for operation: 2975 linear_343
# 2977 add_tensor_148
# 2979 div_73
#
# INFO:nncf:Not adding activation input quantizer for operation: 2986 linear_344
# INFO:nncf:Not adding activation input quantizer for operation: 3005 linear_347
# 3007 add_tensor_149
# 3009 div_74
#
# INFO:nncf:Not adding activation input quantizer for operation: 3016 linear_348
# 3018 add_tensor_150
#
# INFO:nncf:Not adding activation input quantizer for operation: 3027 linear_349
# 3029 add_tensor_151
#
# INFO:nncf:Not adding activation input quantizer for operation: 3036 linear_350
# INFO:nncf:Not adding activation input quantizer for operation: 3039 linear_351
# INFO:nncf:Not adding activation input quantizer for operation: 3042 linear_352
# INFO:nncf:Not adding activation input quantizer for operation: 3055 linear_353
# 3057 add_tensor_152
# 3059 div_75
#
# INFO:nncf:Not adding activation input quantizer for operation: 3066 linear_354
# INFO:nncf:Not adding activation input quantizer for operation: 3085 linear_357
# 3087 add_tensor_153
# 3089 div_76
#
# INFO:nncf:Not adding activation input quantizer for operation: 3096 linear_358
# 3098 add_tensor_154
#
# INFO:nncf:Not adding activation input quantizer for operation: 3107 linear_359
# 3109 add_tensor_155
#
# INFO:nncf:Not adding activation input quantizer for operation: 3113 linear_360
# 3115 add_tensor_156
#
# INFO:nncf:Not adding activation input quantizer for operation: 3192 linear_363
# 3194 add_tensor_159
#
# INFO:nncf:Not adding activation input quantizer for operation: 3200 linear_364
# INFO:nncf:Not adding activation input quantizer for operation: 3203 linear_365
# INFO:nncf:Not adding activation input quantizer for operation: 3206 linear_366
# INFO:nncf:Not adding activation input quantizer for operation: 3219 linear_367
# 3221 add_tensor_160
# 3223 div_79
#
# INFO:nncf:Not adding activation input quantizer for operation: 3230 linear_368
# INFO:nncf:Not adding activation input quantizer for operation: 3249 linear_371
# 3251 add_tensor_161
# 3253 div_80
#
# INFO:nncf:Not adding activation input quantizer for operation: 3260 linear_372
# 3262 add_tensor_162
#
# INFO:nncf:Not adding activation input quantizer for operation: 3271 linear_373
# 3273 add_tensor_163
#
# INFO:nncf:Not adding activation input quantizer for operation: 3280 linear_374
# INFO:nncf:Not adding activation input quantizer for operation: 3283 linear_375
# INFO:nncf:Not adding activation input quantizer for operation: 3286 linear_376
# INFO:nncf:Not adding activation input quantizer for operation: 3299 linear_377
# 3301 add_tensor_164
# 3303 div_81
#
# INFO:nncf:Not adding activation input quantizer for operation: 3310 linear_378
# INFO:nncf:Not adding activation input quantizer for operation: 3329 linear_381
# 3331 add_tensor_165
# 3333 div_82
#
# INFO:nncf:Not adding activation input quantizer for operation: 3340 linear_382
# 3342 add_tensor_166
#
# INFO:nncf:Not adding activation input quantizer for operation: 3351 linear_383
# 3353 add_tensor_167
#
# INFO:nncf:Not adding activation input quantizer for operation: 3360 linear_384
# INFO:nncf:Not adding activation input quantizer for operation: 3363 linear_385
# INFO:nncf:Not adding activation input quantizer for operation: 3366 linear_386
# INFO:nncf:Not adding activation input quantizer for operation: 3379 linear_387
# 3381 add_tensor_168
# 3383 div_83
#
# INFO:nncf:Not adding activation input quantizer for operation: 3390 linear_388
# INFO:nncf:Not adding activation input quantizer for operation: 3409 linear_391
# 3411 add_tensor_169
# 3413 div_84
#
# INFO:nncf:Not adding activation input quantizer for operation: 3420 linear_392
# 3422 add_tensor_170
#
# INFO:nncf:Not adding activation input quantizer for operation: 3431 linear_393
# 3433 add_tensor_171
#
# INFO:nncf:Not adding activation input quantizer for operation: 3440 linear_394
# INFO:nncf:Not adding activation input quantizer for operation: 3443 linear_395
# INFO:nncf:Not adding activation input quantizer for operation: 3446 linear_396
# INFO:nncf:Not adding activation input quantizer for operation: 3459 linear_397
# 3461 add_tensor_172
# 3463 div_85
#
# INFO:nncf:Not adding activation input quantizer for operation: 3470 linear_398
# INFO:nncf:Not adding activation input quantizer for operation: 3489 linear_401
# 3491 add_tensor_173
# 3493 div_86
#
# INFO:nncf:Not adding activation input quantizer for operation: 3500 linear_402
# 3502 add_tensor_174
#
# INFO:nncf:Not adding activation input quantizer for operation: 3511 linear_403
# 3513 add_tensor_175
#
# INFO:nncf:Not adding activation input quantizer for operation: 3520 linear_404
# INFO:nncf:Not adding activation input quantizer for operation: 3523 linear_405
# INFO:nncf:Not adding activation input quantizer for operation: 3526 linear_406
# INFO:nncf:Not adding activation input quantizer for operation: 3539 linear_407
# 3541 add_tensor_176
# 3543 div_87
#
# INFO:nncf:Not adding activation input quantizer for operation: 3550 linear_408
# INFO:nncf:Not adding activation input quantizer for operation: 3569 linear_411
# 3571 add_tensor_177
# 3573 div_88
#
# INFO:nncf:Not adding activation input quantizer for operation: 3580 linear_412
# 3582 add_tensor_178
#
# INFO:nncf:Not adding activation input quantizer for operation: 3591 linear_413
# 3593 add_tensor_179
#
# INFO:nncf:Not adding activation input quantizer for operation: 3600 linear_414
# INFO:nncf:Not adding activation input quantizer for operation: 3603 linear_415
# INFO:nncf:Not adding activation input quantizer for operation: 3606 linear_416
# INFO:nncf:Not adding activation input quantizer for operation: 3619 linear_417
# 3621 add_tensor_180
# 3623 div_89
#
# INFO:nncf:Not adding activation input quantizer for operation: 3630 linear_418
# INFO:nncf:Not adding activation input quantizer for operation: 3649 linear_421
# 3651 add_tensor_181
# 3653 div_90
#
# INFO:nncf:Not adding activation input quantizer for operation: 3660 linear_422
# 3662 add_tensor_182
#
# INFO:nncf:Not adding activation input quantizer for operation: 3671 linear_423
# 3673 add_tensor_183
#
# INFO:nncf:Not adding activation input quantizer for operation: 3680 linear_424
# INFO:nncf:Not adding activation input quantizer for operation: 3683 linear_425
# INFO:nncf:Not adding activation input quantizer for operation: 3686 linear_426
# INFO:nncf:Not adding activation input quantizer for operation: 3699 linear_427
# 3701 add_tensor_184
# 3703 div_91
#
# INFO:nncf:Not adding activation input quantizer for operation: 3710 linear_428
# INFO:nncf:Not adding activation input quantizer for operation: 3729 linear_431
# 3731 add_tensor_185
# 3733 div_92
#
# INFO:nncf:Not adding activation input quantizer for operation: 3740 linear_432
# 3742 add_tensor_186
#
# INFO:nncf:Not adding activation input quantizer for operation: 3751 linear_433
# 3753 add_tensor_187
#
# INFO:nncf:Not adding activation input quantizer for operation: 3760 linear_434
# INFO:nncf:Not adding activation input quantizer for operation: 3763 linear_435
# INFO:nncf:Not adding activation input quantizer for operation: 3766 linear_436
# INFO:nncf:Not adding activation input quantizer for operation: 3779 linear_437
# 3781 add_tensor_188
# 3783 div_93
#
# INFO:nncf:Not adding activation input quantizer for operation: 3790 linear_438
# INFO:nncf:Not adding activation input quantizer for operation: 3809 linear_441
# 3811 add_tensor_189
# 3813 div_94
#
# INFO:nncf:Not adding activation input quantizer for operation: 3820 linear_442
# 3822 add_tensor_190
#
# INFO:nncf:Not adding activation input quantizer for operation: 3831 linear_443
# 3833 add_tensor_191
#
# INFO:nncf:Not adding activation input quantizer for operation: 3840 linear_444
# INFO:nncf:Not adding activation input quantizer for operation: 3843 linear_445
# INFO:nncf:Not adding activation input quantizer for operation: 3846 linear_446
# INFO:nncf:Not adding activation input quantizer for operation: 3859 linear_447
# 3861 add_tensor_192
# 3863 div_95
#
# INFO:nncf:Not adding activation input quantizer for operation: 3870 linear_448
# INFO:nncf:Not adding activation input quantizer for operation: 3889 linear_451
# 3891 add_tensor_193
# 3893 div_96
#
# INFO:nncf:Not adding activation input quantizer for operation: 3900 linear_452
# 3902 add_tensor_194
#
# INFO:nncf:Not adding activation input quantizer for operation: 3911 linear_453
# 3913 add_tensor_195
#
# INFO:nncf:Not adding activation input quantizer for operation: 3920 linear_454
# INFO:nncf:Not adding activation input quantizer for operation: 3923 linear_455
# INFO:nncf:Not adding activation input quantizer for operation: 3926 linear_456
# INFO:nncf:Not adding activation input quantizer for operation: 3939 linear_457
# 3941 add_tensor_196
# 3943 div_97
#
# INFO:nncf:Not adding activation input quantizer for operation: 3950 linear_458
# INFO:nncf:Not adding activation input quantizer for operation: 3969 linear_461
# 3971 add_tensor_197
# 3973 div_98
#
# INFO:nncf:Not adding activation input quantizer for operation: 3980 linear_462
# 3982 add_tensor_198
#
# INFO:nncf:Not adding activation input quantizer for operation: 3991 linear_463
# 3993 add_tensor_199
#
# ...
# INFO:nncf:Not adding activation input quantizer for operation: 4537 linear_528
# INFO:nncf:Not adding activation input quantizer for operation: 4540 linear_529
# INFO:nncf:Not adding activation input quantizer for operation: 4553 linear_530
# 4555 add_tensor_227
# 4557 div_112
#
# INFO:nncf:Not adding activation input quantizer for operation: 4564 linear_531
# INFO:nncf:Not adding activation input quantizer for operation: 4583 linear_534
# 4585 add_tensor_228
# 4587 div_113
#
# INFO:nncf:Not adding activation input quantizer for operation: 4594 linear_535
# 4596 add_tensor_229
#
# INFO:nncf:Not adding activation input quantizer for operation: 4605 linear_536
# 4607 add_tensor_230
#
# INFO:nncf:Not adding activation input quantizer for operation: 4614 linear_537
# INFO:nncf:Not adding activation input quantizer for operation: 4617 linear_538
# INFO:nncf:Not adding activation input quantizer for operation: 4620 linear_539
# INFO:nncf:Not adding activation input quantizer for operation: 4633 linear_540
# 4635 add_tensor_231
# 4637 div_114
#
# INFO:nncf:Not adding activation input quantizer for operation: 4644 linear_541
# INFO:nncf:Not adding activation input quantizer for operation: 4663 linear_544
# 4665 add_tensor_232
# 4667 div_115
#
# INFO:nncf:Not adding activation input quantizer for operation: 4674 linear_545
# 4676 add_tensor_233
#
# INFO:nncf:Not adding activation input quantizer for operation: 4685 linear_546
# 4687 add_tensor_234
#
# INFO:nncf:Not adding activation input quantizer for operation: 4694 linear_547
# INFO:nncf:Not adding activation input quantizer for operation: 4697 linear_548
# INFO:nncf:Not adding activation input quantizer for operation: 4700 linear_549
# INFO:nncf:Not adding activation input quantizer for operation: 4713 linear_550
# 4715 add_tensor_235
# 4717 div_116
#
# INFO:nncf:Not adding activation input quantizer for operation: 4724 linear_551
# INFO:nncf:Not adding activation input quantizer for operation: 4743 linear_554
# 4745 add_tensor_236
# 4747 div_117
#
# INFO:nncf:Not adding activation input quantizer for operation: 4754 linear_555
# 4756 add_tensor_237
#
# INFO:nncf:Not adding activation input quantizer for operation: 4765 linear_556
# 4767 add_tensor_238
#
# INFO:nncf:Not adding activation input quantizer for operation: 4774 linear_557
# INFO:nncf:Not adding activation input quantizer for operation: 4777 linear_558
# INFO:nncf:Not adding activation input quantizer for operation: 4780 linear_559
# INFO:nncf:Not adding activation input quantizer for operation: 4793 linear_560
# 4795 add_tensor_239
# 4797 div_118
#
# INFO:nncf:Not adding activation input quantizer for operation: 4804 linear_561
# INFO:nncf:Not adding activation input quantizer for operation: 4823 linear_564
# 4825 add_tensor_240
# 4827 div_119
#
# INFO:nncf:Not adding activation input quantizer for operation: 4834 linear_565
# 4836 add_tensor_241
#
# INFO:nncf:Not adding activation input quantizer for operation: 4845 linear_566
# 4847 add_tensor_242
#
# INFO:nncf:Not adding activation input quantizer for operation: 4851 linear_567
# 4853 add_tensor_243
#
# INFO:nncf:Not adding activation input quantizer for operation: 4900 linear_569
# 4902 add_tensor_245
#
# INFO:nncf:Not adding activation input quantizer for operation: 4908 linear_570
# INFO:nncf:Not adding activation input quantizer for operation: 4911 linear_571
# INFO:nncf:Not adding activation input quantizer for operation: 4914 linear_572
# INFO:nncf:Not adding activation input quantizer for operation: 4927 linear_573
# 4929 add_tensor_246
# 4931 div_121
#
# INFO:nncf:Not adding activation input quantizer for operation: 4938 linear_574
# INFO:nncf:Not adding activation input quantizer for operation: 4957 linear_577
# 4959 add_tensor_247
# 4961 div_122
#
# INFO:nncf:Not adding activation input quantizer for operation: 4968 linear_578
# 4970 add_tensor_248
#
# INFO:nncf:Not adding activation input quantizer for operation: 4979 linear_579
# 4981 add_tensor_249
#
# INFO:nncf:Not adding activation input quantizer for operation: 4988 linear_580
# INFO:nncf:Not adding activation input quantizer for operation: 4991 linear_581
# INFO:nncf:Not adding activation input quantizer for operation: 4994 linear_582
# INFO:nncf:Not adding activation input quantizer for operation: 5007 linear_583
# 5009 add_tensor_250
# 5011 div_123
#
# INFO:nncf:Not adding activation input quantizer for operation: 5018 linear_584
# INFO:nncf:Not adding activation input quantizer for operation: 5037 linear_587
# 5039 add_tensor_251
# 5041 div_124
#
# INFO:nncf:Not adding activation input quantizer for operation: 5048 linear_588
# 5050 add_tensor_252
#
# INFO:nncf:Not adding activation input quantizer for operation: 5059 linear_589
# 5061 add_tensor_253
#
# INFO:nncf:Not adding activation input quantizer for operation: 5068 linear_590
# INFO:nncf:Not adding activation input quantizer for operation: 5071 linear_591
# INFO:nncf:Not adding activation input quantizer for operation: 5074 linear_592
# INFO:nncf:Not adding activation input quantizer for operation: 5087 linear_593
# 5089 add_tensor_254
# 5091 div_125
#
# INFO:nncf:Not adding activation input quantizer for operation: 5098 linear_594
# INFO:nncf:Not adding activation input quantizer for operation: 5117 linear_597
# 5119 add_tensor_255
# 5121 div_126
#
# INFO:nncf:Not adding activation input quantizer for operation: 5128 linear_598
# 5130 add_tensor_256
#
# INFO:nncf:Not adding activation input quantizer for operation: 5139 linear_599
# 5141 add_tensor_257
#
# INFO:nncf:Not adding activation input quantizer for operation: 5148 linear_600
# INFO:nncf:Not adding activation input quantizer for operation: 5151 linear_601
# INFO:nncf:Not adding activation input quantizer for operation: 5154 linear_602
# INFO:nncf:Not adding activation input quantizer for operation: 5167 linear_603
# 5169 add_tensor_258
# 5171 div_127
#
# INFO:nncf:Not adding activation input quantizer for operation: 5178 linear_604
# INFO:nncf:Not adding activation input quantizer for operation: 5197 linear_607
# 5199 add_tensor_259
# 5201 div_128
#
# INFO:nncf:Not adding activation input quantizer for operation: 5208 linear_608
# 5210 add_tensor_260
#
# INFO:nncf:Not adding activation input quantizer for operation: 5219 linear_609
# 5221 add_tensor_261
#
# INFO:nncf:Not adding activation input quantizer for operation: 5228 linear_610
# INFO:nncf:Not adding activation input quantizer for operation: 5231 linear_611
# INFO:nncf:Not adding activation input quantizer for operation: 5234 linear_612
# INFO:nncf:Not adding activation input quantizer for operation: 5247 linear_613
# 5249 add_tensor_262
# 5251 div_129
#
# INFO:nncf:Not adding activation input quantizer for operation: 5258 linear_614
# INFO:nncf:Not adding activation input quantizer for operation: 5277 linear_617
# 5279 add_tensor_263
# 5281 div_130
#
# INFO:nncf:Not adding activation input quantizer for operation: 5288 linear_618
# 5290 add_tensor_264
#
# INFO:nncf:Not adding activation input quantizer for operation: 5299 linear_619
# 5301 add_tensor_265
#
# INFO:nncf:Not adding activation input quantizer for operation: 5308 linear_620
# INFO:nncf:Not adding activation input quantizer for operation: 5311 linear_621
# INFO:nncf:Not adding activation input quantizer for operation: 5314 linear_622
# INFO:nncf:Not adding activation input quantizer for operation: 5327 linear_623
# 5329 add_tensor_266
# 5331 div_131
#
# INFO:nncf:Not adding activation input quantizer for operation: 5338 linear_624
# INFO:nncf:Not adding activation input quantizer for operation: 5357 linear_627
# 5359 add_tensor_267
# 5361 div_132
#
# INFO:nncf:Not adding activation input quantizer for operation: 5368 linear_628
# 5370 add_tensor_268
#
# INFO:nncf:Not adding activation input quantizer for operation: 5379 linear_629
# 5381 add_tensor_269
#
# INFO:nncf:Not adding activation input quantizer for operation: 5388 linear_630
# INFO:nncf:Not adding activation input quantizer for operation: 5391 linear_631
# INFO:nncf:Not adding activation input quantizer for operation: 5394 linear_632
# INFO:nncf:Not adding activation input quantizer for operation: 5407 linear_633
# 5409 add_tensor_270
# 5411 div_133
#
# INFO:nncf:Not adding activation input quantizer for operation: 5418 linear_634
# INFO:nncf:Not adding activation input quantizer for operation: 5437 linear_637
# 5439 add_tensor_271
# 5441 div_134
#
# INFO:nncf:Not adding activation input quantizer for operation: 5448 linear_638
# 5450 add_tensor_272
#
# INFO:nncf:Not adding activation input quantizer for operation: 5459 linear_639
# 5461 add_tensor_273
#
# INFO:nncf:Not adding activation input quantizer for operation: 5468 linear_640
# INFO:nncf:Not adding activation input quantizer for operation: 5471 linear_641
# INFO:nncf:Not adding activation input quantizer for operation: 5474 linear_642
# INFO:nncf:Not adding activation input quantizer for operation: 5487 linear_643
# 5489 add_tensor_274
# 5491 div_135
#
# INFO:nncf:Not adding activation input quantizer for operation: 5498 linear_644
# INFO:nncf:Not adding activation input quantizer for operation: 5517 linear_647
# 5519 add_tensor_275
# 5521 div_136
#
# INFO:nncf:Not adding activation input quantizer for operation: 5528 linear_648
# 5530 add_tensor_276
#
# INFO:nncf:Not adding activation input quantizer for operation: 5539 linear_649
# 5541 add_tensor_277
#
# INFO:nncf:Not adding activation input quantizer for operation: 5548 linear_650
# INFO:nncf:Not adding activation input quantizer for operation: 5551 linear_651
# INFO:nncf:Not adding activation input quantizer for operation: 5554 linear_652
# INFO:nncf:Not adding activation input quantizer for operation: 5567 linear_653
# 5569 add_tensor_278
# 5571 div_137
#
# INFO:nncf:Not adding activation input quantizer for operation: 5578 linear_654
# INFO:nncf:Not adding activation input quantizer for operation: 5597 linear_657
# 5599 add_tensor_279
# 5601 div_138
#
# INFO:nncf:Not adding activation input quantizer for operation: 5608 linear_658
# 5610 add_tensor_280
#
# INFO:nncf:Not adding activation input quantizer for operation: 5619 linear_659
# 5621 add_tensor_281
#
# INFO:nncf:Not adding activation input quantizer for operation: 5628 linear_660
# INFO:nncf:Not adding activation input quantizer for operation: 5631 linear_661
# INFO:nncf:Not adding activation input quantizer for operation: 5634 linear_662
# INFO:nncf:Not adding activation input quantizer for operation: 5647 linear_663
# 5649 add_tensor_282
# 5651 div_139
#
# INFO:nncf:Not adding activation input quantizer for operation: 5658 linear_664
# INFO:nncf:Not adding activation input quantizer for operation: 5677 linear_667
# 5679 add_tensor_283
# 5681 div_140
#
# INFO:nncf:Not adding activation input quantizer for operation: 5688 linear_668
# 5690 add_tensor_284
#
# INFO:nncf:Not adding activation input quantizer for operation: 5699 linear_669
# 5701 add_tensor_285
#
# INFO:nncf:Not adding activation input quantizer for operation: 5705 linear_670
# 5707 add_tensor_286
#
# INFO:nncf:Not adding activation input quantizer for operation: 5759 linear_672
# 5761 add_tensor_288
#
# INFO:nncf:Not adding activation input quantizer for operation: 5767 linear_673
# INFO:nncf:Not adding activation input quantizer for operation: 5770 linear_674
# INFO:nncf:Not adding activation input quantizer for operation: 5773 linear_675
# INFO:nncf:Not adding activation input quantizer for operation: 5786 linear_676
# 5788 add_tensor_289
# 5790 div_142
#
# INFO:nncf:Not adding activation input quantizer for operation: 5797 linear_677
# INFO:nncf:Not adding activation input quantizer for operation: 5816 linear_680
# 5818 add_tensor_290
# 5820 div_143
#
# INFO:nncf:Not adding activation input quantizer for operation: 5827 linear_681
# 5829 add_tensor_291
#
# INFO:nncf:Not adding activation input quantizer for operation: 5838 linear_682
# 5840 add_tensor_292
#
# INFO:nncf:Not adding activation input quantizer for operation: 5847 linear_683
# INFO:nncf:Not adding activation input quantizer for operation: 5850 linear_684
# INFO:nncf:Not adding activation input quantizer for operation: 5853 linear_685
# INFO:nncf:Not adding activation input quantizer for operation: 5866 linear_686
# 5868 add_tensor_293
# 5870 div_144
#
# INFO:nncf:Not adding activation input quantizer for operation: 5877 linear_687
# INFO:nncf:Not adding activation input quantizer for operation: 5896 linear_690
# 5898 add_tensor_294
# 5900 div_145
#
# INFO:nncf:Not adding activation input quantizer for operation: 5907 linear_691
# 5909 add_tensor_295
#
# INFO:nncf:Not adding activation input quantizer for operation: 5918 linear_692
# 5920 add_tensor_296
#
# INFO:nncf:Not adding activation input quantizer for operation: 5924 linear_693
# 5926 add_tensor_297
#
# INFO:nncf:Not adding activation input quantizer for operation: 5973 linear_695
# 5975 add_tensor_299
#
# INFO:nncf:Not adding activation input quantizer for operation: 5981 linear_696
# INFO:nncf:Not adding activation input quantizer for operation: 5984 linear_697
# INFO:nncf:Not adding activation input quantizer for operation: 5987 linear_698
# INFO:nncf:Not adding activation input quantizer for operation: 6000 linear_699
# 6002 add_tensor_300
# 6004 div_147
#
# INFO:nncf:Not adding activation input quantizer for operation: 6011 linear_700
# INFO:nncf:Not adding activation input quantizer for operation: 6030 linear_703
# 6032 add_tensor_301
# 6034 div_148
#
# INFO:nncf:Not adding activation input quantizer for operation: 6041 linear_704
# 6043 add_tensor_302
#
# INFO:nncf:Not adding activation input quantizer for operation: 6052 linear_705
# 6054 add_tensor_303
#
# INFO:nncf:Not adding activation input quantizer for operation: 6061 linear_706
# INFO:nncf:Not adding activation input quantizer for operation: 6064 linear_707
# INFO:nncf:Not adding activation input quantizer for operation: 6067 linear_708
# INFO:nncf:Not adding activation input quantizer for operation: 6080 linear_709
# 6082 add_tensor_304
# 6084 div_149
#
# INFO:nncf:Not adding activation input quantizer for operation: 6091 linear_710
# INFO:nncf:Not adding activation input quantizer for operation: 6110 linear_713
# 6112 add_tensor_305
# 6114 div_150
#
# INFO:nncf:Not adding activation input quantizer for operation: 6121 linear_714
# 6123 add_tensor_306
#
# INFO:nncf:Not adding activation input quantizer for operation: 6132 linear_715
# 6134 add_tensor_307
#
# INFO:nncf:Not adding activation input quantizer for operation: 6138 linear_716
# 6140 add_tensor_308
#
# INFO:nncf:Not adding activation input quantizer for operation: 6187 linear_718
# 6189 add_tensor_310
#
# INFO:nncf:Not adding activation input quantizer for operation: 6195 linear_719
# INFO:nncf:Not adding activation input quantizer for operation: 6198 linear_720
# INFO:nncf:Not adding activation input quantizer for operation: 6201 linear_721
# INFO:nncf:Not adding activation input quantizer for operation: 6214 linear_722
# 6216 add_tensor_311
# 6218 div_152
#
# INFO:nncf:Not adding activation input quantizer for operation: 6225 linear_723
# INFO:nncf:Not adding activation input quantizer for operation: 6244 linear_726
# 6246 add_tensor_312
# 6248 div_153
#
# INFO:nncf:Not adding activation input quantizer for operation: 6255 linear_727
# 6257 add_tensor_313
#
# INFO:nncf:Not adding activation input quantizer for operation: 6266 linear_728
# 6268 add_tensor_314
#
# INFO:nncf:Not adding activation input quantizer for operation: 6275 linear_729
# INFO:nncf:Not adding activation input quantizer for operation: 6278 linear_730
# INFO:nncf:Not adding activation input quantizer for operation: 6281 linear_731
# INFO:nncf:Not adding activation input quantizer for operation: 6294 linear_732
# 6296 add_tensor_315
# 6298 div_154
#
# INFO:nncf:Not adding activation input quantizer for operation: 6305 linear_733
# INFO:nncf:Not adding activation input quantizer for operation: 6324 linear_736
# 6326 add_tensor_316
# 6328 div_155
#
# INFO:nncf:Not adding activation input quantizer for operation: 6335 linear_737
# 6337 add_tensor_317
#
# INFO:nncf:Not adding activation input quantizer for operation: 6346 linear_738
# 6348 add_tensor_318
#
# INFO:nncf:Not adding activation input quantizer for operation: 6352 linear_739
# 6354 add_tensor_319
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ### Compile Models with OV Backend

# %%
pipe.unet = torch.compile(quantized_unet, backend='openvino')
del quantized_unet

# %%
def get_model_size(model):
    param_size = 0
    for param in model.parameters():
        param_size += param.nelement() * param.element_size()
    buffer_size = 0
    for buffer in model.buffers():
        buffer_size += buffer.nelement() * buffer.element_size()

    model_size_mb = (param_size + buffer_size) / 1024**2

    return model_size_mb

get_model_size(pipe.unet)
# Out:
# 3410.9036712646484

# %% [markdown]
# ### Inference for Compilation

# %%
#Warmup the model for initial compile
prompt = "cute cat 4k, high-res, masterpiece, best quality, soft lighting, dynamic angle"
# negative_prompt = "frames, borderline, text, charachter, duplicate, error, out of frame, watermark, low quality, ugly, deformed, blur"
num_steps = 1
with torch.no_grad():
    image = pipe(prompt=prompt, negative_prompt=negative_prompt, num_inference_steps=num_steps, generator=generator).images[0]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# Reached
# torch.Size([1, 4, 128, 128])

# %%
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)
with torch.no_grad():
    image = pipe(prompt=prompt, negative_prompt=negative_prompt, num_inference_steps=25).images[0]
image.show()
image.save("experiment_2_compressed.png")
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# Reached
# torch.Size([1, 4, 128, 128])
