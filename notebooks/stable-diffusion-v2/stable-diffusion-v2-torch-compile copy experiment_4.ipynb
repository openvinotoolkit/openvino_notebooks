# %% [markdown]
# # Stable Diffusion v2 Demo with Torch Compile

# %% [markdown]
# ## Stable Diffusion v2 for Text-to-Image Generation
#
# To start, let's look on Text-to-Image process for Stable Diffusion v2. We will use [Stable Diffusion v2-1](https://huggingface.co/stabilityai/stable-diffusion-2-1) model for these purposes. The main difference from Stable Diffusion v2 and Stable Diffusion v2.1 is usage of more data, more training, and less restrictive filtering of the dataset, that gives promising results for selecting wide range of input text prompts. More details about model can be found in [Stability AI blog post](https://stability.ai/blog/stablediffusion2-1-release7-dec-2022) and original model [repository](https://github.com/Stability-AI/stablediffusion).
#
# ### Stable Diffusion in Diffusers library
# To work with Stable Diffusion v2, we will use Hugging Face [Diffusers](https://github.com/huggingface/diffusers) library. To experiment with Stable Diffusion models, Diffusers exposes the [`StableDiffusionPipeline`](https://huggingface.co/docs/diffusers/using-diffusers/conditional_image_generation) similar to the [other Diffusers pipelines](https://huggingface.co/docs/diffusers/api/pipelines/overview).  The code below demonstrates how to create `StableDiffusionPipeline` using `stable-diffusion-2-1`:

# %%
from torch._export import capture_pre_autograd_graph
from nncf.torch.dynamic_graph.patch_pytorch import disable_patching
import numpy as np
# Out:
# INFO:nncf:NNCF initialized successfully. Supported frameworks detected: torch, onnx, openvino
# WARNING:nncf:NNCF provides best results with torch==2.4.*, while current torch version is 2.3.1+cpu. If you encounter issues, consider switching to torch==2.4.*

# %%
from diffusers import DiffusionPipeline
import torch
import random
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)
generator = torch.Generator(device="cpu").manual_seed(42)
pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0")
pipe.to("cpu")

prompt = "valley in the Alps at sunset, epic vista, beautiful landscape, 4k, 8k"
negative_prompt = "frames, borderline, text, charachter, duplicate, error, out of frame, watermark, low quality, ugly, deformed, blur"
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# ### Convert Models to Torch Fx Graph

# %%
text_encoder_input = torch.ones((1, 77), dtype=torch.long)
text_encoder_2_input = torch.ones((1, 77), dtype=torch.long)
vae_encoder_input = torch.ones((1, 3, 256, 256))
vae_decoder_input = torch.ones((1, 4, 128, 128))
vae_decoder_kwargs = {}
vae_decoder_kwargs["return_dict"] = False
latents_shape = (2, 4, 128, 128)
latents = torch.randn(latents_shape)
t = torch.from_numpy(np.array(1, dtype=np.float32))
added_cond_kwargs = {}
added_cond_kwargs["text_embeds"] = torch.ones((2, 1280))
added_cond_kwargs["time_ids"] = torch.ones((2,6))
unet_kwargs = {}
unet_kwargs["encoder_hidden_states"] = torch.ones((2, 77, 2048))
unet_kwargs["added_cond_kwargs"] = added_cond_kwargs
unet_kwargs["return_dict"] = False
unet_input = (latents, t)

text_encoder_kwargs = {}
text_encoder_kwargs['output_hidden_states'] = True

with torch.no_grad():
    with disable_patching():
        text_encoder = capture_pre_autograd_graph(pipe.text_encoder.eval(), args=(text_encoder_input,), kwargs=(text_encoder_kwargs))
        text_encoder_2 = capture_pre_autograd_graph(pipe.text_encoder_2.eval(), args=(text_encoder_2_input,), kwargs=(text_encoder_kwargs))
        vae_encoder = capture_pre_autograd_graph(pipe.vae.encoder, args=(vae_encoder_input,))
        vae_decoder = capture_pre_autograd_graph(pipe.vae.decoder.eval(), args=(vae_decoder_input,))
        unet = capture_pre_autograd_graph(pipe.unet.eval(), args=(*unet_input,), kwargs=(unet_kwargs))
del added_cond_kwargs
del unet_kwargs
del unet_input
del latents
del t
del vae_encoder_input
del vae_decoder_input
del text_encoder_2_input
del text_encoder_input
del text_encoder_kwargs
del vae_decoder_kwargs

# %%
pipe.text_encoder = torch.compile(text_encoder, backend='openvino')
pipe.text_encoder_2 = torch.compile(text_encoder_2, backend='openvino')
pipe.vae.decoder = torch.compile(vae_decoder, backend='openvino')
pipe.vae.encoder = torch.compile(vae_encoder, backend='openvino')
pipe.unet = unet

# %% [markdown]
# ### Weights Compression

# %%
import pickle
with open("test_faster", "rb") as fp:
    unet_calibration_data = pickle.load(fp)

def collect_ops_with_weights(graph_module):
    ops_with_weights = []
    for node in graph_module.graph.nodes:
        if "linear" in node.name:
            ops_with_weights.append(node.name)
    return ops_with_weights

unet_ignored_scope = collect_ops_with_weights(pipe.unet)

# %%
import nncf
from nncf.quantization.advanced_parameters import AdvancedSmoothQuantParameters
from nncf.quantization.range_estimator import RangeEstimatorParametersSet

def disable_progress_bar(pipeline, disable=True):
    if not hasattr(pipeline, "_progress_bar_config"):
        pipeline._progress_bar_config = {'disable': disable}
    else:
        pipeline._progress_bar_config['disable'] = disable

with disable_patching():
    with torch.no_grad():
        # compressed_unet = nncf.compress_weights(unet, ignored_scope=nncf.IgnoredScope(types=['conv2d']))
        # quantized_unet = nncf.quantize( #1
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1, disable_bias_correction=True)
        # )
        # quantized_unet = nncf.quantize( #2
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     fast_bias_correction=False,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1, disable_bias_correction=True, weights_range_estimator_params=RangeEstimatorParametersSet.MINMAX, activations_range_estimator_params=RangeEstimatorParametersSet.MINMAX)
        # )
        # quantized_unet = nncf.quantize( #3
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     fast_bias_correction=False,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1)
        # )
        quantized_unet = nncf.quantize( #4.1
            model=pipe.unet,
            calibration_dataset=nncf.Dataset(unet_calibration_data),
            subset_size=len(unet_calibration_data),
            model_type=nncf.ModelType.TRANSFORMER,
            # fast_bias_correction=False,
            ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
            advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alphas=AdvancedSmoothQuantParameters(convolution=0.95, matmul=-1), disable_bias_correction=True)
        )
        # quantized_unet = nncf.quantize( #4.2
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     fast_bias_correction=False,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alphas=AdvancedSmoothQuantParameters(convolution=0.95))
        # )
# del text_encoder
# del text_encoder_2
# del vae_decoder
del unet
# Out:
# WARNING:nncf:Experimental Torch FX quantization backend is being used for the given torch.fx.GraphModule model. Torch FX PTQ is an experimental feature, consider using Torch or OpenVino PTQ backends in case of errors or a poor model performance.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:nncf:743 ignored nodes were found by names in the NNCFGraph
# INFO:nncf:Not adding activation input quantizer for operation: 1021 linear_119
# INFO:nncf:Not adding activation input quantizer for operation: 1023 linear_120
# INFO:nncf:Not adding activation input quantizer for operation: 1091 linear_129
# INFO:nncf:Not adding activation input quantizer for operation: 1093 linear_130
# INFO:nncf:Not adding activation input quantizer for operation: 1161 linear_139
# INFO:nncf:Not adding activation input quantizer for operation: 1163 linear_140
# INFO:nncf:Not adding activation input quantizer for operation: 1231 linear_149
# INFO:nncf:Not adding activation input quantizer for operation: 1233 linear_150
# INFO:nncf:Not adding activation input quantizer for operation: 1348 linear_162
# INFO:nncf:Not adding activation input quantizer for operation: 1350 linear_163
# INFO:nncf:Not adding activation input quantizer for operation: 1418 linear_172
# INFO:nncf:Not adding activation input quantizer for operation: 1420 linear_173
# INFO:nncf:Not adding activation input quantizer for operation: 1488 linear_182
# INFO:nncf:Not adding activation input quantizer for operation: 1490 linear_183
# INFO:nncf:Not adding activation input quantizer for operation: 1558 linear_192
# INFO:nncf:Not adding activation input quantizer for operation: 1560 linear_193
# INFO:nncf:Not adding activation input quantizer for operation: 1628 linear_202
# INFO:nncf:Not adding activation input quantizer for operation: 1630 linear_203
# INFO:nncf:Not adding activation input quantizer for operation: 1698 linear_212
# INFO:nncf:Not adding activation input quantizer for operation: 1700 linear_213
# INFO:nncf:Not adding activation input quantizer for operation: 1768 linear_222
# INFO:nncf:Not adding activation input quantizer for operation: 1770 linear_223
# INFO:nncf:Not adding activation input quantizer for operation: 1838 linear_232
# INFO:nncf:Not adding activation input quantizer for operation: 1840 linear_233
# INFO:nncf:Not adding activation input quantizer for operation: 1908 linear_242
# INFO:nncf:Not adding activation input quantizer for operation: 1910 linear_243
# INFO:nncf:Not adding activation input quantizer for operation: 1978 linear_252
# INFO:nncf:Not adding activation input quantizer for operation: 1980 linear_253
# INFO:nncf:Not adding activation input quantizer for operation: 2095 linear_265
# INFO:nncf:Not adding activation input quantizer for operation: 2097 linear_266
# INFO:nncf:Not adding activation input quantizer for operation: 2165 linear_275
# INFO:nncf:Not adding activation input quantizer for operation: 2167 linear_276
# INFO:nncf:Not adding activation input quantizer for operation: 217 linear_13
# INFO:nncf:Not adding activation input quantizer for operation: 219 linear_14
# INFO:nncf:Not adding activation input quantizer for operation: 2235 linear_285
# INFO:nncf:Not adding activation input quantizer for operation: 2237 linear_286
# INFO:nncf:Not adding activation input quantizer for operation: 2305 linear_295
# INFO:nncf:Not adding activation input quantizer for operation: 2307 linear_296
# INFO:nncf:Not adding activation input quantizer for operation: 2375 linear_305
# INFO:nncf:Not adding activation input quantizer for operation: 2377 linear_306
# INFO:nncf:Not adding activation input quantizer for operation: 2445 linear_315
# INFO:nncf:Not adding activation input quantizer for operation: 2447 linear_316
# INFO:nncf:Not adding activation input quantizer for operation: 2515 linear_325
# INFO:nncf:Not adding activation input quantizer for operation: 2517 linear_326
# INFO:nncf:Not adding activation input quantizer for operation: 2585 linear_335
# INFO:nncf:Not adding activation input quantizer for operation: 2587 linear_336
# INFO:nncf:Not adding activation input quantizer for operation: 2655 linear_345
# INFO:nncf:Not adding activation input quantizer for operation: 2657 linear_346
# INFO:nncf:Not adding activation input quantizer for operation: 2725 linear_355
# INFO:nncf:Not adding activation input quantizer for operation: 2727 linear_356
# INFO:nncf:Not adding activation input quantizer for operation: 287 linear_23
# INFO:nncf:Not adding activation input quantizer for operation: 2878 linear_369
# INFO:nncf:Not adding activation input quantizer for operation: 2880 linear_370
# INFO:nncf:Not adding activation input quantizer for operation: 289 linear_24
# INFO:nncf:Not adding activation input quantizer for operation: 2948 linear_379
# INFO:nncf:Not adding activation input quantizer for operation: 2950 linear_380
# INFO:nncf:Not adding activation input quantizer for operation: 3018 linear_389
# INFO:nncf:Not adding activation input quantizer for operation: 3020 linear_390
# INFO:nncf:Not adding activation input quantizer for operation: 3088 linear_399
# INFO:nncf:Not adding activation input quantizer for operation: 3090 linear_400
# INFO:nncf:Not adding activation input quantizer for operation: 3158 linear_409
# INFO:nncf:Not adding activation input quantizer for operation: 3160 linear_410
# INFO:nncf:Not adding activation input quantizer for operation: 3228 linear_419
# INFO:nncf:Not adding activation input quantizer for operation: 3230 linear_420
# INFO:nncf:Not adding activation input quantizer for operation: 3298 linear_429
# INFO:nncf:Not adding activation input quantizer for operation: 3300 linear_430
# INFO:nncf:Not adding activation input quantizer for operation: 3368 linear_439
# INFO:nncf:Not adding activation input quantizer for operation: 3370 linear_440
# INFO:nncf:Not adding activation input quantizer for operation: 3438 linear_449
# INFO:nncf:Not adding activation input quantizer for operation: 3440 linear_450
# INFO:nncf:Not adding activation input quantizer for operation: 3508 linear_459
# INFO:nncf:Not adding activation input quantizer for operation: 3510 linear_460
# INFO:nncf:Not adding activation input quantizer for operation: 3631 linear_472
# INFO:nncf:Not adding activation input quantizer for operation: 3633 linear_473
# INFO:nncf:Not adding activation input quantizer for operation: 3701 linear_482
# INFO:nncf:Not adding activation input quantizer for operation: 3703 linear_483
# INFO:nncf:Not adding activation input quantizer for operation: 3771 linear_492
# INFO:nncf:Not adding activation input quantizer for operation: 3773 linear_493
# INFO:nncf:Not adding activation input quantizer for operation: 3841 linear_502
# INFO:nncf:Not adding activation input quantizer for operation: 3843 linear_503
# INFO:nncf:Not adding activation input quantizer for operation: 3911 linear_512
# INFO:nncf:Not adding activation input quantizer for operation: 3913 linear_513
# INFO:nncf:Not adding activation input quantizer for operation: 3981 linear_522
# INFO:nncf:Not adding activation input quantizer for operation: 3983 linear_523
# INFO:nncf:Not adding activation input quantizer for operation: 404 linear_36
# INFO:nncf:Not adding activation input quantizer for operation: 4051 linear_532
# INFO:nncf:Not adding activation input quantizer for operation: 4053 linear_533
# INFO:nncf:Not adding activation input quantizer for operation: 406 linear_37
# INFO:nncf:Not adding activation input quantizer for operation: 4121 linear_542
# INFO:nncf:Not adding activation input quantizer for operation: 4123 linear_543
# INFO:nncf:Not adding activation input quantizer for operation: 4191 linear_552
# INFO:nncf:Not adding activation input quantizer for operation: 4193 linear_553
# INFO:nncf:Not adding activation input quantizer for operation: 4261 linear_562
# INFO:nncf:Not adding activation input quantizer for operation: 4263 linear_563
# INFO:nncf:Not adding activation input quantizer for operation: 4384 linear_575
# INFO:nncf:Not adding activation input quantizer for operation: 4386 linear_576
# INFO:nncf:Not adding activation input quantizer for operation: 4454 linear_585
# INFO:nncf:Not adding activation input quantizer for operation: 4456 linear_586
# INFO:nncf:Not adding activation input quantizer for operation: 4524 linear_595
# INFO:nncf:Not adding activation input quantizer for operation: 4526 linear_596
# INFO:nncf:Not adding activation input quantizer for operation: 4594 linear_605
# INFO:nncf:Not adding activation input quantizer for operation: 4596 linear_606
# INFO:nncf:Not adding activation input quantizer for operation: 4664 linear_615
# INFO:nncf:Not adding activation input quantizer for operation: 4666 linear_616
# INFO:nncf:Not adding activation input quantizer for operation: 4734 linear_625
# INFO:nncf:Not adding activation input quantizer for operation: 4736 linear_626
# INFO:nncf:Not adding activation input quantizer for operation: 474 linear_46
# INFO:nncf:Not adding activation input quantizer for operation: 476 linear_47
# INFO:nncf:Not adding activation input quantizer for operation: 4804 linear_635
# INFO:nncf:Not adding activation input quantizer for operation: 4806 linear_636
# INFO:nncf:Not adding activation input quantizer for operation: 4874 linear_645
# INFO:nncf:Not adding activation input quantizer for operation: 4876 linear_646
# INFO:nncf:Not adding activation input quantizer for operation: 4944 linear_655
# INFO:nncf:Not adding activation input quantizer for operation: 4946 linear_656
# INFO:nncf:Not adding activation input quantizer for operation: 5014 linear_665
# INFO:nncf:Not adding activation input quantizer for operation: 5016 linear_666
# INFO:nncf:Not adding activation input quantizer for operation: 5143 linear_678
# INFO:nncf:Not adding activation input quantizer for operation: 5145 linear_679
# INFO:nncf:Not adding activation input quantizer for operation: 5213 linear_688
# INFO:nncf:Not adding activation input quantizer for operation: 5215 linear_689
# INFO:nncf:Not adding activation input quantizer for operation: 5336 linear_701
# INFO:nncf:Not adding activation input quantizer for operation: 5338 linear_702
# INFO:nncf:Not adding activation input quantizer for operation: 5406 linear_711
# INFO:nncf:Not adding activation input quantizer for operation: 5408 linear_712
# INFO:nncf:Not adding activation input quantizer for operation: 5529 linear_724
# INFO:nncf:Not adding activation input quantizer for operation: 5531 linear_725
# INFO:nncf:Not adding activation input quantizer for operation: 5599 linear_734
# INFO:nncf:Not adding activation input quantizer for operation: 5601 linear_735
# INFO:nncf:Not adding activation input quantizer for operation: 601 linear_59
# INFO:nncf:Not adding activation input quantizer for operation: 603 linear_60
# INFO:nncf:Not adding activation input quantizer for operation: 671 linear_69
# INFO:nncf:Not adding activation input quantizer for operation: 673 linear_70
# INFO:nncf:Not adding activation input quantizer for operation: 741 linear_79
# INFO:nncf:Not adding activation input quantizer for operation: 743 linear_80
# INFO:nncf:Not adding activation input quantizer for operation: 811 linear_89
# INFO:nncf:Not adding activation input quantizer for operation: 813 linear_90
# INFO:nncf:Not adding activation input quantizer for operation: 881 linear_99
# INFO:nncf:Not adding activation input quantizer for operation: 883 linear_100
# INFO:nncf:Not adding activation input quantizer for operation: 951 linear_109
# INFO:nncf:Not adding activation input quantizer for operation: 953 linear_110
# INFO:nncf:Not adding activation input quantizer for operation: 30 linear
# 32 add_tensor
#
# INFO:nncf:Not adding activation input quantizer for operation: 35 linear_1
# 37 add_tensor_1
#
# INFO:nncf:Not adding activation input quantizer for operation: 62 linear_2
# 64 add_tensor_2
#
# INFO:nncf:Not adding activation input quantizer for operation: 67 linear_3
# 69 add_tensor_3
#
# INFO:nncf:Not adding activation input quantizer for operation: 117 linear_5
# 119 add_tensor_5
#
# INFO:nncf:Not adding activation input quantizer for operation: 1288 linear_155
# 1290 add_tensor_71
#
# INFO:nncf:Not adding activation input quantizer for operation: 152 linear_6
# 154 add_tensor_6
#
# INFO:nncf:Not adding activation input quantizer for operation: 2035 linear_258
# 2037 add_tensor_114
#
# INFO:nncf:Not adding activation input quantizer for operation: 2782 linear_361
# 2784 add_tensor_157
#
# INFO:nncf:Not adding activation input quantizer for operation: 2813 linear_362
# 2815 add_tensor_158
#
# INFO:nncf:Not adding activation input quantizer for operation: 344 linear_29
# 346 add_tensor_17
#
# INFO:nncf:Not adding activation input quantizer for operation: 3566 linear_465
# 3568 add_tensor_201
#
# INFO:nncf:Not adding activation input quantizer for operation: 4319 linear_568
# 4321 add_tensor_244
#
# INFO:nncf:Not adding activation input quantizer for operation: 5078 linear_671
# 5080 add_tensor_287
#
# INFO:nncf:Not adding activation input quantizer for operation: 5271 linear_694
# 5273 add_tensor_298
#
# INFO:nncf:Not adding activation input quantizer for operation: 536 linear_52
# 538 add_tensor_28
#
# INFO:nncf:Not adding activation input quantizer for operation: 5464 linear_717
# 5466 add_tensor_309
#
# INFO:nncf:Not adding activation input quantizer for operation: 5663 linear_740
# 5665 add_tensor_320
#
# INFO:nncf:Not adding activation input quantizer for operation: 5699 linear_741
# 5701 add_tensor_321
#
# INFO:nncf:Not adding activation input quantizer for operation: 5735 linear_742
# 5737 add_tensor_322
#
# INFO:nncf:Not adding activation input quantizer for operation: 87 linear_4
# 89 add_tensor_4
#
# INFO:nncf:Not adding activation input quantizer for operation: 182 linear_7
# 184 add_tensor_7
#
# INFO:nncf:Not adding activation input quantizer for operation: 189 linear_8
# INFO:nncf:Not adding activation input quantizer for operation: 191 linear_9
# INFO:nncf:Not adding activation input quantizer for operation: 193 linear_10
# INFO:nncf:Not adding activation input quantizer for operation: 205 linear_11
# 207 add_tensor_8
# 209 div_5
#
# INFO:nncf:Not adding activation input quantizer for operation: 215 linear_12
# INFO:nncf:Not adding activation input quantizer for operation: 231 linear_15
# 233 add_tensor_9
# 235 div_6
#
# INFO:nncf:Not adding activation input quantizer for operation: 241 linear_16
# 243 add_tensor_10
#
# INFO:nncf:Not adding activation input quantizer for operation: 251 linear_17
# 253 add_tensor_11
#
# INFO:nncf:Not adding activation input quantizer for operation: 259 linear_18
# INFO:nncf:Not adding activation input quantizer for operation: 261 linear_19
# INFO:nncf:Not adding activation input quantizer for operation: 263 linear_20
# INFO:nncf:Not adding activation input quantizer for operation: 275 linear_21
# 277 add_tensor_12
# 279 div_7
#
# INFO:nncf:Not adding activation input quantizer for operation: 285 linear_22
# INFO:nncf:Not adding activation input quantizer for operation: 301 linear_25
# 303 add_tensor_13
# 305 div_8
#
# INFO:nncf:Not adding activation input quantizer for operation: 311 linear_26
# 313 add_tensor_14
#
# INFO:nncf:Not adding activation input quantizer for operation: 321 linear_27
# 323 add_tensor_15
#
# INFO:nncf:Not adding activation input quantizer for operation: 326 linear_28
# 328 add_tensor_16
#
# INFO:nncf:Not adding activation input quantizer for operation: 369 linear_30
# 371 add_tensor_18
#
# INFO:nncf:Not adding activation input quantizer for operation: 376 linear_31
# INFO:nncf:Not adding activation input quantizer for operation: 378 linear_32
# INFO:nncf:Not adding activation input quantizer for operation: 380 linear_33
# INFO:nncf:Not adding activation input quantizer for operation: 392 linear_34
# 394 add_tensor_19
# 396 div_10
#
# INFO:nncf:Not adding activation input quantizer for operation: 402 linear_35
# INFO:nncf:Not adding activation input quantizer for operation: 418 linear_38
# 420 add_tensor_20
# 422 div_11
#
# INFO:nncf:Not adding activation input quantizer for operation: 428 linear_39
# 430 add_tensor_21
#
# INFO:nncf:Not adding activation input quantizer for operation: 438 linear_40
# 440 add_tensor_22
#
# INFO:nncf:Not adding activation input quantizer for operation: 446 linear_41
# INFO:nncf:Not adding activation input quantizer for operation: 448 linear_42
# INFO:nncf:Not adding activation input quantizer for operation: 450 linear_43
# INFO:nncf:Not adding activation input quantizer for operation: 462 linear_44
# 464 add_tensor_23
# 466 div_12
#
# INFO:nncf:Not adding activation input quantizer for operation: 472 linear_45
# INFO:nncf:Not adding activation input quantizer for operation: 488 linear_48
# 490 add_tensor_24
# 492 div_13
#
# INFO:nncf:Not adding activation input quantizer for operation: 498 linear_49
# 500 add_tensor_25
#
# INFO:nncf:Not adding activation input quantizer for operation: 508 linear_50
# 510 add_tensor_26
#
# INFO:nncf:Not adding activation input quantizer for operation: 513 linear_51
# 515 add_tensor_27
#
# INFO:nncf:Not adding activation input quantizer for operation: 566 linear_53
# 568 add_tensor_29
#
# INFO:nncf:Not adding activation input quantizer for operation: 573 linear_54
# INFO:nncf:Not adding activation input quantizer for operation: 575 linear_55
# INFO:nncf:Not adding activation input quantizer for operation: 577 linear_56
# INFO:nncf:Not adding activation input quantizer for operation: 589 linear_57
# 591 add_tensor_30
# 593 div_15
#
# INFO:nncf:Not adding activation input quantizer for operation: 599 linear_58
# INFO:nncf:Not adding activation input quantizer for operation: 615 linear_61
# 617 add_tensor_31
# 619 div_16
#
# INFO:nncf:Not adding activation input quantizer for operation: 625 linear_62
# 627 add_tensor_32
#
# INFO:nncf:Not adding activation input quantizer for operation: 635 linear_63
# 637 add_tensor_33
#
# INFO:nncf:Not adding activation input quantizer for operation: 643 linear_64
# INFO:nncf:Not adding activation input quantizer for operation: 645 linear_65
# INFO:nncf:Not adding activation input quantizer for operation: 647 linear_66
# INFO:nncf:Not adding activation input quantizer for operation: 659 linear_67
# 661 add_tensor_34
# 663 div_17
#
# INFO:nncf:Not adding activation input quantizer for operation: 669 linear_68
# INFO:nncf:Not adding activation input quantizer for operation: 685 linear_71
# 687 add_tensor_35
# 689 div_18
#
# INFO:nncf:Not adding activation input quantizer for operation: 695 linear_72
# 697 add_tensor_36
#
# INFO:nncf:Not adding activation input quantizer for operation: 705 linear_73
# 707 add_tensor_37
#
# INFO:nncf:Not adding activation input quantizer for operation: 713 linear_74
# INFO:nncf:Not adding activation input quantizer for operation: 715 linear_75
# INFO:nncf:Not adding activation input quantizer for operation: 717 linear_76
# INFO:nncf:Not adding activation input quantizer for operation: 729 linear_77
# 731 add_tensor_38
# 733 div_19
#
# INFO:nncf:Not adding activation input quantizer for operation: 739 linear_78
# INFO:nncf:Not adding activation input quantizer for operation: 755 linear_81
# 757 add_tensor_39
# 759 div_20
#
# INFO:nncf:Not adding activation input quantizer for operation: 765 linear_82
# 767 add_tensor_40
#
# INFO:nncf:Not adding activation input quantizer for operation: 775 linear_83
# 777 add_tensor_41
#
# INFO:nncf:Not adding activation input quantizer for operation: 783 linear_84
# INFO:nncf:Not adding activation input quantizer for operation: 785 linear_85
# INFO:nncf:Not adding activation input quantizer for operation: 787 linear_86
# INFO:nncf:Not adding activation input quantizer for operation: 799 linear_87
# 801 add_tensor_42
# 803 div_21
#
# INFO:nncf:Not adding activation input quantizer for operation: 809 linear_88
# INFO:nncf:Not adding activation input quantizer for operation: 825 linear_91
# 827 add_tensor_43
# 829 div_22
#
# INFO:nncf:Not adding activation input quantizer for operation: 835 linear_92
# 837 add_tensor_44
#
# INFO:nncf:Not adding activation input quantizer for operation: 845 linear_93
# 847 add_tensor_45
#
# INFO:nncf:Not adding activation input quantizer for operation: 853 linear_94
# INFO:nncf:Not adding activation input quantizer for operation: 855 linear_95
# INFO:nncf:Not adding activation input quantizer for operation: 857 linear_96
# INFO:nncf:Not adding activation input quantizer for operation: 869 linear_97
# 871 add_tensor_46
# 873 div_23
#
# INFO:nncf:Not adding activation input quantizer for operation: 879 linear_98
# INFO:nncf:Not adding activation input quantizer for operation: 895 linear_101
# 897 add_tensor_47
# 899 div_24
#
# INFO:nncf:Not adding activation input quantizer for operation: 905 linear_102
# 907 add_tensor_48
#
# INFO:nncf:Not adding activation input quantizer for operation: 915 linear_103
# 917 add_tensor_49
#
# INFO:nncf:Not adding activation input quantizer for operation: 923 linear_104
# INFO:nncf:Not adding activation input quantizer for operation: 925 linear_105
# INFO:nncf:Not adding activation input quantizer for operation: 927 linear_106
# INFO:nncf:Not adding activation input quantizer for operation: 939 linear_107
# 941 add_tensor_50
# 943 div_25
#
# INFO:nncf:Not adding activation input quantizer for operation: 949 linear_108
# INFO:nncf:Not adding activation input quantizer for operation: 965 linear_111
# 967 add_tensor_51
# 969 div_26
#
# INFO:nncf:Not adding activation input quantizer for operation: 975 linear_112
# 977 add_tensor_52
#
# INFO:nncf:Not adding activation input quantizer for operation: 985 linear_113
# 987 add_tensor_53
#
# INFO:nncf:Not adding activation input quantizer for operation: 993 linear_114
# INFO:nncf:Not adding activation input quantizer for operation: 995 linear_115
# INFO:nncf:Not adding activation input quantizer for operation: 997 linear_116
# INFO:nncf:Not adding activation input quantizer for operation: 1009 linear_117
# 1011 add_tensor_54
# 1013 div_27
#
# INFO:nncf:Not adding activation input quantizer for operation: 1019 linear_118
# INFO:nncf:Not adding activation input quantizer for operation: 1035 linear_121
# 1037 add_tensor_55
# 1039 div_28
#
# INFO:nncf:Not adding activation input quantizer for operation: 1045 linear_122
# 1047 add_tensor_56
#
# INFO:nncf:Not adding activation input quantizer for operation: 1055 linear_123
# 1057 add_tensor_57
#
# INFO:nncf:Not adding activation input quantizer for operation: 1063 linear_124
# INFO:nncf:Not adding activation input quantizer for operation: 1065 linear_125
# INFO:nncf:Not adding activation input quantizer for operation: 1067 linear_126
# INFO:nncf:Not adding activation input quantizer for operation: 1079 linear_127
# 1081 add_tensor_58
# 1083 div_29
#
# INFO:nncf:Not adding activation input quantizer for operation: 1089 linear_128
# INFO:nncf:Not adding activation input quantizer for operation: 1105 linear_131
# 1107 add_tensor_59
# 1109 div_30
#
# INFO:nncf:Not adding activation input quantizer for operation: 1115 linear_132
# 1117 add_tensor_60
#
# INFO:nncf:Not adding activation input quantizer for operation: 1125 linear_133
# 1127 add_tensor_61
#
# INFO:nncf:Not adding activation input quantizer for operation: 1133 linear_134
# INFO:nncf:Not adding activation input quantizer for operation: 1135 linear_135
# INFO:nncf:Not adding activation input quantizer for operation: 1137 linear_136
# INFO:nncf:Not adding activation input quantizer for operation: 1149 linear_137
# 1151 add_tensor_62
# 1153 div_31
#
# INFO:nncf:Not adding activation input quantizer for operation: 1159 linear_138
# INFO:nncf:Not adding activation input quantizer for operation: 1175 linear_141
# 1177 add_tensor_63
# 1179 div_32
#
# INFO:nncf:Not adding activation input quantizer for operation: 1185 linear_142
# 1187 add_tensor_64
#
# INFO:nncf:Not adding activation input quantizer for operation: 1195 linear_143
# 1197 add_tensor_65
#
# INFO:nncf:Not adding activation input quantizer for operation: 1203 linear_144
# INFO:nncf:Not adding activation input quantizer for operation: 1205 linear_145
# INFO:nncf:Not adding activation input quantizer for operation: 1207 linear_146
# INFO:nncf:Not adding activation input quantizer for operation: 1219 linear_147
# 1221 add_tensor_66
# 1223 div_33
#
# INFO:nncf:Not adding activation input quantizer for operation: 1229 linear_148
# INFO:nncf:Not adding activation input quantizer for operation: 1245 linear_151
# 1247 add_tensor_67
# 1249 div_34
#
# INFO:nncf:Not adding activation input quantizer for operation: 1255 linear_152
# 1257 add_tensor_68
#
# INFO:nncf:Not adding activation input quantizer for operation: 1265 linear_153
# 1267 add_tensor_69
#
# INFO:nncf:Not adding activation input quantizer for operation: 1270 linear_154
# 1272 add_tensor_70
#
# INFO:nncf:Not adding activation input quantizer for operation: 1313 linear_156
# 1315 add_tensor_72
#
# INFO:nncf:Not adding activation input quantizer for operation: 1320 linear_157
# INFO:nncf:Not adding activation input quantizer for operation: 1322 linear_158
# INFO:nncf:Not adding activation input quantizer for operation: 1324 linear_159
# INFO:nncf:Not adding activation input quantizer for operation: 1336 linear_160
# 1338 add_tensor_73
# 1340 div_36
#
# INFO:nncf:Not adding activation input quantizer for operation: 1346 linear_161
# INFO:nncf:Not adding activation input quantizer for operation: 1362 linear_164
# 1364 add_tensor_74
# 1366 div_37
#
# INFO:nncf:Not adding activation input quantizer for operation: 1372 linear_165
# 1374 add_tensor_75
#
# INFO:nncf:Not adding activation input quantizer for operation: 1382 linear_166
# 1384 add_tensor_76
#
# INFO:nncf:Not adding activation input quantizer for operation: 1390 linear_167
# INFO:nncf:Not adding activation input quantizer for operation: 1392 linear_168
# INFO:nncf:Not adding activation input quantizer for operation: 1394 linear_169
# INFO:nncf:Not adding activation input quantizer for operation: 1406 linear_170
# 1408 add_tensor_77
# 1410 div_38
#
# INFO:nncf:Not adding activation input quantizer for operation: 1416 linear_171
# INFO:nncf:Not adding activation input quantizer for operation: 1432 linear_174
# 1434 add_tensor_78
# 1436 div_39
#
# INFO:nncf:Not adding activation input quantizer for operation: 1442 linear_175
# 1444 add_tensor_79
#
# INFO:nncf:Not adding activation input quantizer for operation: 1452 linear_176
# 1454 add_tensor_80
#
# INFO:nncf:Not adding activation input quantizer for operation: 1460 linear_177
# INFO:nncf:Not adding activation input quantizer for operation: 1462 linear_178
# INFO:nncf:Not adding activation input quantizer for operation: 1464 linear_179
# INFO:nncf:Not adding activation input quantizer for operation: 1476 linear_180
# 1478 add_tensor_81
# 1480 div_40
#
# INFO:nncf:Not adding activation input quantizer for operation: 1486 linear_181
# INFO:nncf:Not adding activation input quantizer for operation: 1502 linear_184
# 1504 add_tensor_82
# 1506 div_41
#
# INFO:nncf:Not adding activation input quantizer for operation: 1512 linear_185
# 1514 add_tensor_83
#
# INFO:nncf:Not adding activation input quantizer for operation: 1522 linear_186
# 1524 add_tensor_84
#
# INFO:nncf:Not adding activation input quantizer for operation: 1530 linear_187
# INFO:nncf:Not adding activation input quantizer for operation: 1532 linear_188
# INFO:nncf:Not adding activation input quantizer for operation: 1534 linear_189
# INFO:nncf:Not adding activation input quantizer for operation: 1546 linear_190
# 1548 add_tensor_85
# 1550 div_42
#
# INFO:nncf:Not adding activation input quantizer for operation: 1556 linear_191
# INFO:nncf:Not adding activation input quantizer for operation: 1572 linear_194
# 1574 add_tensor_86
# 1576 div_43
#
# INFO:nncf:Not adding activation input quantizer for operation: 1582 linear_195
# 1584 add_tensor_87
#
# INFO:nncf:Not adding activation input quantizer for operation: 1592 linear_196
# 1594 add_tensor_88
#
# INFO:nncf:Not adding activation input quantizer for operation: 1600 linear_197
# INFO:nncf:Not adding activation input quantizer for operation: 1602 linear_198
# INFO:nncf:Not adding activation input quantizer for operation: 1604 linear_199
# INFO:nncf:Not adding activation input quantizer for operation: 1616 linear_200
# 1618 add_tensor_89
# 1620 div_44
#
# INFO:nncf:Not adding activation input quantizer for operation: 1626 linear_201
# INFO:nncf:Not adding activation input quantizer for operation: 1642 linear_204
# 1644 add_tensor_90
# 1646 div_45
#
# INFO:nncf:Not adding activation input quantizer for operation: 1652 linear_205
# 1654 add_tensor_91
#
# INFO:nncf:Not adding activation input quantizer for operation: 1662 linear_206
# 1664 add_tensor_92
#
# INFO:nncf:Not adding activation input quantizer for operation: 1670 linear_207
# INFO:nncf:Not adding activation input quantizer for operation: 1672 linear_208
# INFO:nncf:Not adding activation input quantizer for operation: 1674 linear_209
# INFO:nncf:Not adding activation input quantizer for operation: 1686 linear_210
# 1688 add_tensor_93
# 1690 div_46
#
# INFO:nncf:Not adding activation input quantizer for operation: 1696 linear_211
# INFO:nncf:Not adding activation input quantizer for operation: 1712 linear_214
# 1714 add_tensor_94
# 1716 div_47
#
# INFO:nncf:Not adding activation input quantizer for operation: 1722 linear_215
# 1724 add_tensor_95
#
# INFO:nncf:Not adding activation input quantizer for operation: 1732 linear_216
# 1734 add_tensor_96
#
# INFO:nncf:Not adding activation input quantizer for operation: 1740 linear_217
# INFO:nncf:Not adding activation input quantizer for operation: 1742 linear_218
# INFO:nncf:Not adding activation input quantizer for operation: 1744 linear_219
# INFO:nncf:Not adding activation input quantizer for operation: 1756 linear_220
# 1758 add_tensor_97
# 1760 div_48
#
# INFO:nncf:Not adding activation input quantizer for operation: 1766 linear_221
# INFO:nncf:Not adding activation input quantizer for operation: 1782 linear_224
# 1784 add_tensor_98
# 1786 div_49
#
# INFO:nncf:Not adding activation input quantizer for operation: 1792 linear_225
# 1794 add_tensor_99
#
# INFO:nncf:Not adding activation input quantizer for operation: 1802 linear_226
# 1804 add_tensor_100
#
# INFO:nncf:Not adding activation input quantizer for operation: 1810 linear_227
# INFO:nncf:Not adding activation input quantizer for operation: 1812 linear_228
# INFO:nncf:Not adding activation input quantizer for operation: 1814 linear_229
# INFO:nncf:Not adding activation input quantizer for operation: 1826 linear_230
# 1828 add_tensor_101
# 1830 div_50
#
# INFO:nncf:Not adding activation input quantizer for operation: 1836 linear_231
# INFO:nncf:Not adding activation input quantizer for operation: 1852 linear_234
# 1854 add_tensor_102
# 1856 div_51
#
# INFO:nncf:Not adding activation input quantizer for operation: 1862 linear_235
# 1864 add_tensor_103
#
# INFO:nncf:Not adding activation input quantizer for operation: 1872 linear_236
# 1874 add_tensor_104
#
# INFO:nncf:Not adding activation input quantizer for operation: 1880 linear_237
# INFO:nncf:Not adding activation input quantizer for operation: 1882 linear_238
# INFO:nncf:Not adding activation input quantizer for operation: 1884 linear_239
# INFO:nncf:Not adding activation input quantizer for operation: 1896 linear_240
# 1898 add_tensor_105
# 1900 div_52
#
# INFO:nncf:Not adding activation input quantizer for operation: 1906 linear_241
# INFO:nncf:Not adding activation input quantizer for operation: 1922 linear_244
# 1924 add_tensor_106
# 1926 div_53
#
# INFO:nncf:Not adding activation input quantizer for operation: 1932 linear_245
# 1934 add_tensor_107
#
# INFO:nncf:Not adding activation input quantizer for operation: 1942 linear_246
# 1944 add_tensor_108
#
# INFO:nncf:Not adding activation input quantizer for operation: 1950 linear_247
# INFO:nncf:Not adding activation input quantizer for operation: 1952 linear_248
# INFO:nncf:Not adding activation input quantizer for operation: 1954 linear_249
# INFO:nncf:Not adding activation input quantizer for operation: 1966 linear_250
# 1968 add_tensor_109
# 1970 div_54
#
# INFO:nncf:Not adding activation input quantizer for operation: 1976 linear_251
# INFO:nncf:Not adding activation input quantizer for operation: 1992 linear_254
# 1994 add_tensor_110
# 1996 div_55
#
# INFO:nncf:Not adding activation input quantizer for operation: 2002 linear_255
# 2004 add_tensor_111
#
# INFO:nncf:Not adding activation input quantizer for operation: 2012 linear_256
# 2014 add_tensor_112
#
# INFO:nncf:Not adding activation input quantizer for operation: 2017 linear_257
# 2019 add_tensor_113
#
# INFO:nncf:Not adding activation input quantizer for operation: 2060 linear_259
# 2062 add_tensor_115
#
# INFO:nncf:Not adding activation input quantizer for operation: 2067 linear_260
# INFO:nncf:Not adding activation input quantizer for operation: 2069 linear_261
# INFO:nncf:Not adding activation input quantizer for operation: 2071 linear_262
# INFO:nncf:Not adding activation input quantizer for operation: 2083 linear_263
# 2085 add_tensor_116
# 2087 div_57
#
# INFO:nncf:Not adding activation input quantizer for operation: 2093 linear_264
# INFO:nncf:Not adding activation input quantizer for operation: 2109 linear_267
# 2111 add_tensor_117
# 2113 div_58
#
# INFO:nncf:Not adding activation input quantizer for operation: 2119 linear_268
# 2121 add_tensor_118
#
# INFO:nncf:Not adding activation input quantizer for operation: 2129 linear_269
# 2131 add_tensor_119
#
# INFO:nncf:Not adding activation input quantizer for operation: 2137 linear_270
# INFO:nncf:Not adding activation input quantizer for operation: 2139 linear_271
# INFO:nncf:Not adding activation input quantizer for operation: 2141 linear_272
# INFO:nncf:Not adding activation input quantizer for operation: 2153 linear_273
# 2155 add_tensor_120
# 2157 div_59
#
# INFO:nncf:Not adding activation input quantizer for operation: 2163 linear_274
# INFO:nncf:Not adding activation input quantizer for operation: 2179 linear_277
# 2181 add_tensor_121
# 2183 div_60
#
# INFO:nncf:Not adding activation input quantizer for operation: 2189 linear_278
# 2191 add_tensor_122
#
# INFO:nncf:Not adding activation input quantizer for operation: 2199 linear_279
# 2201 add_tensor_123
#
# INFO:nncf:Not adding activation input quantizer for operation: 2207 linear_280
# INFO:nncf:Not adding activation input quantizer for operation: 2209 linear_281
# INFO:nncf:Not adding activation input quantizer for operation: 2211 linear_282
# INFO:nncf:Not adding activation input quantizer for operation: 2223 linear_283
# 2225 add_tensor_124
# 2227 div_61
#
# INFO:nncf:Not adding activation input quantizer for operation: 2233 linear_284
# INFO:nncf:Not adding activation input quantizer for operation: 2249 linear_287
# 2251 add_tensor_125
# 2253 div_62
#
# INFO:nncf:Not adding activation input quantizer for operation: 2259 linear_288
# 2261 add_tensor_126
#
# INFO:nncf:Not adding activation input quantizer for operation: 2269 linear_289
# 2271 add_tensor_127
#
# INFO:nncf:Not adding activation input quantizer for operation: 2277 linear_290
# INFO:nncf:Not adding activation input quantizer for operation: 2279 linear_291
# INFO:nncf:Not adding activation input quantizer for operation: 2281 linear_292
# INFO:nncf:Not adding activation input quantizer for operation: 2293 linear_293
# 2295 add_tensor_128
# 2297 div_63
#
# INFO:nncf:Not adding activation input quantizer for operation: 2303 linear_294
# INFO:nncf:Not adding activation input quantizer for operation: 2319 linear_297
# 2321 add_tensor_129
# 2323 div_64
#
# INFO:nncf:Not adding activation input quantizer for operation: 2329 linear_298
# 2331 add_tensor_130
#
# INFO:nncf:Not adding activation input quantizer for operation: 2339 linear_299
# 2341 add_tensor_131
#
# INFO:nncf:Not adding activation input quantizer for operation: 2347 linear_300
# INFO:nncf:Not adding activation input quantizer for operation: 2349 linear_301
# INFO:nncf:Not adding activation input quantizer for operation: 2351 linear_302
# INFO:nncf:Not adding activation input quantizer for operation: 2363 linear_303
# 2365 add_tensor_132
# 2367 div_65
#
# INFO:nncf:Not adding activation input quantizer for operation: 2373 linear_304
# INFO:nncf:Not adding activation input quantizer for operation: 2389 linear_307
# 2391 add_tensor_133
# 2393 div_66
#
# INFO:nncf:Not adding activation input quantizer for operation: 2399 linear_308
# 2401 add_tensor_134
#
# INFO:nncf:Not adding activation input quantizer for operation: 2409 linear_309
# 2411 add_tensor_135
#
# INFO:nncf:Not adding activation input quantizer for operation: 2417 linear_310
# INFO:nncf:Not adding activation input quantizer for operation: 2419 linear_311
# INFO:nncf:Not adding activation input quantizer for operation: 2421 linear_312
# INFO:nncf:Not adding activation input quantizer for operation: 2433 linear_313
# 2435 add_tensor_136
# 2437 div_67
#
# INFO:nncf:Not adding activation input quantizer for operation: 2443 linear_314
# INFO:nncf:Not adding activation input quantizer for operation: 2459 linear_317
# 2461 add_tensor_137
# 2463 div_68
#
# INFO:nncf:Not adding activation input quantizer for operation: 2469 linear_318
# 2471 add_tensor_138
#
# INFO:nncf:Not adding activation input quantizer for operation: 2479 linear_319
# 2481 add_tensor_139
#
# INFO:nncf:Not adding activation input quantizer for operation: 2487 linear_320
# INFO:nncf:Not adding activation input quantizer for operation: 2489 linear_321
# INFO:nncf:Not adding activation input quantizer for operation: 2491 linear_322
# INFO:nncf:Not adding activation input quantizer for operation: 2503 linear_323
# 2505 add_tensor_140
# 2507 div_69
#
# INFO:nncf:Not adding activation input quantizer for operation: 2513 linear_324
# INFO:nncf:Not adding activation input quantizer for operation: 2529 linear_327
# 2531 add_tensor_141
# 2533 div_70
#
# INFO:nncf:Not adding activation input quantizer for operation: 2539 linear_328
# 2541 add_tensor_142
#
# INFO:nncf:Not adding activation input quantizer for operation: 2549 linear_329
# 2551 add_tensor_143
#
# INFO:nncf:Not adding activation input quantizer for operation: 2557 linear_330
# INFO:nncf:Not adding activation input quantizer for operation: 2559 linear_331
# INFO:nncf:Not adding activation input quantizer for operation: 2561 linear_332
# INFO:nncf:Not adding activation input quantizer for operation: 2573 linear_333
# 2575 add_tensor_144
# 2577 div_71
#
# INFO:nncf:Not adding activation input quantizer for operation: 2583 linear_334
# INFO:nncf:Not adding activation input quantizer for operation: 2599 linear_337
# 2601 add_tensor_145
# 2603 div_72
#
# INFO:nncf:Not adding activation input quantizer for operation: 2609 linear_338
# 2611 add_tensor_146
#
# INFO:nncf:Not adding activation input quantizer for operation: 2619 linear_339
# 2621 add_tensor_147
#
# INFO:nncf:Not adding activation input quantizer for operation: 2627 linear_340
# INFO:nncf:Not adding activation input quantizer for operation: 2629 linear_341
# INFO:nncf:Not adding activation input quantizer for operation: 2631 linear_342
# INFO:nncf:Not adding activation input quantizer for operation: 2643 linear_343
# 2645 add_tensor_148
# 2647 div_73
#
# INFO:nncf:Not adding activation input quantizer for operation: 2653 linear_344
# INFO:nncf:Not adding activation input quantizer for operation: 2669 linear_347
# 2671 add_tensor_149
# 2673 div_74
#
# INFO:nncf:Not adding activation input quantizer for operation: 2679 linear_348
# 2681 add_tensor_150
#
# INFO:nncf:Not adding activation input quantizer for operation: 2689 linear_349
# 2691 add_tensor_151
#
# INFO:nncf:Not adding activation input quantizer for operation: 2697 linear_350
# INFO:nncf:Not adding activation input quantizer for operation: 2699 linear_351
# INFO:nncf:Not adding activation input quantizer for operation: 2701 linear_352
# INFO:nncf:Not adding activation input quantizer for operation: 2713 linear_353
# 2715 add_tensor_152
# 2717 div_75
#
# INFO:nncf:Not adding activation input quantizer for operation: 2723 linear_354
# INFO:nncf:Not adding activation input quantizer for operation: 2739 linear_357
# 2741 add_tensor_153
# 2743 div_76
#
# INFO:nncf:Not adding activation input quantizer for operation: 2749 linear_358
# 2751 add_tensor_154
#
# INFO:nncf:Not adding activation input quantizer for operation: 2759 linear_359
# 2761 add_tensor_155
#
# INFO:nncf:Not adding activation input quantizer for operation: 2764 linear_360
# 2766 add_tensor_156
#
# INFO:nncf:Not adding activation input quantizer for operation: 2843 linear_363
# 2845 add_tensor_159
#
# INFO:nncf:Not adding activation input quantizer for operation: 2850 linear_364
# INFO:nncf:Not adding activation input quantizer for operation: 2852 linear_365
# INFO:nncf:Not adding activation input quantizer for operation: 2854 linear_366
# INFO:nncf:Not adding activation input quantizer for operation: 2866 linear_367
# 2868 add_tensor_160
# 2870 div_79
#
# INFO:nncf:Not adding activation input quantizer for operation: 2876 linear_368
# INFO:nncf:Not adding activation input quantizer for operation: 2892 linear_371
# 2894 add_tensor_161
# 2896 div_80
#
# INFO:nncf:Not adding activation input quantizer for operation: 2902 linear_372
# 2904 add_tensor_162
#
# INFO:nncf:Not adding activation input quantizer for operation: 2912 linear_373
# 2914 add_tensor_163
#
# INFO:nncf:Not adding activation input quantizer for operation: 2920 linear_374
# INFO:nncf:Not adding activation input quantizer for operation: 2922 linear_375
# INFO:nncf:Not adding activation input quantizer for operation: 2924 linear_376
# INFO:nncf:Not adding activation input quantizer for operation: 2936 linear_377
# 2938 add_tensor_164
# 2940 div_81
#
# INFO:nncf:Not adding activation input quantizer for operation: 2946 linear_378
# INFO:nncf:Not adding activation input quantizer for operation: 2962 linear_381
# 2964 add_tensor_165
# 2966 div_82
#
# INFO:nncf:Not adding activation input quantizer for operation: 2972 linear_382
# 2974 add_tensor_166
#
# INFO:nncf:Not adding activation input quantizer for operation: 2982 linear_383
# 2984 add_tensor_167
#
# INFO:nncf:Not adding activation input quantizer for operation: 2990 linear_384
# INFO:nncf:Not adding activation input quantizer for operation: 2992 linear_385
# INFO:nncf:Not adding activation input quantizer for operation: 2994 linear_386
# INFO:nncf:Not adding activation input quantizer for operation: 3006 linear_387
# 3008 add_tensor_168
# 3010 div_83
#
# INFO:nncf:Not adding activation input quantizer for operation: 3016 linear_388
# INFO:nncf:Not adding activation input quantizer for operation: 3032 linear_391
# 3034 add_tensor_169
# 3036 div_84
#
# INFO:nncf:Not adding activation input quantizer for operation: 3042 linear_392
# 3044 add_tensor_170
#
# INFO:nncf:Not adding activation input quantizer for operation: 3052 linear_393
# 3054 add_tensor_171
#
# INFO:nncf:Not adding activation input quantizer for operation: 3060 linear_394
# INFO:nncf:Not adding activation input quantizer for operation: 3062 linear_395
# INFO:nncf:Not adding activation input quantizer for operation: 3064 linear_396
# INFO:nncf:Not adding activation input quantizer for operation: 3076 linear_397
# 3078 add_tensor_172
# 3080 div_85
#
# INFO:nncf:Not adding activation input quantizer for operation: 3086 linear_398
# INFO:nncf:Not adding activation input quantizer for operation: 3102 linear_401
# 3104 add_tensor_173
# 3106 div_86
#
# INFO:nncf:Not adding activation input quantizer for operation: 3112 linear_402
# 3114 add_tensor_174
#
# INFO:nncf:Not adding activation input quantizer for operation: 3122 linear_403
# 3124 add_tensor_175
#
# INFO:nncf:Not adding activation input quantizer for operation: 3130 linear_404
# INFO:nncf:Not adding activation input quantizer for operation: 3132 linear_405
# INFO:nncf:Not adding activation input quantizer for operation: 3134 linear_406
# INFO:nncf:Not adding activation input quantizer for operation: 3146 linear_407
# 3148 add_tensor_176
# 3150 div_87
#
# INFO:nncf:Not adding activation input quantizer for operation: 3156 linear_408
# INFO:nncf:Not adding activation input quantizer for operation: 3172 linear_411
# 3174 add_tensor_177
# 3176 div_88
#
# INFO:nncf:Not adding activation input quantizer for operation: 3182 linear_412
# 3184 add_tensor_178
#
# INFO:nncf:Not adding activation input quantizer for operation: 3192 linear_413
# 3194 add_tensor_179
#
# INFO:nncf:Not adding activation input quantizer for operation: 3200 linear_414
# INFO:nncf:Not adding activation input quantizer for operation: 3202 linear_415
# INFO:nncf:Not adding activation input quantizer for operation: 3204 linear_416
# INFO:nncf:Not adding activation input quantizer for operation: 3216 linear_417
# 3218 add_tensor_180
# 3220 div_89
#
# INFO:nncf:Not adding activation input quantizer for operation: 3226 linear_418
# INFO:nncf:Not adding activation input quantizer for operation: 3242 linear_421
# 3244 add_tensor_181
# 3246 div_90
#
# INFO:nncf:Not adding activation input quantizer for operation: 3252 linear_422
# 3254 add_tensor_182
#
# INFO:nncf:Not adding activation input quantizer for operation: 3262 linear_423
# 3264 add_tensor_183
#
# INFO:nncf:Not adding activation input quantizer for operation: 3270 linear_424
# INFO:nncf:Not adding activation input quantizer for operation: 3272 linear_425
# INFO:nncf:Not adding activation input quantizer for operation: 3274 linear_426
# INFO:nncf:Not adding activation input quantizer for operation: 3286 linear_427
# 3288 add_tensor_184
# 3290 div_91
#
# INFO:nncf:Not adding activation input quantizer for operation: 3296 linear_428
# INFO:nncf:Not adding activation input quantizer for operation: 3312 linear_431
# 3314 add_tensor_185
# 3316 div_92
#
# INFO:nncf:Not adding activation input quantizer for operation: 3322 linear_432
# 3324 add_tensor_186
#
# INFO:nncf:Not adding activation input quantizer for operation: 3332 linear_433
# 3334 add_tensor_187
#
# INFO:nncf:Not adding activation input quantizer for operation: 3340 linear_434
# INFO:nncf:Not adding activation input quantizer for operation: 3342 linear_435
# INFO:nncf:Not adding activation input quantizer for operation: 3344 linear_436
# INFO:nncf:Not adding activation input quantizer for operation: 3356 linear_437
# 3358 add_tensor_188
# 3360 div_93
#
# INFO:nncf:Not adding activation input quantizer for operation: 3366 linear_438
# INFO:nncf:Not adding activation input quantizer for operation: 3382 linear_441
# 3384 add_tensor_189
# 3386 div_94
#
# INFO:nncf:Not adding activation input quantizer for operation: 3392 linear_442
# 3394 add_tensor_190
#
# INFO:nncf:Not adding activation input quantizer for operation: 3402 linear_443
# 3404 add_tensor_191
#
# INFO:nncf:Not adding activation input quantizer for operation: 3410 linear_444
# INFO:nncf:Not adding activation input quantizer for operation: 3412 linear_445
# INFO:nncf:Not adding activation input quantizer for operation: 3414 linear_446
# INFO:nncf:Not adding activation input quantizer for operation: 3426 linear_447
# 3428 add_tensor_192
# 3430 div_95
#
# INFO:nncf:Not adding activation input quantizer for operation: 3436 linear_448
# INFO:nncf:Not adding activation input quantizer for operation: 3452 linear_451
# 3454 add_tensor_193
# 3456 div_96
#
# INFO:nncf:Not adding activation input quantizer for operation: 3462 linear_452
# 3464 add_tensor_194
#
# INFO:nncf:Not adding activation input quantizer for operation: 3472 linear_453
# 3474 add_tensor_195
#
# INFO:nncf:Not adding activation input quantizer for operation: 3480 linear_454
# INFO:nncf:Not adding activation input quantizer for operation: 3482 linear_455
# INFO:nncf:Not adding activation input quantizer for operation: 3484 linear_456
# INFO:nncf:Not adding activation input quantizer for operation: 3496 linear_457
# 3498 add_tensor_196
# 3500 div_97
#
# INFO:nncf:Not adding activation input quantizer for operation: 3506 linear_458
# INFO:nncf:Not adding activation input quantizer for operation: 3522 linear_461
# 3524 add_tensor_197
# 3526 div_98
#
# INFO:nncf:Not adding activation input quantizer for operation: 3532 linear_462
# 3534 add_tensor_198
#
# INFO:nncf:Not adding activation input quantizer for operation: 3542 linear_463
# 3544 add_tensor_199
#
# INFO:nncf:Not adding activation input quantizer for operation: 3547 linear_464
# 3549 add_tensor_200
#
# INFO:nncf:Not adding activation input quantizer for operation: 3596 linear_466
# 3598 add_tensor_202
#
# INFO:nncf:Not adding activation input quantizer for operation: 3603 linear_467
# INFO:nncf:Not adding activation input quantizer for operation: 3605 linear_468
# INFO:nncf:Not adding activation input quantizer for operation: 3607 linear_469
# INFO:nncf:Not adding activation input quantizer for operation: 3619 linear_470
# 3621 add_tensor_203
# 3623 div_100
#
# INFO:nncf:Not adding activation input quantizer for operation: 3629 linear_471
# INFO:nncf:Not adding activation input quantizer for operation: 3645 linear_474
# ...
# 4840 add_tensor_273
#
# INFO:nncf:Not adding activation input quantizer for operation: 4846 linear_640
# INFO:nncf:Not adding activation input quantizer for operation: 4848 linear_641
# INFO:nncf:Not adding activation input quantizer for operation: 4850 linear_642
# INFO:nncf:Not adding activation input quantizer for operation: 4862 linear_643
# 4864 add_tensor_274
# 4866 div_135
#
# INFO:nncf:Not adding activation input quantizer for operation: 4872 linear_644
# INFO:nncf:Not adding activation input quantizer for operation: 4888 linear_647
# 4890 add_tensor_275
# 4892 div_136
#
# INFO:nncf:Not adding activation input quantizer for operation: 4898 linear_648
# 4900 add_tensor_276
#
# INFO:nncf:Not adding activation input quantizer for operation: 4908 linear_649
# 4910 add_tensor_277
#
# INFO:nncf:Not adding activation input quantizer for operation: 4916 linear_650
# INFO:nncf:Not adding activation input quantizer for operation: 4918 linear_651
# INFO:nncf:Not adding activation input quantizer for operation: 4920 linear_652
# INFO:nncf:Not adding activation input quantizer for operation: 4932 linear_653
# 4934 add_tensor_278
# 4936 div_137
#
# INFO:nncf:Not adding activation input quantizer for operation: 4942 linear_654
# INFO:nncf:Not adding activation input quantizer for operation: 4958 linear_657
# 4960 add_tensor_279
# 4962 div_138
#
# INFO:nncf:Not adding activation input quantizer for operation: 4968 linear_658
# 4970 add_tensor_280
#
# INFO:nncf:Not adding activation input quantizer for operation: 4978 linear_659
# 4980 add_tensor_281
#
# INFO:nncf:Not adding activation input quantizer for operation: 4986 linear_660
# INFO:nncf:Not adding activation input quantizer for operation: 4988 linear_661
# INFO:nncf:Not adding activation input quantizer for operation: 4990 linear_662
# INFO:nncf:Not adding activation input quantizer for operation: 5002 linear_663
# 5004 add_tensor_282
# 5006 div_139
#
# INFO:nncf:Not adding activation input quantizer for operation: 5012 linear_664
# INFO:nncf:Not adding activation input quantizer for operation: 5028 linear_667
# 5030 add_tensor_283
# 5032 div_140
#
# INFO:nncf:Not adding activation input quantizer for operation: 5038 linear_668
# 5040 add_tensor_284
#
# INFO:nncf:Not adding activation input quantizer for operation: 5048 linear_669
# 5050 add_tensor_285
#
# INFO:nncf:Not adding activation input quantizer for operation: 5053 linear_670
# 5055 add_tensor_286
#
# INFO:nncf:Not adding activation input quantizer for operation: 5108 linear_672
# 5110 add_tensor_288
#
# INFO:nncf:Not adding activation input quantizer for operation: 5115 linear_673
# INFO:nncf:Not adding activation input quantizer for operation: 5117 linear_674
# INFO:nncf:Not adding activation input quantizer for operation: 5119 linear_675
# INFO:nncf:Not adding activation input quantizer for operation: 5131 linear_676
# 5133 add_tensor_289
# 5135 div_142
#
# INFO:nncf:Not adding activation input quantizer for operation: 5141 linear_677
# INFO:nncf:Not adding activation input quantizer for operation: 5157 linear_680
# 5159 add_tensor_290
# 5161 div_143
#
# INFO:nncf:Not adding activation input quantizer for operation: 5167 linear_681
# 5169 add_tensor_291
#
# INFO:nncf:Not adding activation input quantizer for operation: 5177 linear_682
# 5179 add_tensor_292
#
# INFO:nncf:Not adding activation input quantizer for operation: 5185 linear_683
# INFO:nncf:Not adding activation input quantizer for operation: 5187 linear_684
# INFO:nncf:Not adding activation input quantizer for operation: 5189 linear_685
# INFO:nncf:Not adding activation input quantizer for operation: 5201 linear_686
# 5203 add_tensor_293
# 5205 div_144
#
# INFO:nncf:Not adding activation input quantizer for operation: 5211 linear_687
# INFO:nncf:Not adding activation input quantizer for operation: 5227 linear_690
# 5229 add_tensor_294
# 5231 div_145
#
# INFO:nncf:Not adding activation input quantizer for operation: 5237 linear_691
# 5239 add_tensor_295
#
# INFO:nncf:Not adding activation input quantizer for operation: 5247 linear_692
# 5249 add_tensor_296
#
# INFO:nncf:Not adding activation input quantizer for operation: 5252 linear_693
# 5254 add_tensor_297
#
# INFO:nncf:Not adding activation input quantizer for operation: 5301 linear_695
# 5303 add_tensor_299
#
# INFO:nncf:Not adding activation input quantizer for operation: 5308 linear_696
# INFO:nncf:Not adding activation input quantizer for operation: 5310 linear_697
# INFO:nncf:Not adding activation input quantizer for operation: 5312 linear_698
# INFO:nncf:Not adding activation input quantizer for operation: 5324 linear_699
# 5326 add_tensor_300
# 5328 div_147
#
# INFO:nncf:Not adding activation input quantizer for operation: 5334 linear_700
# INFO:nncf:Not adding activation input quantizer for operation: 5350 linear_703
# 5352 add_tensor_301
# 5354 div_148
#
# INFO:nncf:Not adding activation input quantizer for operation: 5360 linear_704
# 5362 add_tensor_302
#
# INFO:nncf:Not adding activation input quantizer for operation: 5370 linear_705
# 5372 add_tensor_303
#
# INFO:nncf:Not adding activation input quantizer for operation: 5378 linear_706
# INFO:nncf:Not adding activation input quantizer for operation: 5380 linear_707
# INFO:nncf:Not adding activation input quantizer for operation: 5382 linear_708
# INFO:nncf:Not adding activation input quantizer for operation: 5394 linear_709
# 5396 add_tensor_304
# 5398 div_149
#
# INFO:nncf:Not adding activation input quantizer for operation: 5404 linear_710
# INFO:nncf:Not adding activation input quantizer for operation: 5420 linear_713
# 5422 add_tensor_305
# 5424 div_150
#
# INFO:nncf:Not adding activation input quantizer for operation: 5430 linear_714
# 5432 add_tensor_306
#
# INFO:nncf:Not adding activation input quantizer for operation: 5440 linear_715
# 5442 add_tensor_307
#
# INFO:nncf:Not adding activation input quantizer for operation: 5445 linear_716
# 5447 add_tensor_308
#
# INFO:nncf:Not adding activation input quantizer for operation: 5494 linear_718
# 5496 add_tensor_310
#
# INFO:nncf:Not adding activation input quantizer for operation: 5501 linear_719
# INFO:nncf:Not adding activation input quantizer for operation: 5503 linear_720
# INFO:nncf:Not adding activation input quantizer for operation: 5505 linear_721
# INFO:nncf:Not adding activation input quantizer for operation: 5517 linear_722
# 5519 add_tensor_311
# 5521 div_152
#
# INFO:nncf:Not adding activation input quantizer for operation: 5527 linear_723
# INFO:nncf:Not adding activation input quantizer for operation: 5543 linear_726
# 5545 add_tensor_312
# 5547 div_153
#
# INFO:nncf:Not adding activation input quantizer for operation: 5553 linear_727
# 5555 add_tensor_313
#
# INFO:nncf:Not adding activation input quantizer for operation: 5563 linear_728
# 5565 add_tensor_314
#
# INFO:nncf:Not adding activation input quantizer for operation: 5571 linear_729
# INFO:nncf:Not adding activation input quantizer for operation: 5573 linear_730
# INFO:nncf:Not adding activation input quantizer for operation: 5575 linear_731
# INFO:nncf:Not adding activation input quantizer for operation: 5587 linear_732
# 5589 add_tensor_315
# 5591 div_154
#
# INFO:nncf:Not adding activation input quantizer for operation: 5597 linear_733
# INFO:nncf:Not adding activation input quantizer for operation: 5613 linear_736
# 5615 add_tensor_316
# 5617 div_155
#
# INFO:nncf:Not adding activation input quantizer for operation: 5623 linear_737
# 5625 add_tensor_317
#
# INFO:nncf:Not adding activation input quantizer for operation: 5633 linear_738
# 5635 add_tensor_318
#
# INFO:nncf:Not adding activation input quantizer for operation: 5638 linear_739
# 5640 add_tensor_319
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 40
#      11 with disable_patching():
#      12     with torch.no_grad():
#      13         # compressed_unet = nncf.compress_weights(unet, ignored_scope=nncf.IgnoredScope(types=['conv2d']))
#      14         # quantized_unet = nncf.quantize( #1
#    (...)
#      38         #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1)
#      39         # )
# ---> 40         quantized_unet = nncf.quantize( #4.1
#      41             model=pipe.unet,
#      42             calibration_dataset=nncf.Dataset(unet_calibration_data),
#      43             subset_size=len(unet_calibration_data),
#      44             model_type=nncf.ModelType.TRANSFORMER,
#      45             fast_bias_correction=False,
#      46             ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
#      47             advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alphas=AdvancedSmoothQuantParameters(convolution=0.95, matmul=-1))
#      48         )
#      49         # quantized_unet = nncf.quantize( #4.2
#      50         #     model=pipe.unet,
#      51         #     calibration_dataset=nncf.Dataset(unet_calibration_data),
#    (...)
#      59 # del text_encoder_2
#      60 # del vae_decoder
#      61 del unet
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/nncf/quantization/quantize_model.py:234, in quantize(model, calibration_dataset, mode, preset, target_device, subset_size, fast_bias_correction, model_type, ignored_scope, advanced_parameters)
#     231 if backend == BackendType.TORCH_FX:
#     232     from nncf.experimental.torch.fx.quantization.quantize_model import quantize_impl
# --> 234     return quantize_impl(
#     235         model=model,
#     236         calibration_dataset=calibration_dataset,
#     237         mode=mode,
#     238         preset=preset,
#     239         target_device=target_device,
#     240         subset_size=subset_size,
#     241         fast_bias_correction=fast_bias_correction,
#     242         model_type=model_type,
#     243         ignored_scope=ignored_scope,
#     244         advanced_parameters=advanced_parameters,
#     245     )
#     246 raise nncf.UnsupportedBackendError(f"Unsupported type of backend: {backend}")
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/nncf/experimental/torch/fx/quantization/quantize_model.py:85, in quantize_impl(model, calibration_dataset, mode, preset, target_device, subset_size, fast_bias_correction, model_type, ignored_scope, advanced_parameters)
#      82 apply_quantization_transformations(copied_model)
#      84 nncf_graph = NNCFGraphFactory.create(copied_model)
# ---> 85 quantized_model = quantization_algorithm.apply(copied_model, nncf_graph, dataset=calibration_dataset)
#      87 # Revert applied transformation to keep original model
#      88 # bias configuration.
#      89 revert_quantization_transformations(quantized_model)
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/nncf/quantization/algorithms/post_training/algorithm.py:112, in PostTrainingQuantization.apply(self, model, graph, statistic_points, dataset)
#     109 if statistic_points:
#     110     step_index_to_statistics = {0: statistic_points}
# --> 112 return self._pipeline.run_from_step(model, dataset, graph, 0, step_index_to_statistics)
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/nncf/quantization/algorithms/pipeline.py:164, in Pipeline.run_from_step(self, model, dataset, graph, start_step_index, step_index_to_statistics)
#     161         step_statistics = collect_statistics(statistic_points, step_model, step_graph, dataset)
#     163     # Run current pipeline step
# --> 164     step_model = self.run_step(step_index, step_statistics, step_model, step_graph)
#     166     step_graph = None  # We should rebuild the graph for the next pipeline step
#     168 return step_model
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/nncf/quantization/algorithms/pipeline.py:119, in Pipeline.run_step(self, step_index, step_statistics, model, graph)
#     117     current_model = algorithm.apply(current_model, current_graph, step_statistics)
#     118     current_graph = NNCFGraphFactory.create(current_model)
# --> 119 current_model = pipeline_step[-1].apply(current_model, current_graph, step_statistics)
#     121 return current_model
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/nncf/quantization/algorithms/bias_correction/algorithm.py:176, in BiasCorrection.apply(self, model, graph, statistic_points, dataset)
#     172 # Then we create the necessary data lists from the previously collected statistics,
#     173 # for the subgraph inference.
#     174 feed_dicts = self._create_feed_dicts(model_copy_subgraph, subgraph_data, statistic_points)
# --> 176 bias_shift = self._compute_bias_shift(node, model_copy_subgraph, feed_dicts, statistic_points)
#     178 current_bias = self._backend_entity.get_bias_value(node, model_copy, nncf_graph)
#     180 channel_axis = node.metatype.output_channel_axis
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/nncf/quantization/algorithms/bias_correction/algorithm.py:427, in BiasCorrection._compute_bias_shift(self, node, model, feed_dicts, statistic_points)
#     425 q_outputs = []
#     426 for feed_dict in feed_dicts:
# --> 427     q_output = engine.infer(feed_dict)
#     428     q_output = self._backend_entity.process_model_output(q_output, output_tensor_name)
#     429     q_outputs.append(mean_per_channel(q_output, channel_axis))
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/nncf/torch/engine.py:49, in PTEngine.infer(self, input_data)
#      41 """
#      42 Runs Torch model on the provided input.
#      43
#      44 :param input_data: Inputs for the model.
#      45 :return: Model outputs.
#      46 """
#      48 if isinstance(input_data, dict):
# ---> 49     return self._model(**input_data)
#      50 if isinstance(input_data, tuple):
#      51     return self._model(*input_data)
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/torch/fx/graph_module.py:737, in GraphModule.recompile.<locals>.call_wrapped(self, *args, **kwargs)
#     736 def call_wrapped(self, *args, **kwargs):
# --> 737     return self._wrapped_call(self, *args, **kwargs)
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/torch/fx/graph_module.py:317, in _WrappedCall.__call__(self, obj, *args, **kwargs)
#     315     raise e.with_traceback(None)  # noqa: TRY200
#     316 else:
# --> 317     raise e
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/torch/fx/graph_module.py:304, in _WrappedCall.__call__(self, obj, *args, **kwargs)
#     302         return self.cls_call(obj, *args, **kwargs)
#     303     else:
# --> 304         return super(self.cls, obj).__call__(*args, **kwargs)  # type: ignore[misc]
#     305 except Exception as e:
#     306     assert e.__traceback__
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# TypeError: forward() missing 1 required positional argument: 'arg2'

# %% [markdown]
# ### Compile Models with OV Backend

# %%
pipe.unet = torch.compile(quantized_unet, backend='openvino')
del quantized_unet

# %% [markdown]
# ### Inference for Compilation

# %%
#Warmup the model for initial compile
prompt = "valley in the Alps at sunset, epic vista, beautiful landscape, 4k, 8k"
negative_prompt = "frames, borderline, text, charachter, duplicate, error, out of frame, watermark, low quality, ugly, deformed, blur"
num_steps = 1
with torch.no_grad():
    image = pipe(prompt=prompt, negative_prompt=negative_prompt, num_inference_steps=num_steps, generator=generator).images[0]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# Reached
# torch.Size([1, 4, 128, 128])

# %%
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)
with torch.no_grad():
    image = pipe(prompt=prompt, negative_prompt=negative_prompt, num_inference_steps=25, generator=generator).images[0]
image.show()
image.save("experiment_4.png")
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# Reached
# torch.Size([1, 4, 128, 128])
