# %% [markdown]
# # Stable Diffusion v2 Demo with Torch Compile

# %% [markdown]
# ## Stable Diffusion v2 for Text-to-Image Generation
#
# To start, let's look on Text-to-Image process for Stable Diffusion v2. We will use [Stable Diffusion v2-1](https://huggingface.co/stabilityai/stable-diffusion-2-1) model for these purposes. The main difference from Stable Diffusion v2 and Stable Diffusion v2.1 is usage of more data, more training, and less restrictive filtering of the dataset, that gives promising results for selecting wide range of input text prompts. More details about model can be found in [Stability AI blog post](https://stability.ai/blog/stablediffusion2-1-release7-dec-2022) and original model [repository](https://github.com/Stability-AI/stablediffusion).
#
# ### Stable Diffusion in Diffusers library
# To work with Stable Diffusion v2, we will use Hugging Face [Diffusers](https://github.com/huggingface/diffusers) library. To experiment with Stable Diffusion models, Diffusers exposes the [`StableDiffusionPipeline`](https://huggingface.co/docs/diffusers/using-diffusers/conditional_image_generation) similar to the [other Diffusers pipelines](https://huggingface.co/docs/diffusers/api/pipelines/overview).  The code below demonstrates how to create `StableDiffusionPipeline` using `stable-diffusion-2-1`:

# %%
from torch._export import capture_pre_autograd_graph
from nncf.torch.dynamic_graph.patch_pytorch import disable_patching
import numpy as np
import gc
# Out:
# INFO:nncf:NNCF initialized successfully. Supported frameworks detected: torch, onnx, openvino
# WARNING:nncf:NNCF provides best results with torch==2.4.*, while current torch version is 2.3.1+cpu. If you encounter issues, consider switching to torch==2.4.*

# %%
from diffusers import DiffusionPipeline
import torch
import random
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)
generator = torch.Generator(device="cpu").manual_seed(42)
pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0")
pipe.to("cpu")

prompt = "valley in the Alps at sunset, epic vista, beautiful landscape, 4k, 8k"
negative_prompt = "frames, borderline, text, charachter, duplicate, error, out of frame, watermark, low quality, ugly, deformed, blur"
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# ### Convert Models to Torch Fx Graph

# %%
text_encoder_input = torch.ones((1, 77), dtype=torch.long)
text_encoder_2_input = torch.ones((1, 77), dtype=torch.long)
vae_encoder_input = torch.ones((1, 3, 256, 256))
vae_decoder_input = torch.ones((1, 4, 128, 128))
vae_decoder_kwargs = {}
vae_decoder_kwargs["return_dict"] = False
latents_shape = (2, 4, 128, 128)
latents = torch.randn(latents_shape)
t = torch.from_numpy(np.array(1, dtype=np.float32))
added_cond_kwargs = {}
added_cond_kwargs["text_embeds"] = torch.ones((2, 1280))
added_cond_kwargs["time_ids"] = torch.ones((2,6))
unet_kwargs = {}
unet_kwargs["encoder_hidden_states"] = torch.ones((2, 77, 2048))
unet_kwargs["added_cond_kwargs"] = added_cond_kwargs
unet_kwargs["return_dict"] = False
unet_input = (latents, t)

text_encoder_kwargs = {}
text_encoder_kwargs['output_hidden_states'] = True

with torch.no_grad():
    with disable_patching():
        text_encoder = capture_pre_autograd_graph(pipe.text_encoder.eval(), args=(text_encoder_input,), kwargs=(text_encoder_kwargs))
        text_encoder_2 = capture_pre_autograd_graph(pipe.text_encoder_2.eval(), args=(text_encoder_2_input,), kwargs=(text_encoder_kwargs))
        vae_encoder = capture_pre_autograd_graph(pipe.vae.encoder.eval(), args=(vae_encoder_input,))
        vae_decoder = capture_pre_autograd_graph(pipe.vae.decoder.eval(), args=(vae_decoder_input,))
        unet = capture_pre_autograd_graph(pipe.unet.eval(), args=(*unet_input,), kwargs=(unet_kwargs))
del added_cond_kwargs
del unet_kwargs
del unet_input
del latents
del t
del vae_encoder_input
del vae_decoder_input
del text_encoder_2_input
del text_encoder_input
del text_encoder_kwargs
del vae_decoder_kwargs

# %%
pipe.text_encoder = text_encoder
pipe.text_encoder_2 = text_encoder_2
pipe.vae.decoder = vae_decoder
pipe.vae.encoder = vae_encoder
pipe.unet = unet

# %% [markdown]
# ### Weights Compression

# %%
import pickle
with open("test_faster", "rb") as fp:
    unet_calibration_data = pickle.load(fp)

def collect_ops_with_weights(graph_module):
    ops_with_weights = []
    for node in graph_module.graph.nodes:
        if "linear" in node.name:
            ops_with_weights.append(node.name)
    return ops_with_weights

unet_ignored_scope = collect_ops_with_weights(pipe.unet)

# %%
import nncf
from nncf.quantization.advanced_parameters import AdvancedSmoothQuantParameters
from nncf.quantization.range_estimator import RangeEstimatorParametersSet

def disable_progress_bar(pipeline, disable=True):
    if not hasattr(pipeline, "_progress_bar_config"):
        pipeline._progress_bar_config = {'disable': disable}
    else:
        pipeline._progress_bar_config['disable'] = disable

with disable_patching():
    with torch.no_grad():
        compressed_text_encoder = nncf.compress_weights(text_encoder)
        compressed_text_encoder_2 = nncf.compress_weights(text_encoder_2)
        compressed_vae_encoder = nncf.compress_weights(vae_encoder)
        compressed_vae_decoder = nncf.compress_weights(vae_decoder)
        # compressed_unet = nncf.compress_weights(unet, ignored_scope=nncf.IgnoredScope(types=['conv2d']))
        # quantized_unet = nncf.quantize( #1
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1, disable_bias_correction=True)
        # )
        quantized_unet = nncf.quantize( #2
            model=pipe.unet,
            calibration_dataset=nncf.Dataset(unet_calibration_data),
            subset_size=len(unet_calibration_data),
            model_type=nncf.ModelType.TRANSFORMER,
            ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
            advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1, disable_bias_correction=True, weights_range_estimator_params=RangeEstimatorParametersSet.MINMAX, activations_range_estimator_params=RangeEstimatorParametersSet.MINMAX)
        )
        # quantized_unet = nncf.quantize( #3
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     fast_bias_correction=False,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alpha=-1)
        # )
        # quantized_unet = nncf.quantize( #4.1
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     fast_bias_correction=False,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alphas=AdvancedSmoothQuantParameters(convolution=0.95, matmul=-1))
        # )
        # quantized_unet = nncf.quantize( #4.2
        #     model=pipe.unet,
        #     calibration_dataset=nncf.Dataset(unet_calibration_data),
        #     subset_size=len(unet_calibration_data),
        #     model_type=nncf.ModelType.TRANSFORMER,
        #     fast_bias_correction=False,
        #     ignored_scope=nncf.IgnoredScope(names=unet_ignored_scope),
        #     advanced_parameters=nncf.AdvancedQuantizationParameters(smooth_quant_alphas=AdvancedSmoothQuantParameters(convolution=0.95))
        # )
del text_encoder
del text_encoder_2
del vae_decoder
del vae_encoder
del unet
# Out:
# INFO:nncf:Statistics of the bitwidth distribution:
# ┍━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
# │   Num bits (N) │ % all parameters (layers)   │ % ratio-defining parameters (layers)   │
# ┝━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │              8 │ 100% (74 / 74)              │ 100% (74 / 74)                         │
# ┕━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:nncf:Statistics of the bitwidth distribution:
# ┍━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
# │   Num bits (N) │ % all parameters (layers)   │ % ratio-defining parameters (layers)   │
# ┝━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │              8 │ 100% (195 / 195)            │ 100% (195 / 195)                       │
# ┕━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:nncf:Statistics of the bitwidth distribution:
# ┍━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
# │   Num bits (N) │ % all parameters (layers)   │ % ratio-defining parameters (layers)   │
# ┝━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │              8 │ 100% (31 / 31)              │ 100% (31 / 31)                         │
# ┕━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:nncf:Statistics of the bitwidth distribution:
# ┍━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
# │   Num bits (N) │ % all parameters (layers)   │ % ratio-defining parameters (layers)   │
# ┝━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │              8 │ 100% (39 / 39)              │ 100% (39 / 39)                         │
# ┕━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# WARNING:nncf:Experimental Torch FX quantization backend is being used for the given torch.fx.GraphModule model. Torch FX PTQ is an experimental feature, consider using Torch or OpenVino PTQ backends in case of errors or a poor model performance.
# /home/user/Downloads/openvino_notebooks/.venv/lib/python3.10/site-packages/nncf/quantization/algorithms/post_training/pipeline.py:87: FutureWarning: `AdvancedQuantizationParameters(smooth_quant_alpha=..)` is deprecated.Please, use `AdvancedQuantizationParameters(smooth_quant_alphas)` option with AdvancedSmoothQuantParameters(convolution=.., matmul=..) as value instead.
#   warning_deprecated(
# INFO:nncf:743 ignored nodes were found by names in the NNCFGraph
# INFO:nncf:Not adding activation input quantizer for operation: 1011 linear_119
# INFO:nncf:Not adding activation input quantizer for operation: 1013 linear_120
# INFO:nncf:Not adding activation input quantizer for operation: 1081 linear_129
# INFO:nncf:Not adding activation input quantizer for operation: 1083 linear_130
# INFO:nncf:Not adding activation input quantizer for operation: 1151 linear_139
# INFO:nncf:Not adding activation input quantizer for operation: 1153 linear_140
# INFO:nncf:Not adding activation input quantizer for operation: 1221 linear_149
# INFO:nncf:Not adding activation input quantizer for operation: 1223 linear_150
# INFO:nncf:Not adding activation input quantizer for operation: 1337 linear_162
# INFO:nncf:Not adding activation input quantizer for operation: 1339 linear_163
# INFO:nncf:Not adding activation input quantizer for operation: 1407 linear_172
# INFO:nncf:Not adding activation input quantizer for operation: 1409 linear_173
# INFO:nncf:Not adding activation input quantizer for operation: 1477 linear_182
# INFO:nncf:Not adding activation input quantizer for operation: 1479 linear_183
# INFO:nncf:Not adding activation input quantizer for operation: 1547 linear_192
# INFO:nncf:Not adding activation input quantizer for operation: 1549 linear_193
# INFO:nncf:Not adding activation input quantizer for operation: 1617 linear_202
# INFO:nncf:Not adding activation input quantizer for operation: 1619 linear_203
# INFO:nncf:Not adding activation input quantizer for operation: 1687 linear_212
# INFO:nncf:Not adding activation input quantizer for operation: 1689 linear_213
# INFO:nncf:Not adding activation input quantizer for operation: 1757 linear_222
# INFO:nncf:Not adding activation input quantizer for operation: 1759 linear_223
# INFO:nncf:Not adding activation input quantizer for operation: 1827 linear_232
# INFO:nncf:Not adding activation input quantizer for operation: 1829 linear_233
# INFO:nncf:Not adding activation input quantizer for operation: 1897 linear_242
# INFO:nncf:Not adding activation input quantizer for operation: 1899 linear_243
# INFO:nncf:Not adding activation input quantizer for operation: 1967 linear_252
# INFO:nncf:Not adding activation input quantizer for operation: 1969 linear_253
# INFO:nncf:Not adding activation input quantizer for operation: 2083 linear_265
# INFO:nncf:Not adding activation input quantizer for operation: 2085 linear_266
# INFO:nncf:Not adding activation input quantizer for operation: 211 linear_13
# INFO:nncf:Not adding activation input quantizer for operation: 213 linear_14
# INFO:nncf:Not adding activation input quantizer for operation: 2153 linear_275
# INFO:nncf:Not adding activation input quantizer for operation: 2155 linear_276
# INFO:nncf:Not adding activation input quantizer for operation: 2223 linear_285
# INFO:nncf:Not adding activation input quantizer for operation: 2225 linear_286
# INFO:nncf:Not adding activation input quantizer for operation: 2293 linear_295
# INFO:nncf:Not adding activation input quantizer for operation: 2295 linear_296
# INFO:nncf:Not adding activation input quantizer for operation: 2363 linear_305
# INFO:nncf:Not adding activation input quantizer for operation: 2365 linear_306
# INFO:nncf:Not adding activation input quantizer for operation: 2433 linear_315
# INFO:nncf:Not adding activation input quantizer for operation: 2435 linear_316
# INFO:nncf:Not adding activation input quantizer for operation: 2503 linear_325
# INFO:nncf:Not adding activation input quantizer for operation: 2505 linear_326
# INFO:nncf:Not adding activation input quantizer for operation: 2573 linear_335
# INFO:nncf:Not adding activation input quantizer for operation: 2575 linear_336
# INFO:nncf:Not adding activation input quantizer for operation: 2643 linear_345
# INFO:nncf:Not adding activation input quantizer for operation: 2645 linear_346
# INFO:nncf:Not adding activation input quantizer for operation: 2713 linear_355
# INFO:nncf:Not adding activation input quantizer for operation: 2715 linear_356
# INFO:nncf:Not adding activation input quantizer for operation: 281 linear_23
# INFO:nncf:Not adding activation input quantizer for operation: 283 linear_24
# INFO:nncf:Not adding activation input quantizer for operation: 2863 linear_369
# INFO:nncf:Not adding activation input quantizer for operation: 2865 linear_370
# INFO:nncf:Not adding activation input quantizer for operation: 2933 linear_379
# INFO:nncf:Not adding activation input quantizer for operation: 2935 linear_380
# INFO:nncf:Not adding activation input quantizer for operation: 3003 linear_389
# INFO:nncf:Not adding activation input quantizer for operation: 3005 linear_390
# INFO:nncf:Not adding activation input quantizer for operation: 3073 linear_399
# INFO:nncf:Not adding activation input quantizer for operation: 3075 linear_400
# INFO:nncf:Not adding activation input quantizer for operation: 3143 linear_409
# INFO:nncf:Not adding activation input quantizer for operation: 3145 linear_410
# INFO:nncf:Not adding activation input quantizer for operation: 3213 linear_419
# INFO:nncf:Not adding activation input quantizer for operation: 3215 linear_420
# INFO:nncf:Not adding activation input quantizer for operation: 3283 linear_429
# INFO:nncf:Not adding activation input quantizer for operation: 3285 linear_430
# INFO:nncf:Not adding activation input quantizer for operation: 3353 linear_439
# INFO:nncf:Not adding activation input quantizer for operation: 3355 linear_440
# INFO:nncf:Not adding activation input quantizer for operation: 3423 linear_449
# INFO:nncf:Not adding activation input quantizer for operation: 3425 linear_450
# INFO:nncf:Not adding activation input quantizer for operation: 3493 linear_459
# INFO:nncf:Not adding activation input quantizer for operation: 3495 linear_460
# INFO:nncf:Not adding activation input quantizer for operation: 3614 linear_472
# INFO:nncf:Not adding activation input quantizer for operation: 3616 linear_473
# INFO:nncf:Not adding activation input quantizer for operation: 3684 linear_482
# INFO:nncf:Not adding activation input quantizer for operation: 3686 linear_483
# INFO:nncf:Not adding activation input quantizer for operation: 3754 linear_492
# INFO:nncf:Not adding activation input quantizer for operation: 3756 linear_493
# INFO:nncf:Not adding activation input quantizer for operation: 3824 linear_502
# INFO:nncf:Not adding activation input quantizer for operation: 3826 linear_503
# INFO:nncf:Not adding activation input quantizer for operation: 3894 linear_512
# INFO:nncf:Not adding activation input quantizer for operation: 3896 linear_513
# INFO:nncf:Not adding activation input quantizer for operation: 3964 linear_522
# INFO:nncf:Not adding activation input quantizer for operation: 3966 linear_523
# INFO:nncf:Not adding activation input quantizer for operation: 397 linear_36
# INFO:nncf:Not adding activation input quantizer for operation: 399 linear_37
# INFO:nncf:Not adding activation input quantizer for operation: 4034 linear_532
# INFO:nncf:Not adding activation input quantizer for operation: 4036 linear_533
# INFO:nncf:Not adding activation input quantizer for operation: 4104 linear_542
# INFO:nncf:Not adding activation input quantizer for operation: 4106 linear_543
# INFO:nncf:Not adding activation input quantizer for operation: 4174 linear_552
# INFO:nncf:Not adding activation input quantizer for operation: 4176 linear_553
# INFO:nncf:Not adding activation input quantizer for operation: 4244 linear_562
# INFO:nncf:Not adding activation input quantizer for operation: 4246 linear_563
# INFO:nncf:Not adding activation input quantizer for operation: 4365 linear_575
# INFO:nncf:Not adding activation input quantizer for operation: 4367 linear_576
# INFO:nncf:Not adding activation input quantizer for operation: 4435 linear_585
# INFO:nncf:Not adding activation input quantizer for operation: 4437 linear_586
# INFO:nncf:Not adding activation input quantizer for operation: 4505 linear_595
# INFO:nncf:Not adding activation input quantizer for operation: 4507 linear_596
# INFO:nncf:Not adding activation input quantizer for operation: 4575 linear_605
# INFO:nncf:Not adding activation input quantizer for operation: 4577 linear_606
# INFO:nncf:Not adding activation input quantizer for operation: 4645 linear_615
# INFO:nncf:Not adding activation input quantizer for operation: 4647 linear_616
# INFO:nncf:Not adding activation input quantizer for operation: 467 linear_46
# INFO:nncf:Not adding activation input quantizer for operation: 469 linear_47
# INFO:nncf:Not adding activation input quantizer for operation: 4715 linear_625
# INFO:nncf:Not adding activation input quantizer for operation: 4717 linear_626
# INFO:nncf:Not adding activation input quantizer for operation: 4785 linear_635
# INFO:nncf:Not adding activation input quantizer for operation: 4787 linear_636
# INFO:nncf:Not adding activation input quantizer for operation: 4855 linear_645
# INFO:nncf:Not adding activation input quantizer for operation: 4857 linear_646
# INFO:nncf:Not adding activation input quantizer for operation: 4925 linear_655
# INFO:nncf:Not adding activation input quantizer for operation: 4927 linear_656
# INFO:nncf:Not adding activation input quantizer for operation: 4995 linear_665
# INFO:nncf:Not adding activation input quantizer for operation: 4997 linear_666
# INFO:nncf:Not adding activation input quantizer for operation: 5121 linear_678
# INFO:nncf:Not adding activation input quantizer for operation: 5123 linear_679
# INFO:nncf:Not adding activation input quantizer for operation: 5191 linear_688
# INFO:nncf:Not adding activation input quantizer for operation: 5193 linear_689
# INFO:nncf:Not adding activation input quantizer for operation: 5312 linear_701
# INFO:nncf:Not adding activation input quantizer for operation: 5314 linear_702
# INFO:nncf:Not adding activation input quantizer for operation: 5382 linear_711
# INFO:nncf:Not adding activation input quantizer for operation: 5384 linear_712
# INFO:nncf:Not adding activation input quantizer for operation: 5503 linear_724
# INFO:nncf:Not adding activation input quantizer for operation: 5505 linear_725
# INFO:nncf:Not adding activation input quantizer for operation: 5573 linear_734
# INFO:nncf:Not adding activation input quantizer for operation: 5575 linear_735
# INFO:nncf:Not adding activation input quantizer for operation: 591 linear_59
# INFO:nncf:Not adding activation input quantizer for operation: 593 linear_60
# INFO:nncf:Not adding activation input quantizer for operation: 661 linear_69
# INFO:nncf:Not adding activation input quantizer for operation: 663 linear_70
# INFO:nncf:Not adding activation input quantizer for operation: 731 linear_79
# INFO:nncf:Not adding activation input quantizer for operation: 733 linear_80
# INFO:nncf:Not adding activation input quantizer for operation: 801 linear_89
# INFO:nncf:Not adding activation input quantizer for operation: 803 linear_90
# INFO:nncf:Not adding activation input quantizer for operation: 871 linear_99
# INFO:nncf:Not adding activation input quantizer for operation: 873 linear_100
# INFO:nncf:Not adding activation input quantizer for operation: 941 linear_109
# INFO:nncf:Not adding activation input quantizer for operation: 943 linear_110
# INFO:nncf:Not adding activation input quantizer for operation: 30 linear
# 32 add_tensor
#
# INFO:nncf:Not adding activation input quantizer for operation: 35 linear_1
# 37 add_tensor_1
#
# INFO:nncf:Not adding activation input quantizer for operation: 62 linear_2
# 64 add_tensor_2
#
# INFO:nncf:Not adding activation input quantizer for operation: 67 linear_3
# 69 add_tensor_3
#
# INFO:nncf:Not adding activation input quantizer for operation: 114 linear_5
# 116 add_tensor_5
#
# INFO:nncf:Not adding activation input quantizer for operation: 1277 linear_155
# 1279 add_tensor_71
#
# INFO:nncf:Not adding activation input quantizer for operation: 147 linear_6
# 149 add_tensor_6
#
# INFO:nncf:Not adding activation input quantizer for operation: 2023 linear_258
# 2025 add_tensor_114
#
# INFO:nncf:Not adding activation input quantizer for operation: 2769 linear_361
# 2771 add_tensor_157
#
# INFO:nncf:Not adding activation input quantizer for operation: 2799 linear_362
# 2801 add_tensor_158
#
# INFO:nncf:Not adding activation input quantizer for operation: 337 linear_29
# 339 add_tensor_17
#
# INFO:nncf:Not adding activation input quantizer for operation: 3550 linear_465
# 3552 add_tensor_201
#
# INFO:nncf:Not adding activation input quantizer for operation: 4301 linear_568
# 4303 add_tensor_244
#
# INFO:nncf:Not adding activation input quantizer for operation: 5057 linear_671
# 5059 add_tensor_287
#
# INFO:nncf:Not adding activation input quantizer for operation: 5248 linear_694
# 5250 add_tensor_298
#
# INFO:nncf:Not adding activation input quantizer for operation: 527 linear_52
# 529 add_tensor_28
#
# INFO:nncf:Not adding activation input quantizer for operation: 5439 linear_717
# 5441 add_tensor_309
#
# INFO:nncf:Not adding activation input quantizer for operation: 5635 linear_740
# 5637 add_tensor_320
#
# INFO:nncf:Not adding activation input quantizer for operation: 5669 linear_741
# 5671 add_tensor_321
#
# INFO:nncf:Not adding activation input quantizer for operation: 5703 linear_742
# 5705 add_tensor_322
#
# INFO:nncf:Not adding activation input quantizer for operation: 85 linear_4
# 87 add_tensor_4
#
# INFO:nncf:Not adding activation input quantizer for operation: 176 linear_7
# 178 add_tensor_7
#
# INFO:nncf:Not adding activation input quantizer for operation: 183 linear_8
# INFO:nncf:Not adding activation input quantizer for operation: 185 linear_9
# INFO:nncf:Not adding activation input quantizer for operation: 187 linear_10
# INFO:nncf:Not adding activation input quantizer for operation: 199 linear_11
# 201 add_tensor_8
# 203 div_5
#
# INFO:nncf:Not adding activation input quantizer for operation: 209 linear_12
# INFO:nncf:Not adding activation input quantizer for operation: 225 linear_15
# 227 add_tensor_9
# 229 div_6
#
# INFO:nncf:Not adding activation input quantizer for operation: 235 linear_16
# 237 add_tensor_10
#
# INFO:nncf:Not adding activation input quantizer for operation: 245 linear_17
# 247 add_tensor_11
#
# INFO:nncf:Not adding activation input quantizer for operation: 253 linear_18
# INFO:nncf:Not adding activation input quantizer for operation: 255 linear_19
# INFO:nncf:Not adding activation input quantizer for operation: 257 linear_20
# INFO:nncf:Not adding activation input quantizer for operation: 269 linear_21
# 271 add_tensor_12
# 273 div_7
#
# INFO:nncf:Not adding activation input quantizer for operation: 279 linear_22
# INFO:nncf:Not adding activation input quantizer for operation: 295 linear_25
# 297 add_tensor_13
# 299 div_8
#
# INFO:nncf:Not adding activation input quantizer for operation: 305 linear_26
# 307 add_tensor_14
#
# INFO:nncf:Not adding activation input quantizer for operation: 315 linear_27
# 317 add_tensor_15
#
# INFO:nncf:Not adding activation input quantizer for operation: 320 linear_28
# 322 add_tensor_16
#
# INFO:nncf:Not adding activation input quantizer for operation: 362 linear_30
# 364 add_tensor_18
#
# INFO:nncf:Not adding activation input quantizer for operation: 369 linear_31
# INFO:nncf:Not adding activation input quantizer for operation: 371 linear_32
# INFO:nncf:Not adding activation input quantizer for operation: 373 linear_33
# INFO:nncf:Not adding activation input quantizer for operation: 385 linear_34
# 387 add_tensor_19
# 389 div_10
#
# INFO:nncf:Not adding activation input quantizer for operation: 395 linear_35
# INFO:nncf:Not adding activation input quantizer for operation: 411 linear_38
# 413 add_tensor_20
# 415 div_11
#
# INFO:nncf:Not adding activation input quantizer for operation: 421 linear_39
# 423 add_tensor_21
#
# INFO:nncf:Not adding activation input quantizer for operation: 431 linear_40
# 433 add_tensor_22
#
# INFO:nncf:Not adding activation input quantizer for operation: 439 linear_41
# INFO:nncf:Not adding activation input quantizer for operation: 441 linear_42
# INFO:nncf:Not adding activation input quantizer for operation: 443 linear_43
# INFO:nncf:Not adding activation input quantizer for operation: 455 linear_44
# 457 add_tensor_23
# 459 div_12
#
# INFO:nncf:Not adding activation input quantizer for operation: 465 linear_45
# INFO:nncf:Not adding activation input quantizer for operation: 481 linear_48
# 483 add_tensor_24
# 485 div_13
#
# INFO:nncf:Not adding activation input quantizer for operation: 491 linear_49
# 493 add_tensor_25
#
# INFO:nncf:Not adding activation input quantizer for operation: 501 linear_50
# 503 add_tensor_26
#
# INFO:nncf:Not adding activation input quantizer for operation: 506 linear_51
# 508 add_tensor_27
#
# INFO:nncf:Not adding activation input quantizer for operation: 556 linear_53
# 558 add_tensor_29
#
# INFO:nncf:Not adding activation input quantizer for operation: 563 linear_54
# INFO:nncf:Not adding activation input quantizer for operation: 565 linear_55
# INFO:nncf:Not adding activation input quantizer for operation: 567 linear_56
# INFO:nncf:Not adding activation input quantizer for operation: 579 linear_57
# 581 add_tensor_30
# 583 div_15
#
# INFO:nncf:Not adding activation input quantizer for operation: 589 linear_58
# INFO:nncf:Not adding activation input quantizer for operation: 605 linear_61
# 607 add_tensor_31
# 609 div_16
#
# INFO:nncf:Not adding activation input quantizer for operation: 615 linear_62
# 617 add_tensor_32
#
# INFO:nncf:Not adding activation input quantizer for operation: 625 linear_63
# 627 add_tensor_33
#
# INFO:nncf:Not adding activation input quantizer for operation: 633 linear_64
# INFO:nncf:Not adding activation input quantizer for operation: 635 linear_65
# INFO:nncf:Not adding activation input quantizer for operation: 637 linear_66
# INFO:nncf:Not adding activation input quantizer for operation: 649 linear_67
# 651 add_tensor_34
# 653 div_17
#
# INFO:nncf:Not adding activation input quantizer for operation: 659 linear_68
# INFO:nncf:Not adding activation input quantizer for operation: 675 linear_71
# 677 add_tensor_35
# 679 div_18
#
# INFO:nncf:Not adding activation input quantizer for operation: 685 linear_72
# 687 add_tensor_36
#
# INFO:nncf:Not adding activation input quantizer for operation: 695 linear_73
# 697 add_tensor_37
#
# INFO:nncf:Not adding activation input quantizer for operation: 703 linear_74
# INFO:nncf:Not adding activation input quantizer for operation: 705 linear_75
# INFO:nncf:Not adding activation input quantizer for operation: 707 linear_76
# INFO:nncf:Not adding activation input quantizer for operation: 719 linear_77
# 721 add_tensor_38
# 723 div_19
#
# INFO:nncf:Not adding activation input quantizer for operation: 729 linear_78
# INFO:nncf:Not adding activation input quantizer for operation: 745 linear_81
# 747 add_tensor_39
# 749 div_20
#
# INFO:nncf:Not adding activation input quantizer for operation: 755 linear_82
# 757 add_tensor_40
#
# INFO:nncf:Not adding activation input quantizer for operation: 765 linear_83
# 767 add_tensor_41
#
# INFO:nncf:Not adding activation input quantizer for operation: 773 linear_84
# INFO:nncf:Not adding activation input quantizer for operation: 775 linear_85
# INFO:nncf:Not adding activation input quantizer for operation: 777 linear_86
# INFO:nncf:Not adding activation input quantizer for operation: 789 linear_87
# 791 add_tensor_42
# 793 div_21
#
# INFO:nncf:Not adding activation input quantizer for operation: 799 linear_88
# INFO:nncf:Not adding activation input quantizer for operation: 815 linear_91
# 817 add_tensor_43
# 819 div_22
#
# INFO:nncf:Not adding activation input quantizer for operation: 825 linear_92
# 827 add_tensor_44
#
# INFO:nncf:Not adding activation input quantizer for operation: 835 linear_93
# 837 add_tensor_45
#
# INFO:nncf:Not adding activation input quantizer for operation: 843 linear_94
# INFO:nncf:Not adding activation input quantizer for operation: 845 linear_95
# INFO:nncf:Not adding activation input quantizer for operation: 847 linear_96
# INFO:nncf:Not adding activation input quantizer for operation: 859 linear_97
# 861 add_tensor_46
# 863 div_23
#
# INFO:nncf:Not adding activation input quantizer for operation: 869 linear_98
# INFO:nncf:Not adding activation input quantizer for operation: 885 linear_101
# 887 add_tensor_47
# 889 div_24
#
# INFO:nncf:Not adding activation input quantizer for operation: 895 linear_102
# 897 add_tensor_48
#
# INFO:nncf:Not adding activation input quantizer for operation: 905 linear_103
# 907 add_tensor_49
#
# INFO:nncf:Not adding activation input quantizer for operation: 913 linear_104
# INFO:nncf:Not adding activation input quantizer for operation: 915 linear_105
# INFO:nncf:Not adding activation input quantizer for operation: 917 linear_106
# INFO:nncf:Not adding activation input quantizer for operation: 929 linear_107
# 931 add_tensor_50
# 933 div_25
#
# INFO:nncf:Not adding activation input quantizer for operation: 939 linear_108
# INFO:nncf:Not adding activation input quantizer for operation: 955 linear_111
# 957 add_tensor_51
# 959 div_26
#
# INFO:nncf:Not adding activation input quantizer for operation: 965 linear_112
# 967 add_tensor_52
#
# INFO:nncf:Not adding activation input quantizer for operation: 975 linear_113
# 977 add_tensor_53
#
# INFO:nncf:Not adding activation input quantizer for operation: 983 linear_114
# INFO:nncf:Not adding activation input quantizer for operation: 985 linear_115
# INFO:nncf:Not adding activation input quantizer for operation: 987 linear_116
# INFO:nncf:Not adding activation input quantizer for operation: 999 linear_117
# 1001 add_tensor_54
# 1003 div_27
#
# INFO:nncf:Not adding activation input quantizer for operation: 1009 linear_118
# INFO:nncf:Not adding activation input quantizer for operation: 1025 linear_121
# 1027 add_tensor_55
# 1029 div_28
#
# INFO:nncf:Not adding activation input quantizer for operation: 1035 linear_122
# 1037 add_tensor_56
#
# INFO:nncf:Not adding activation input quantizer for operation: 1045 linear_123
# 1047 add_tensor_57
#
# INFO:nncf:Not adding activation input quantizer for operation: 1053 linear_124
# INFO:nncf:Not adding activation input quantizer for operation: 1055 linear_125
# INFO:nncf:Not adding activation input quantizer for operation: 1057 linear_126
# INFO:nncf:Not adding activation input quantizer for operation: 1069 linear_127
# 1071 add_tensor_58
# 1073 div_29
#
# INFO:nncf:Not adding activation input quantizer for operation: 1079 linear_128
# INFO:nncf:Not adding activation input quantizer for operation: 1095 linear_131
# 1097 add_tensor_59
# 1099 div_30
#
# INFO:nncf:Not adding activation input quantizer for operation: 1105 linear_132
# 1107 add_tensor_60
#
# INFO:nncf:Not adding activation input quantizer for operation: 1115 linear_133
# 1117 add_tensor_61
#
# INFO:nncf:Not adding activation input quantizer for operation: 1123 linear_134
# INFO:nncf:Not adding activation input quantizer for operation: 1125 linear_135
# INFO:nncf:Not adding activation input quantizer for operation: 1127 linear_136
# INFO:nncf:Not adding activation input quantizer for operation: 1139 linear_137
# 1141 add_tensor_62
# 1143 div_31
#
# INFO:nncf:Not adding activation input quantizer for operation: 1149 linear_138
# INFO:nncf:Not adding activation input quantizer for operation: 1165 linear_141
# 1167 add_tensor_63
# 1169 div_32
#
# INFO:nncf:Not adding activation input quantizer for operation: 1175 linear_142
# 1177 add_tensor_64
#
# INFO:nncf:Not adding activation input quantizer for operation: 1185 linear_143
# 1187 add_tensor_65
#
# INFO:nncf:Not adding activation input quantizer for operation: 1193 linear_144
# INFO:nncf:Not adding activation input quantizer for operation: 1195 linear_145
# INFO:nncf:Not adding activation input quantizer for operation: 1197 linear_146
# INFO:nncf:Not adding activation input quantizer for operation: 1209 linear_147
# 1211 add_tensor_66
# 1213 div_33
#
# INFO:nncf:Not adding activation input quantizer for operation: 1219 linear_148
# INFO:nncf:Not adding activation input quantizer for operation: 1235 linear_151
# 1237 add_tensor_67
# 1239 div_34
#
# INFO:nncf:Not adding activation input quantizer for operation: 1245 linear_152
# 1247 add_tensor_68
#
# INFO:nncf:Not adding activation input quantizer for operation: 1255 linear_153
# 1257 add_tensor_69
#
# INFO:nncf:Not adding activation input quantizer for operation: 1260 linear_154
# 1262 add_tensor_70
#
# INFO:nncf:Not adding activation input quantizer for operation: 1302 linear_156
# 1304 add_tensor_72
#
# INFO:nncf:Not adding activation input quantizer for operation: 1309 linear_157
# INFO:nncf:Not adding activation input quantizer for operation: 1311 linear_158
# INFO:nncf:Not adding activation input quantizer for operation: 1313 linear_159
# INFO:nncf:Not adding activation input quantizer for operation: 1325 linear_160
# 1327 add_tensor_73
# 1329 div_36
#
# INFO:nncf:Not adding activation input quantizer for operation: 1335 linear_161
# INFO:nncf:Not adding activation input quantizer for operation: 1351 linear_164
# 1353 add_tensor_74
# 1355 div_37
#
# INFO:nncf:Not adding activation input quantizer for operation: 1361 linear_165
# 1363 add_tensor_75
#
# INFO:nncf:Not adding activation input quantizer for operation: 1371 linear_166
# 1373 add_tensor_76
#
# INFO:nncf:Not adding activation input quantizer for operation: 1379 linear_167
# INFO:nncf:Not adding activation input quantizer for operation: 1381 linear_168
# INFO:nncf:Not adding activation input quantizer for operation: 1383 linear_169
# INFO:nncf:Not adding activation input quantizer for operation: 1395 linear_170
# 1397 add_tensor_77
# 1399 div_38
#
# INFO:nncf:Not adding activation input quantizer for operation: 1405 linear_171
# INFO:nncf:Not adding activation input quantizer for operation: 1421 linear_174
# 1423 add_tensor_78
# 1425 div_39
#
# INFO:nncf:Not adding activation input quantizer for operation: 1431 linear_175
# 1433 add_tensor_79
#
# INFO:nncf:Not adding activation input quantizer for operation: 1441 linear_176
# 1443 add_tensor_80
#
# INFO:nncf:Not adding activation input quantizer for operation: 1449 linear_177
# INFO:nncf:Not adding activation input quantizer for operation: 1451 linear_178
# INFO:nncf:Not adding activation input quantizer for operation: 1453 linear_179
# INFO:nncf:Not adding activation input quantizer for operation: 1465 linear_180
# 1467 add_tensor_81
# 1469 div_40
#
# INFO:nncf:Not adding activation input quantizer for operation: 1475 linear_181
# INFO:nncf:Not adding activation input quantizer for operation: 1491 linear_184
# 1493 add_tensor_82
# 1495 div_41
#
# INFO:nncf:Not adding activation input quantizer for operation: 1501 linear_185
# 1503 add_tensor_83
#
# INFO:nncf:Not adding activation input quantizer for operation: 1511 linear_186
# 1513 add_tensor_84
#
# INFO:nncf:Not adding activation input quantizer for operation: 1519 linear_187
# INFO:nncf:Not adding activation input quantizer for operation: 1521 linear_188
# INFO:nncf:Not adding activation input quantizer for operation: 1523 linear_189
# INFO:nncf:Not adding activation input quantizer for operation: 1535 linear_190
# 1537 add_tensor_85
# 1539 div_42
#
# INFO:nncf:Not adding activation input quantizer for operation: 1545 linear_191
# INFO:nncf:Not adding activation input quantizer for operation: 1561 linear_194
# 1563 add_tensor_86
# 1565 div_43
#
# INFO:nncf:Not adding activation input quantizer for operation: 1571 linear_195
# 1573 add_tensor_87
#
# INFO:nncf:Not adding activation input quantizer for operation: 1581 linear_196
# 1583 add_tensor_88
#
# INFO:nncf:Not adding activation input quantizer for operation: 1589 linear_197
# INFO:nncf:Not adding activation input quantizer for operation: 1591 linear_198
# INFO:nncf:Not adding activation input quantizer for operation: 1593 linear_199
# INFO:nncf:Not adding activation input quantizer for operation: 1605 linear_200
# 1607 add_tensor_89
# 1609 div_44
#
# INFO:nncf:Not adding activation input quantizer for operation: 1615 linear_201
# INFO:nncf:Not adding activation input quantizer for operation: 1631 linear_204
# 1633 add_tensor_90
# 1635 div_45
#
# INFO:nncf:Not adding activation input quantizer for operation: 1641 linear_205
# 1643 add_tensor_91
#
# INFO:nncf:Not adding activation input quantizer for operation: 1651 linear_206
# 1653 add_tensor_92
#
# INFO:nncf:Not adding activation input quantizer for operation: 1659 linear_207
# INFO:nncf:Not adding activation input quantizer for operation: 1661 linear_208
# INFO:nncf:Not adding activation input quantizer for operation: 1663 linear_209
# INFO:nncf:Not adding activation input quantizer for operation: 1675 linear_210
# 1677 add_tensor_93
# 1679 div_46
#
# INFO:nncf:Not adding activation input quantizer for operation: 1685 linear_211
# INFO:nncf:Not adding activation input quantizer for operation: 1701 linear_214
# 1703 add_tensor_94
# 1705 div_47
#
# INFO:nncf:Not adding activation input quantizer for operation: 1711 linear_215
# 1713 add_tensor_95
#
# INFO:nncf:Not adding activation input quantizer for operation: 1721 linear_216
# 1723 add_tensor_96
#
# INFO:nncf:Not adding activation input quantizer for operation: 1729 linear_217
# INFO:nncf:Not adding activation input quantizer for operation: 1731 linear_218
# INFO:nncf:Not adding activation input quantizer for operation: 1733 linear_219
# INFO:nncf:Not adding activation input quantizer for operation: 1745 linear_220
# 1747 add_tensor_97
# 1749 div_48
#
# INFO:nncf:Not adding activation input quantizer for operation: 1755 linear_221
# INFO:nncf:Not adding activation input quantizer for operation: 1771 linear_224
# 1773 add_tensor_98
# 1775 div_49
#
# INFO:nncf:Not adding activation input quantizer for operation: 1781 linear_225
# 1783 add_tensor_99
#
# INFO:nncf:Not adding activation input quantizer for operation: 1791 linear_226
# 1793 add_tensor_100
#
# INFO:nncf:Not adding activation input quantizer for operation: 1799 linear_227
# INFO:nncf:Not adding activation input quantizer for operation: 1801 linear_228
# INFO:nncf:Not adding activation input quantizer for operation: 1803 linear_229
# INFO:nncf:Not adding activation input quantizer for operation: 1815 linear_230
# 1817 add_tensor_101
# 1819 div_50
#
# INFO:nncf:Not adding activation input quantizer for operation: 1825 linear_231
# INFO:nncf:Not adding activation input quantizer for operation: 1841 linear_234
# 1843 add_tensor_102
# 1845 div_51
#
# INFO:nncf:Not adding activation input quantizer for operation: 1851 linear_235
# 1853 add_tensor_103
#
# INFO:nncf:Not adding activation input quantizer for operation: 1861 linear_236
# 1863 add_tensor_104
#
# INFO:nncf:Not adding activation input quantizer for operation: 1869 linear_237
# INFO:nncf:Not adding activation input quantizer for operation: 1871 linear_238
# INFO:nncf:Not adding activation input quantizer for operation: 1873 linear_239
# INFO:nncf:Not adding activation input quantizer for operation: 1885 linear_240
# 1887 add_tensor_105
# 1889 div_52
#
# INFO:nncf:Not adding activation input quantizer for operation: 1895 linear_241
# INFO:nncf:Not adding activation input quantizer for operation: 1911 linear_244
# 1913 add_tensor_106
# 1915 div_53
#
# INFO:nncf:Not adding activation input quantizer for operation: 1921 linear_245
# 1923 add_tensor_107
#
# INFO:nncf:Not adding activation input quantizer for operation: 1931 linear_246
# 1933 add_tensor_108
#
# INFO:nncf:Not adding activation input quantizer for operation: 1939 linear_247
# INFO:nncf:Not adding activation input quantizer for operation: 1941 linear_248
# INFO:nncf:Not adding activation input quantizer for operation: 1943 linear_249
# INFO:nncf:Not adding activation input quantizer for operation: 1955 linear_250
# 1957 add_tensor_109
# 1959 div_54
#
# INFO:nncf:Not adding activation input quantizer for operation: 1965 linear_251
# INFO:nncf:Not adding activation input quantizer for operation: 1981 linear_254
# 1983 add_tensor_110
# 1985 div_55
#
# INFO:nncf:Not adding activation input quantizer for operation: 1991 linear_255
# 1993 add_tensor_111
#
# INFO:nncf:Not adding activation input quantizer for operation: 2001 linear_256
# 2003 add_tensor_112
#
# INFO:nncf:Not adding activation input quantizer for operation: 2006 linear_257
# 2008 add_tensor_113
#
# INFO:nncf:Not adding activation input quantizer for operation: 2048 linear_259
# 2050 add_tensor_115
#
# INFO:nncf:Not adding activation input quantizer for operation: 2055 linear_260
# INFO:nncf:Not adding activation input quantizer for operation: 2057 linear_261
# INFO:nncf:Not adding activation input quantizer for operation: 2059 linear_262
# INFO:nncf:Not adding activation input quantizer for operation: 2071 linear_263
# 2073 add_tensor_116
# 2075 div_57
#
# INFO:nncf:Not adding activation input quantizer for operation: 2081 linear_264
# INFO:nncf:Not adding activation input quantizer for operation: 2097 linear_267
# 2099 add_tensor_117
# 2101 div_58
#
# INFO:nncf:Not adding activation input quantizer for operation: 2107 linear_268
# 2109 add_tensor_118
#
# INFO:nncf:Not adding activation input quantizer for operation: 2117 linear_269
# 2119 add_tensor_119
#
# INFO:nncf:Not adding activation input quantizer for operation: 2125 linear_270
# INFO:nncf:Not adding activation input quantizer for operation: 2127 linear_271
# INFO:nncf:Not adding activation input quantizer for operation: 2129 linear_272
# INFO:nncf:Not adding activation input quantizer for operation: 2141 linear_273
# 2143 add_tensor_120
# 2145 div_59
#
# INFO:nncf:Not adding activation input quantizer for operation: 2151 linear_274
# INFO:nncf:Not adding activation input quantizer for operation: 2167 linear_277
# 2169 add_tensor_121
# 2171 div_60
#
# INFO:nncf:Not adding activation input quantizer for operation: 2177 linear_278
# 2179 add_tensor_122
#
# INFO:nncf:Not adding activation input quantizer for operation: 2187 linear_279
# 2189 add_tensor_123
#
# INFO:nncf:Not adding activation input quantizer for operation: 2195 linear_280
# INFO:nncf:Not adding activation input quantizer for operation: 2197 linear_281
# INFO:nncf:Not adding activation input quantizer for operation: 2199 linear_282
# INFO:nncf:Not adding activation input quantizer for operation: 2211 linear_283
# 2213 add_tensor_124
# 2215 div_61
#
# INFO:nncf:Not adding activation input quantizer for operation: 2221 linear_284
# INFO:nncf:Not adding activation input quantizer for operation: 2237 linear_287
# 2239 add_tensor_125
# 2241 div_62
#
# INFO:nncf:Not adding activation input quantizer for operation: 2247 linear_288
# 2249 add_tensor_126
#
# INFO:nncf:Not adding activation input quantizer for operation: 2257 linear_289
# 2259 add_tensor_127
#
# INFO:nncf:Not adding activation input quantizer for operation: 2265 linear_290
# INFO:nncf:Not adding activation input quantizer for operation: 2267 linear_291
# INFO:nncf:Not adding activation input quantizer for operation: 2269 linear_292
# INFO:nncf:Not adding activation input quantizer for operation: 2281 linear_293
# 2283 add_tensor_128
# 2285 div_63
#
# INFO:nncf:Not adding activation input quantizer for operation: 2291 linear_294
# INFO:nncf:Not adding activation input quantizer for operation: 2307 linear_297
# 2309 add_tensor_129
# 2311 div_64
#
# INFO:nncf:Not adding activation input quantizer for operation: 2317 linear_298
# 2319 add_tensor_130
#
# INFO:nncf:Not adding activation input quantizer for operation: 2327 linear_299
# 2329 add_tensor_131
#
# INFO:nncf:Not adding activation input quantizer for operation: 2335 linear_300
# INFO:nncf:Not adding activation input quantizer for operation: 2337 linear_301
# INFO:nncf:Not adding activation input quantizer for operation: 2339 linear_302
# INFO:nncf:Not adding activation input quantizer for operation: 2351 linear_303
# 2353 add_tensor_132
# 2355 div_65
#
# INFO:nncf:Not adding activation input quantizer for operation: 2361 linear_304
# INFO:nncf:Not adding activation input quantizer for operation: 2377 linear_307
# 2379 add_tensor_133
# 2381 div_66
#
# INFO:nncf:Not adding activation input quantizer for operation: 2387 linear_308
# 2389 add_tensor_134
#
# INFO:nncf:Not adding activation input quantizer for operation: 2397 linear_309
# 2399 add_tensor_135
#
# INFO:nncf:Not adding activation input quantizer for operation: 2405 linear_310
# INFO:nncf:Not adding activation input quantizer for operation: 2407 linear_311
# INFO:nncf:Not adding activation input quantizer for operation: 2409 linear_312
# INFO:nncf:Not adding activation input quantizer for operation: 2421 linear_313
# 2423 add_tensor_136
# 2425 div_67
#
# INFO:nncf:Not adding activation input quantizer for operation: 2431 linear_314
# INFO:nncf:Not adding activation input quantizer for operation: 2447 linear_317
# 2449 add_tensor_137
# 2451 div_68
#
# INFO:nncf:Not adding activation input quantizer for operation: 2457 linear_318
# 2459 add_tensor_138
#
# INFO:nncf:Not adding activation input quantizer for operation: 2467 linear_319
# 2469 add_tensor_139
#
# INFO:nncf:Not adding activation input quantizer for operation: 2475 linear_320
# INFO:nncf:Not adding activation input quantizer for operation: 2477 linear_321
# INFO:nncf:Not adding activation input quantizer for operation: 2479 linear_322
# INFO:nncf:Not adding activation input quantizer for operation: 2491 linear_323
# 2493 add_tensor_140
# 2495 div_69
#
# INFO:nncf:Not adding activation input quantizer for operation: 2501 linear_324
# INFO:nncf:Not adding activation input quantizer for operation: 2517 linear_327
# 2519 add_tensor_141
# 2521 div_70
#
# INFO:nncf:Not adding activation input quantizer for operation: 2527 linear_328
# 2529 add_tensor_142
#
# INFO:nncf:Not adding activation input quantizer for operation: 2537 linear_329
# 2539 add_tensor_143
#
# INFO:nncf:Not adding activation input quantizer for operation: 2545 linear_330
# INFO:nncf:Not adding activation input quantizer for operation: 2547 linear_331
# INFO:nncf:Not adding activation input quantizer for operation: 2549 linear_332
# INFO:nncf:Not adding activation input quantizer for operation: 2561 linear_333
# 2563 add_tensor_144
# 2565 div_71
#
# INFO:nncf:Not adding activation input quantizer for operation: 2571 linear_334
# INFO:nncf:Not adding activation input quantizer for operation: 2587 linear_337
# 2589 add_tensor_145
# 2591 div_72
#
# INFO:nncf:Not adding activation input quantizer for operation: 2597 linear_338
# 2599 add_tensor_146
#
# INFO:nncf:Not adding activation input quantizer for operation: 2607 linear_339
# 2609 add_tensor_147
#
# INFO:nncf:Not adding activation input quantizer for operation: 2615 linear_340
# INFO:nncf:Not adding activation input quantizer for operation: 2617 linear_341
# INFO:nncf:Not adding activation input quantizer for operation: 2619 linear_342
# INFO:nncf:Not adding activation input quantizer for operation: 2631 linear_343
# 2633 add_tensor_148
# 2635 div_73
#
# INFO:nncf:Not adding activation input quantizer for operation: 2641 linear_344
# INFO:nncf:Not adding activation input quantizer for operation: 2657 linear_347
# 2659 add_tensor_149
# 2661 div_74
#
# INFO:nncf:Not adding activation input quantizer for operation: 2667 linear_348
# 2669 add_tensor_150
#
# INFO:nncf:Not adding activation input quantizer for operation: 2677 linear_349
# 2679 add_tensor_151
#
# INFO:nncf:Not adding activation input quantizer for operation: 2685 linear_350
# INFO:nncf:Not adding activation input quantizer for operation: 2687 linear_351
# INFO:nncf:Not adding activation input quantizer for operation: 2689 linear_352
# INFO:nncf:Not adding activation input quantizer for operation: 2701 linear_353
# 2703 add_tensor_152
# 2705 div_75
#
# INFO:nncf:Not adding activation input quantizer for operation: 2711 linear_354
# INFO:nncf:Not adding activation input quantizer for operation: 2727 linear_357
# 2729 add_tensor_153
# 2731 div_76
#
# INFO:nncf:Not adding activation input quantizer for operation: 2737 linear_358
# 2739 add_tensor_154
#
# INFO:nncf:Not adding activation input quantizer for operation: 2747 linear_359
# 2749 add_tensor_155
#
# INFO:nncf:Not adding activation input quantizer for operation: 2752 linear_360
# 2754 add_tensor_156
#
# INFO:nncf:Not adding activation input quantizer for operation: 2828 linear_363
# 2830 add_tensor_159
#
# INFO:nncf:Not adding activation input quantizer for operation: 2835 linear_364
# INFO:nncf:Not adding activation input quantizer for operation: 2837 linear_365
# INFO:nncf:Not adding activation input quantizer for operation: 2839 linear_366
# INFO:nncf:Not adding activation input quantizer for operation: 2851 linear_367
# 2853 add_tensor_160
# 2855 div_79
#
# INFO:nncf:Not adding activation input quantizer for operation: 2861 linear_368
# INFO:nncf:Not adding activation input quantizer for operation: 2877 linear_371
# 2879 add_tensor_161
# 2881 div_80
#
# INFO:nncf:Not adding activation input quantizer for operation: 2887 linear_372
# 2889 add_tensor_162
#
# INFO:nncf:Not adding activation input quantizer for operation: 2897 linear_373
# 2899 add_tensor_163
#
# INFO:nncf:Not adding activation input quantizer for operation: 2905 linear_374
# INFO:nncf:Not adding activation input quantizer for operation: 2907 linear_375
# INFO:nncf:Not adding activation input quantizer for operation: 2909 linear_376
# INFO:nncf:Not adding activation input quantizer for operation: 2921 linear_377
# 2923 add_tensor_164
# 2925 div_81
#
# INFO:nncf:Not adding activation input quantizer for operation: 2931 linear_378
# INFO:nncf:Not adding activation input quantizer for operation: 2947 linear_381
# 2949 add_tensor_165
# 2951 div_82
#
# INFO:nncf:Not adding activation input quantizer for operation: 2957 linear_382
# 2959 add_tensor_166
#
# INFO:nncf:Not adding activation input quantizer for operation: 2967 linear_383
# 2969 add_tensor_167
#
# INFO:nncf:Not adding activation input quantizer for operation: 2975 linear_384
# INFO:nncf:Not adding activation input quantizer for operation: 2977 linear_385
# INFO:nncf:Not adding activation input quantizer for operation: 2979 linear_386
# INFO:nncf:Not adding activation input quantizer for operation: 2991 linear_387
# 2993 add_tensor_168
# 2995 div_83
#
# INFO:nncf:Not adding activation input quantizer for operation: 3001 linear_388
# INFO:nncf:Not adding activation input quantizer for operation: 3017 linear_391
# 3019 add_tensor_169
# 3021 div_84
#
# INFO:nncf:Not adding activation input quantizer for operation: 3027 linear_392
# 3029 add_tensor_170
#
# INFO:nncf:Not adding activation input quantizer for operation: 3037 linear_393
# 3039 add_tensor_171
#
# INFO:nncf:Not adding activation input quantizer for operation: 3045 linear_394
# INFO:nncf:Not adding activation input quantizer for operation: 3047 linear_395
# INFO:nncf:Not adding activation input quantizer for operation: 3049 linear_396
# INFO:nncf:Not adding activation input quantizer for operation: 3061 linear_397
# 3063 add_tensor_172
# 3065 div_85
#
# INFO:nncf:Not adding activation input quantizer for operation: 3071 linear_398
# INFO:nncf:Not adding activation input quantizer for operation: 3087 linear_401
# 3089 add_tensor_173
# 3091 div_86
#
# INFO:nncf:Not adding activation input quantizer for operation: 3097 linear_402
# 3099 add_tensor_174
#
# INFO:nncf:Not adding activation input quantizer for operation: 3107 linear_403
# 3109 add_tensor_175
#
# INFO:nncf:Not adding activation input quantizer for operation: 3115 linear_404
# INFO:nncf:Not adding activation input quantizer for operation: 3117 linear_405
# INFO:nncf:Not adding activation input quantizer for operation: 3119 linear_406
# INFO:nncf:Not adding activation input quantizer for operation: 3131 linear_407
# 3133 add_tensor_176
# 3135 div_87
#
# INFO:nncf:Not adding activation input quantizer for operation: 3141 linear_408
# INFO:nncf:Not adding activation input quantizer for operation: 3157 linear_411
# 3159 add_tensor_177
# 3161 div_88
#
# INFO:nncf:Not adding activation input quantizer for operation: 3167 linear_412
# 3169 add_tensor_178
#
# INFO:nncf:Not adding activation input quantizer for operation: 3177 linear_413
# 3179 add_tensor_179
#
# INFO:nncf:Not adding activation input quantizer for operation: 3185 linear_414
# INFO:nncf:Not adding activation input quantizer for operation: 3187 linear_415
# INFO:nncf:Not adding activation input quantizer for operation: 3189 linear_416
# INFO:nncf:Not adding activation input quantizer for operation: 3201 linear_417
# 3203 add_tensor_180
# 3205 div_89
#
# INFO:nncf:Not adding activation input quantizer for operation: 3211 linear_418
# INFO:nncf:Not adding activation input quantizer for operation: 3227 linear_421
# 3229 add_tensor_181
# 3231 div_90
#
# INFO:nncf:Not adding activation input quantizer for operation: 3237 linear_422
# 3239 add_tensor_182
#
# INFO:nncf:Not adding activation input quantizer for operation: 3247 linear_423
# 3249 add_tensor_183
#
# INFO:nncf:Not adding activation input quantizer for operation: 3255 linear_424
# INFO:nncf:Not adding activation input quantizer for operation: 3257 linear_425
# INFO:nncf:Not adding activation input quantizer for operation: 3259 linear_426
# INFO:nncf:Not adding activation input quantizer for operation: 3271 linear_427
# 3273 add_tensor_184
# 3275 div_91
#
# INFO:nncf:Not adding activation input quantizer for operation: 3281 linear_428
# INFO:nncf:Not adding activation input quantizer for operation: 3297 linear_431
# 3299 add_tensor_185
# 3301 div_92
#
# INFO:nncf:Not adding activation input quantizer for operation: 3307 linear_432
# 3309 add_tensor_186
#
# ...
# INFO:nncf:Not adding activation input quantizer for operation: 4008 linear_528
# INFO:nncf:Not adding activation input quantizer for operation: 4010 linear_529
# INFO:nncf:Not adding activation input quantizer for operation: 4022 linear_530
# 4024 add_tensor_227
# 4026 div_112
#
# INFO:nncf:Not adding activation input quantizer for operation: 4032 linear_531
# INFO:nncf:Not adding activation input quantizer for operation: 4048 linear_534
# 4050 add_tensor_228
# 4052 div_113
#
# INFO:nncf:Not adding activation input quantizer for operation: 4058 linear_535
# 4060 add_tensor_229
#
# INFO:nncf:Not adding activation input quantizer for operation: 4068 linear_536
# 4070 add_tensor_230
#
# INFO:nncf:Not adding activation input quantizer for operation: 4076 linear_537
# INFO:nncf:Not adding activation input quantizer for operation: 4078 linear_538
# INFO:nncf:Not adding activation input quantizer for operation: 4080 linear_539
# INFO:nncf:Not adding activation input quantizer for operation: 4092 linear_540
# 4094 add_tensor_231
# 4096 div_114
#
# INFO:nncf:Not adding activation input quantizer for operation: 4102 linear_541
# INFO:nncf:Not adding activation input quantizer for operation: 4118 linear_544
# 4120 add_tensor_232
# 4122 div_115
#
# INFO:nncf:Not adding activation input quantizer for operation: 4128 linear_545
# 4130 add_tensor_233
#
# INFO:nncf:Not adding activation input quantizer for operation: 4138 linear_546
# 4140 add_tensor_234
#
# INFO:nncf:Not adding activation input quantizer for operation: 4146 linear_547
# INFO:nncf:Not adding activation input quantizer for operation: 4148 linear_548
# INFO:nncf:Not adding activation input quantizer for operation: 4150 linear_549
# INFO:nncf:Not adding activation input quantizer for operation: 4162 linear_550
# 4164 add_tensor_235
# 4166 div_116
#
# INFO:nncf:Not adding activation input quantizer for operation: 4172 linear_551
# INFO:nncf:Not adding activation input quantizer for operation: 4188 linear_554
# 4190 add_tensor_236
# 4192 div_117
#
# INFO:nncf:Not adding activation input quantizer for operation: 4198 linear_555
# 4200 add_tensor_237
#
# INFO:nncf:Not adding activation input quantizer for operation: 4208 linear_556
# 4210 add_tensor_238
#
# INFO:nncf:Not adding activation input quantizer for operation: 4216 linear_557
# INFO:nncf:Not adding activation input quantizer for operation: 4218 linear_558
# INFO:nncf:Not adding activation input quantizer for operation: 4220 linear_559
# INFO:nncf:Not adding activation input quantizer for operation: 4232 linear_560
# 4234 add_tensor_239
# 4236 div_118
#
# INFO:nncf:Not adding activation input quantizer for operation: 4242 linear_561
# INFO:nncf:Not adding activation input quantizer for operation: 4258 linear_564
# 4260 add_tensor_240
# 4262 div_119
#
# INFO:nncf:Not adding activation input quantizer for operation: 4268 linear_565
# 4270 add_tensor_241
#
# INFO:nncf:Not adding activation input quantizer for operation: 4278 linear_566
# 4280 add_tensor_242
#
# INFO:nncf:Not adding activation input quantizer for operation: 4283 linear_567
# 4285 add_tensor_243
#
# INFO:nncf:Not adding activation input quantizer for operation: 4330 linear_569
# 4332 add_tensor_245
#
# INFO:nncf:Not adding activation input quantizer for operation: 4337 linear_570
# INFO:nncf:Not adding activation input quantizer for operation: 4339 linear_571
# INFO:nncf:Not adding activation input quantizer for operation: 4341 linear_572
# INFO:nncf:Not adding activation input quantizer for operation: 4353 linear_573
# 4355 add_tensor_246
# 4357 div_121
#
# INFO:nncf:Not adding activation input quantizer for operation: 4363 linear_574
# INFO:nncf:Not adding activation input quantizer for operation: 4379 linear_577
# 4381 add_tensor_247
# 4383 div_122
#
# INFO:nncf:Not adding activation input quantizer for operation: 4389 linear_578
# 4391 add_tensor_248
#
# INFO:nncf:Not adding activation input quantizer for operation: 4399 linear_579
# 4401 add_tensor_249
#
# INFO:nncf:Not adding activation input quantizer for operation: 4407 linear_580
# INFO:nncf:Not adding activation input quantizer for operation: 4409 linear_581
# INFO:nncf:Not adding activation input quantizer for operation: 4411 linear_582
# INFO:nncf:Not adding activation input quantizer for operation: 4423 linear_583
# 4425 add_tensor_250
# 4427 div_123
#
# INFO:nncf:Not adding activation input quantizer for operation: 4433 linear_584
# INFO:nncf:Not adding activation input quantizer for operation: 4449 linear_587
# 4451 add_tensor_251
# 4453 div_124
#
# INFO:nncf:Not adding activation input quantizer for operation: 4459 linear_588
# 4461 add_tensor_252
#
# INFO:nncf:Not adding activation input quantizer for operation: 4469 linear_589
# 4471 add_tensor_253
#
# INFO:nncf:Not adding activation input quantizer for operation: 4477 linear_590
# INFO:nncf:Not adding activation input quantizer for operation: 4479 linear_591
# INFO:nncf:Not adding activation input quantizer for operation: 4481 linear_592
# INFO:nncf:Not adding activation input quantizer for operation: 4493 linear_593
# 4495 add_tensor_254
# 4497 div_125
#
# INFO:nncf:Not adding activation input quantizer for operation: 4503 linear_594
# INFO:nncf:Not adding activation input quantizer for operation: 4519 linear_597
# 4521 add_tensor_255
# 4523 div_126
#
# INFO:nncf:Not adding activation input quantizer for operation: 4529 linear_598
# 4531 add_tensor_256
#
# INFO:nncf:Not adding activation input quantizer for operation: 4539 linear_599
# 4541 add_tensor_257
#
# INFO:nncf:Not adding activation input quantizer for operation: 4547 linear_600
# INFO:nncf:Not adding activation input quantizer for operation: 4549 linear_601
# INFO:nncf:Not adding activation input quantizer for operation: 4551 linear_602
# INFO:nncf:Not adding activation input quantizer for operation: 4563 linear_603
# 4565 add_tensor_258
# 4567 div_127
#
# INFO:nncf:Not adding activation input quantizer for operation: 4573 linear_604
# INFO:nncf:Not adding activation input quantizer for operation: 4589 linear_607
# 4591 add_tensor_259
# 4593 div_128
#
# INFO:nncf:Not adding activation input quantizer for operation: 4599 linear_608
# 4601 add_tensor_260
#
# INFO:nncf:Not adding activation input quantizer for operation: 4609 linear_609
# 4611 add_tensor_261
#
# INFO:nncf:Not adding activation input quantizer for operation: 4617 linear_610
# INFO:nncf:Not adding activation input quantizer for operation: 4619 linear_611
# INFO:nncf:Not adding activation input quantizer for operation: 4621 linear_612
# INFO:nncf:Not adding activation input quantizer for operation: 4633 linear_613
# 4635 add_tensor_262
# 4637 div_129
#
# INFO:nncf:Not adding activation input quantizer for operation: 4643 linear_614
# INFO:nncf:Not adding activation input quantizer for operation: 4659 linear_617
# 4661 add_tensor_263
# 4663 div_130
#
# INFO:nncf:Not adding activation input quantizer for operation: 4669 linear_618
# 4671 add_tensor_264
#
# INFO:nncf:Not adding activation input quantizer for operation: 4679 linear_619
# 4681 add_tensor_265
#
# INFO:nncf:Not adding activation input quantizer for operation: 4687 linear_620
# INFO:nncf:Not adding activation input quantizer for operation: 4689 linear_621
# INFO:nncf:Not adding activation input quantizer for operation: 4691 linear_622
# INFO:nncf:Not adding activation input quantizer for operation: 4703 linear_623
# 4705 add_tensor_266
# 4707 div_131
#
# INFO:nncf:Not adding activation input quantizer for operation: 4713 linear_624
# INFO:nncf:Not adding activation input quantizer for operation: 4729 linear_627
# 4731 add_tensor_267
# 4733 div_132
#
# INFO:nncf:Not adding activation input quantizer for operation: 4739 linear_628
# 4741 add_tensor_268
#
# INFO:nncf:Not adding activation input quantizer for operation: 4749 linear_629
# 4751 add_tensor_269
#
# INFO:nncf:Not adding activation input quantizer for operation: 4757 linear_630
# INFO:nncf:Not adding activation input quantizer for operation: 4759 linear_631
# INFO:nncf:Not adding activation input quantizer for operation: 4761 linear_632
# INFO:nncf:Not adding activation input quantizer for operation: 4773 linear_633
# 4775 add_tensor_270
# 4777 div_133
#
# INFO:nncf:Not adding activation input quantizer for operation: 4783 linear_634
# INFO:nncf:Not adding activation input quantizer for operation: 4799 linear_637
# 4801 add_tensor_271
# 4803 div_134
#
# INFO:nncf:Not adding activation input quantizer for operation: 4809 linear_638
# 4811 add_tensor_272
#
# INFO:nncf:Not adding activation input quantizer for operation: 4819 linear_639
# 4821 add_tensor_273
#
# INFO:nncf:Not adding activation input quantizer for operation: 4827 linear_640
# INFO:nncf:Not adding activation input quantizer for operation: 4829 linear_641
# INFO:nncf:Not adding activation input quantizer for operation: 4831 linear_642
# INFO:nncf:Not adding activation input quantizer for operation: 4843 linear_643
# 4845 add_tensor_274
# 4847 div_135
#
# INFO:nncf:Not adding activation input quantizer for operation: 4853 linear_644
# INFO:nncf:Not adding activation input quantizer for operation: 4869 linear_647
# 4871 add_tensor_275
# 4873 div_136
#
# INFO:nncf:Not adding activation input quantizer for operation: 4879 linear_648
# 4881 add_tensor_276
#
# INFO:nncf:Not adding activation input quantizer for operation: 4889 linear_649
# 4891 add_tensor_277
#
# INFO:nncf:Not adding activation input quantizer for operation: 4897 linear_650
# INFO:nncf:Not adding activation input quantizer for operation: 4899 linear_651
# INFO:nncf:Not adding activation input quantizer for operation: 4901 linear_652
# INFO:nncf:Not adding activation input quantizer for operation: 4913 linear_653
# 4915 add_tensor_278
# 4917 div_137
#
# INFO:nncf:Not adding activation input quantizer for operation: 4923 linear_654
# INFO:nncf:Not adding activation input quantizer for operation: 4939 linear_657
# 4941 add_tensor_279
# 4943 div_138
#
# INFO:nncf:Not adding activation input quantizer for operation: 4949 linear_658
# 4951 add_tensor_280
#
# INFO:nncf:Not adding activation input quantizer for operation: 4959 linear_659
# 4961 add_tensor_281
#
# INFO:nncf:Not adding activation input quantizer for operation: 4967 linear_660
# INFO:nncf:Not adding activation input quantizer for operation: 4969 linear_661
# INFO:nncf:Not adding activation input quantizer for operation: 4971 linear_662
# INFO:nncf:Not adding activation input quantizer for operation: 4983 linear_663
# 4985 add_tensor_282
# 4987 div_139
#
# INFO:nncf:Not adding activation input quantizer for operation: 4993 linear_664
# INFO:nncf:Not adding activation input quantizer for operation: 5009 linear_667
# 5011 add_tensor_283
# 5013 div_140
#
# INFO:nncf:Not adding activation input quantizer for operation: 5019 linear_668
# 5021 add_tensor_284
#
# INFO:nncf:Not adding activation input quantizer for operation: 5029 linear_669
# 5031 add_tensor_285
#
# INFO:nncf:Not adding activation input quantizer for operation: 5034 linear_670
# 5036 add_tensor_286
#
# INFO:nncf:Not adding activation input quantizer for operation: 5086 linear_672
# 5088 add_tensor_288
#
# INFO:nncf:Not adding activation input quantizer for operation: 5093 linear_673
# INFO:nncf:Not adding activation input quantizer for operation: 5095 linear_674
# INFO:nncf:Not adding activation input quantizer for operation: 5097 linear_675
# INFO:nncf:Not adding activation input quantizer for operation: 5109 linear_676
# 5111 add_tensor_289
# 5113 div_142
#
# INFO:nncf:Not adding activation input quantizer for operation: 5119 linear_677
# INFO:nncf:Not adding activation input quantizer for operation: 5135 linear_680
# 5137 add_tensor_290
# 5139 div_143
#
# INFO:nncf:Not adding activation input quantizer for operation: 5145 linear_681
# 5147 add_tensor_291
#
# INFO:nncf:Not adding activation input quantizer for operation: 5155 linear_682
# 5157 add_tensor_292
#
# INFO:nncf:Not adding activation input quantizer for operation: 5163 linear_683
# INFO:nncf:Not adding activation input quantizer for operation: 5165 linear_684
# INFO:nncf:Not adding activation input quantizer for operation: 5167 linear_685
# INFO:nncf:Not adding activation input quantizer for operation: 5179 linear_686
# 5181 add_tensor_293
# 5183 div_144
#
# INFO:nncf:Not adding activation input quantizer for operation: 5189 linear_687
# INFO:nncf:Not adding activation input quantizer for operation: 5205 linear_690
# 5207 add_tensor_294
# 5209 div_145
#
# INFO:nncf:Not adding activation input quantizer for operation: 5215 linear_691
# 5217 add_tensor_295
#
# INFO:nncf:Not adding activation input quantizer for operation: 5225 linear_692
# 5227 add_tensor_296
#
# INFO:nncf:Not adding activation input quantizer for operation: 5230 linear_693
# 5232 add_tensor_297
#
# INFO:nncf:Not adding activation input quantizer for operation: 5277 linear_695
# 5279 add_tensor_299
#
# INFO:nncf:Not adding activation input quantizer for operation: 5284 linear_696
# INFO:nncf:Not adding activation input quantizer for operation: 5286 linear_697
# INFO:nncf:Not adding activation input quantizer for operation: 5288 linear_698
# INFO:nncf:Not adding activation input quantizer for operation: 5300 linear_699
# 5302 add_tensor_300
# 5304 div_147
#
# INFO:nncf:Not adding activation input quantizer for operation: 5310 linear_700
# INFO:nncf:Not adding activation input quantizer for operation: 5326 linear_703
# 5328 add_tensor_301
# 5330 div_148
#
# INFO:nncf:Not adding activation input quantizer for operation: 5336 linear_704
# 5338 add_tensor_302
#
# INFO:nncf:Not adding activation input quantizer for operation: 5346 linear_705
# 5348 add_tensor_303
#
# INFO:nncf:Not adding activation input quantizer for operation: 5354 linear_706
# INFO:nncf:Not adding activation input quantizer for operation: 5356 linear_707
# INFO:nncf:Not adding activation input quantizer for operation: 5358 linear_708
# INFO:nncf:Not adding activation input quantizer for operation: 5370 linear_709
# 5372 add_tensor_304
# 5374 div_149
#
# INFO:nncf:Not adding activation input quantizer for operation: 5380 linear_710
# INFO:nncf:Not adding activation input quantizer for operation: 5396 linear_713
# 5398 add_tensor_305
# 5400 div_150
#
# INFO:nncf:Not adding activation input quantizer for operation: 5406 linear_714
# 5408 add_tensor_306
#
# INFO:nncf:Not adding activation input quantizer for operation: 5416 linear_715
# 5418 add_tensor_307
#
# INFO:nncf:Not adding activation input quantizer for operation: 5421 linear_716
# 5423 add_tensor_308
#
# INFO:nncf:Not adding activation input quantizer for operation: 5468 linear_718
# 5470 add_tensor_310
#
# INFO:nncf:Not adding activation input quantizer for operation: 5475 linear_719
# INFO:nncf:Not adding activation input quantizer for operation: 5477 linear_720
# INFO:nncf:Not adding activation input quantizer for operation: 5479 linear_721
# INFO:nncf:Not adding activation input quantizer for operation: 5491 linear_722
# 5493 add_tensor_311
# 5495 div_152
#
# INFO:nncf:Not adding activation input quantizer for operation: 5501 linear_723
# INFO:nncf:Not adding activation input quantizer for operation: 5517 linear_726
# 5519 add_tensor_312
# 5521 div_153
#
# INFO:nncf:Not adding activation input quantizer for operation: 5527 linear_727
# 5529 add_tensor_313
#
# INFO:nncf:Not adding activation input quantizer for operation: 5537 linear_728
# 5539 add_tensor_314
#
# INFO:nncf:Not adding activation input quantizer for operation: 5545 linear_729
# INFO:nncf:Not adding activation input quantizer for operation: 5547 linear_730
# INFO:nncf:Not adding activation input quantizer for operation: 5549 linear_731
# INFO:nncf:Not adding activation input quantizer for operation: 5561 linear_732
# 5563 add_tensor_315
# 5565 div_154
#
# INFO:nncf:Not adding activation input quantizer for operation: 5571 linear_733
# INFO:nncf:Not adding activation input quantizer for operation: 5587 linear_736
# 5589 add_tensor_316
# 5591 div_155
#
# INFO:nncf:Not adding activation input quantizer for operation: 5597 linear_737
# 5599 add_tensor_317
#
# INFO:nncf:Not adding activation input quantizer for operation: 5607 linear_738
# 5609 add_tensor_318
#
# INFO:nncf:Not adding activation input quantizer for operation: 5612 linear_739
# 5614 add_tensor_319
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ### Compile Models with OV Backend

# %%
pipe.text_encoder = torch.compile(compressed_text_encoder, backend='openvino')
pipe.text_encoder_2 = torch.compile(compressed_text_encoder_2, backend='openvino')
pipe.vae.decoder = torch.compile(compressed_vae_decoder, backend='openvino')
pipe.vae.encoder = torch.compile(compressed_vae_encoder, backend='openvino')
pipe.unet = torch.compile(quantized_unet, backend='openvino')
del compressed_text_encoder
del compressed_text_encoder_2
del compressed_vae_decoder
del compressed_vae_encoder
del quantized_unet
gc.collect()
# Out:
# 35

# %%
len(pipe)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 len(pipe)
#
# TypeError: object of type 'StableDiffusionXLPipeline' has no len()

# %%
def get_model_size(models):
    total_size = 0
    for model in models:
        param_size = 0
        for param in model.parameters():
            param_size += param.nelement() * param.element_size()
        buffer_size = 0
        for buffer in model.buffers():
            buffer_size += buffer.nelement() * buffer.element_size()

        model_size_mb = (param_size + buffer_size) / 1024**2

        total_size += model_size_mb
    return total_size

get_model_size([pipe.unet, pipe.vae.encoder, pipe.vae.decoder, pipe.text_encoder, pipe.text_encoder_2])
# Out:
# 10657.735987663269

# %% [markdown]
# ### Inference for Compilation

# %%
#Warmup the model for initial compile
# prompt = "valley in the Alps at sunset, epic vista, beautiful landscape, 4k, 8k"
prompt = "cute cat 4k, high-res, masterpiece, best quality, soft lighting, dynamic angle"
negative_prompt = "frames, borderline, text, charachter, duplicate, error, out of frame, watermark, low quality, ugly, deformed, blur"
num_steps = 1
with torch.no_grad():
    image = pipe(prompt=prompt, negative_prompt=negative_prompt, num_inference_steps=num_steps, generator=generator).images[0]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# Reached
# torch.Size([1, 4, 128, 128])

# %%
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)
with torch.no_grad():
    image = pipe(prompt=prompt, num_inference_steps=25, generator=generator).images[0]
image.show()
image.save("stable_diffusion_xl_all_fx_unet_quantized_more_calibration.png")
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# torch.Size([2, 1280]) torch.Size([2, 6]) torch.Size([2, 4, 128, 128]) torch.Size([]) encoder_hidden_states= torch.Size([2, 77, 2048]) cross_attention_kwarg None
# Reached
# torch.Size([1, 4, 128, 128])
